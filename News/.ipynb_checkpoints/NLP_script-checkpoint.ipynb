# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk import FreqDist

# %%
#Reading of .csv file
df = pd.read_csv("TheGuardian.csv")
content = df['Text']
assert content.isnull().count() == len(content)

# %%
#Before stop word removal count
count = [len(content[i]) for i in range(200)]
# data['Count Before'] = count
print(count)
# Out:
# [4193, 8625, 9258, 2648, 13182, 1899, 7842, 11971, 8772, 5565, 9165, 3198, 2426, 8657, 9182, 12405, 11333, 25352, 7375, 12506, 12845, 3788, 23099, 7351, 7728, 4338, 10207, 11862, 10192, 10773, 5184, 13471, 1028, 6678, 3873, 4470, 10071, 7516, 2964, 3423, 6897, 7321, 6019, 2920, 1614, 1004, 3680, 8942, 6232, 8002, 16608, 7648, 7448, 8712, 8582, 7375, 4079, 8308, 2319, 1882, 7517, 5742, 6646, 638, 7839, 7870, 624, 20102, 10232, 5633, 4097, 3218, 7325, 6543, 3348, 7306, 4280, 9235, 9615, 3016, 1582, 1119, 4117, 6499, 4670, 3604, 10180, 3544, 5768, 9769, 6767, 3352, 828, 5165, 4172, 1195, 1460, 3413, 2723, 7797, 9302, 12164, 5348, 5273, 7782, 3729, 3376, 3347, 4418, 7799, 1798, 6489, 2310, 3982, 9678, 7603, 11839, 720, 5915, 3332, 7701, 5279, 9187, 13448, 5879, 5599, 8929, 2212, 1950, 26567, 3209, 21282, 5188, 4600, 8239, 1318, 4899, 4707, 4045, 7950, 6905, 5694, 4248, 6604, 13625, 5775, 6385, 6005, 7459, 9072, 16628, 8515, 7515, 2805, 11277, 4662, 3423, 9310, 6415, 9101, 7395, 10163, 3749, 6962, 6004, 2551, 7063, 3189, 7154, 9514, 3657, 8356, 9881, 12059, 7653, 2324, 5158, 7010, 8721, 6863, 7818, 31668, 8641, 8062, 1877, 3927, 5917, 3298, 4480, 6634, 4576, 10661, 1337, 2040, 3964, 5096, 270, 4200, 14125, 1955]

# %%
#Tokenization
from nltk.tokenize import RegexpTokenizer


data = []
tokenizer = RegexpTokenizer(r'\w+')

content = content.apply(lambda x: tokenizer.tokenize(x))
content.head(20)
# Out:
# 0     [Google, has, snapped, up, the, Fitbit, activi...
# 1     [Brilliant, camera, slick, features, and, smal...
# 2     [On, a, dark, dark, night, in, a, dark, dark, ...
# 3     [Labour, has, written, to, the, competition, r...
# 4     [Google, s, latest, Pixel, 4, XL, smartphone, ...
# 5     [Apple, has, launched, a, new, set, of, its, p...
# 6     [I, use, a, 9, 7in, Samsung, Galaxy, Tab, S2, ...
# 7     [Always, on, screen, completes, the, package, ...
# 8     [Still, an, absolute, beast, in, every, way, e...
# 9     [First, it, was, books, then, it, was, the, Ki...
# 10    [The, OnePlus, 7T, takes, the, best, bits, of,...
# 11    [In, a, country, where, the, biggest, companie...
# 12    [I, think, you, should, at, least, make, an, e...
# 13    [Plastic, packaging, has, many, amazing, quali...
# 14    [A, great, camera, screen, and, performance, c...
# 15    [After, a, period, of, stagnation, the, A, Lea...
# 16    [Apple, s, iPhone, has, gone, pro, for, its, 1...
# 17    [Gordon, s, wine, bar, is, reached, through, a...
# 18    [Microsoft, has, launched, the, Surface, Pro, ...
# 19    [Apple, s, lower, cost, model, has, latest, ch...
# Name: Text, dtype: object

# %%
#Removal of Stop Words
from nltk.corpus import stopwords
set(stopwords.words('english'))

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

content = content.apply(lambda x: remove_stopwords(x))

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i, pos="v") for i in text]
    return lem_text

content = content.apply(lambda x: word_lemmatizer(x))

content_freq = content

# %%
#Count after removal of stop words
countaft = [len(content[i]) for i in range(200)]
print(countaft)
# Out:
# [435, 944, 951, 241, 1399, 202, 834, 1237, 973, 558, 1007, 331, 255, 853, 1047, 1320, 1240, 2484, 802, 1348, 1366, 406, 2427, 710, 820, 468, 1057, 1288, 1063, 1156, 616, 1389, 112, 664, 383, 476, 1096, 754, 301, 317, 793, 766, 563, 320, 169, 96, 368, 861, 569, 876, 1827, 846, 809, 970, 879, 811, 393, 870, 253, 206, 801, 548, 709, 70, 835, 851, 67, 1956, 1132, 596, 424, 378, 824, 732, 367, 796, 455, 935, 995, 328, 171, 107, 432, 604, 441, 349, 1140, 345, 581, 1004, 723, 347, 78, 545, 449, 131, 148, 365, 298, 885, 919, 1288, 548, 556, 853, 407, 343, 345, 479, 792, 173, 686, 224, 394, 1034, 789, 1170, 82, 637, 341, 797, 579, 913, 1437, 580, 558, 892, 240, 205, 2776, 307, 1985, 545, 483, 807, 137, 494, 480, 426, 818, 731, 616, 428, 705, 1570, 591, 649, 628, 724, 904, 1585, 888, 806, 309, 1235, 550, 329, 1030, 705, 921, 799, 1094, 429, 762, 559, 260, 765, 329, 779, 1047, 343, 862, 960, 1240, 815, 230, 531, 779, 827, 664, 876, 3000, 937, 836, 199, 428, 641, 329, 486, 671, 458, 1089, 136, 220, 416, 502, 29, 443, 1447, 204]

# %%
#Tagging
content = [nltk.pos_tag(i) for i in content]

# %%
for tags in content:
    if tags[0][1] == "NNP":
        print(tags[0][0])
# Out:
# Google
# Brilliant
# Labour
# Google
# Apple
# First
# Plastic
# Apple
# Gordon
# Microsoft
# Apple
# Amazon
# Libratone
# Bose
# Apple
# Google
# Huawei
# Australia
# Samsung
# George
# Australia
# Apple
# BlackBerry
# Music
# Apple
# Apple
# Smallest
# Panasonic
# Huawei
# Great
# Earbuds
# Google
# Spotify
# Malcolm
# Huawei
# Hello
# TS
# South
# Samsung
# Samsung
# Samsung
# Sad
# Apple
# Imagine
# Facebook
# Channel
# Huawei
# Huawei
# Police
# Black
# Vacuum
# Think
# Apple
# Huawei
# Google
# Apple
# Peter
# Google
# Action
# Trip
# Huawei
# Facebook
# Kim
# Fortnite
# Samsung
# Google
# Online
# Elijah
# MP3
# Huawei
# Thursday

# %%
count_diff = []
for i in range(len(count)):
    count_diff.append(round(((count[i] - countaft[i])/count[i])*100, 1))
print(count_diff)
# Out:
# [89.6, 89.1, 89.7, 90.9, 89.4, 89.4, 89.4, 89.7, 88.9, 90.0, 89.0, 89.6, 89.5, 90.1, 88.6, 89.4, 89.1, 90.2, 89.1, 89.2, 89.4, 89.3, 89.5, 90.3, 89.4, 89.2, 89.6, 89.1, 89.6, 89.3, 88.1, 89.7, 89.1, 90.1, 90.1, 89.4, 89.1, 90.0, 89.8, 90.7, 88.5, 89.5, 90.6, 89.0, 89.5, 90.4, 90.0, 90.4, 90.9, 89.1, 89.0, 88.9, 89.1, 88.9, 89.8, 89.0, 90.4, 89.5, 89.1, 89.1, 89.3, 90.5, 89.3, 89.0, 89.3, 89.2, 89.3, 90.3, 88.9, 89.4, 89.7, 88.3, 88.8, 88.8, 89.0, 89.1, 89.4, 89.9, 89.7, 89.1, 89.2, 90.4, 89.5, 90.7, 90.6, 90.3, 88.8, 90.3, 89.9, 89.7, 89.3, 89.6, 90.6, 89.4, 89.2, 89.0, 89.9, 89.3, 89.1, 88.6, 90.1, 89.4, 89.8, 89.5, 89.0, 89.1, 89.8, 89.7, 89.2, 89.8, 90.4, 89.4, 90.3, 90.1, 89.3, 89.6, 90.1, 88.6, 89.2, 89.8, 89.7, 89.0, 90.1, 89.3, 90.1, 90.0, 90.0, 89.2, 89.5, 89.6, 90.4, 90.7, 89.5, 89.5, 90.2, 89.6, 89.9, 89.8, 89.5, 89.7, 89.4, 89.2, 89.9, 89.3, 88.5, 89.8, 89.8, 89.5, 90.3, 90.0, 90.5, 89.6, 89.3, 89.0, 89.0, 88.2, 90.4, 88.9, 89.0, 89.9, 89.2, 89.2, 88.6, 89.1, 90.7, 89.8, 89.2, 89.7, 89.1, 89.0, 90.6, 89.7, 90.3, 89.7, 89.4, 90.1, 89.7, 88.9, 90.5, 90.3, 88.8, 90.5, 89.2, 89.6, 89.4, 89.1, 89.2, 90.0, 89.2, 89.9, 90.0, 89.8, 89.8, 89.2, 89.5, 90.1, 89.3, 89.5, 89.8, 89.6]

# %%
print(content_freq)
# Out:
# 0      [Google, snap, Fitbit, activity, tracker, busi...
# 1      [Brilliant, camera, slick, feature, small, siz...
# 2      [On, dark, dark, night, dark, dark, town, dark...
# 3      [Labour, write, competition, regulator, call, ...
# 4      [Google, latest, Pixel, 4, XL, smartphone, bra...
#                              ...
# 195    [In, 2007, coincide, moment, David, Beckham, m...
# 196    [Weirdly, indelible, memory, lacy, trousers, R...
# 197    [How, find, best, value, smartphone, deal, If,...
# 198    [Thursday, 12, July, red, letter, day, thousan...
# 199    [Glass, maker, Corning, unveil, new, version, ...
# Name: Text, Length: 200, dtype: object

# %%
Freq = [FreqDist(content_freq[i]).most_common(5) for i in range(len(content_freq))]

# %%
df['Amount Cleansed (%)'] = count_diff
df['Frequency'] = Freq

df.to_csv('Output.csv')

# %%
import pprint
pprint.pprint(Freq)
# Out:
# [[('Fitbit', 15), ('Google', 14), ('data', 13), ('The', 9), ('deal', 7)],
#  [('Pixel', 27), ('4', 25), ('Google', 18), ('The', 17), ('phone', 15)],
#  [('Halloween', 36), ('people', 14), ('The', 11), ('costume', 10), ('year', 9)],
#  [('Google', 8), ('Watson', 6), ('data', 6), ('write', 5), ('CMA', 5)],
#  [('Google', 27), ('phone', 26), ('Pixel', 21), ('The', 21), ('4', 19)],
#  [('AirPods', 8), ('earbuds', 5), ('The', 5), ('Pro', 5), ('Apple', 4)],
#  [('iPad', 18), ('storage', 15), ('Pro', 13), ('Apple', 11), ('It', 9)],
#  [('Apple', 40), ('Watch', 27), ('I', 21), ('The', 18), ('iPhone', 14)],
#  [('The', 26), ('Pro', 24), ('7T', 21), ('OnePlus', 17), ('camera', 14)],
#  [('brand', 14), ('music', 12), ('festival', 12), ('one', 6), ('cultural', 6)],
#  [('The', 24), ('7T', 19), ('OnePlus', 17), ('camera', 17), ('screen', 15)],
#  [('company', 10), ('startup', 8), ('Seoul', 7), ('startups', 7), ('Korea', 6)],
#  [('I', 12), ('yawn', 6), ('emojis', 6), ('emoji', 6), ('new', 5)],
#  [('plastic', 36),
#   ('package', 27),
#   ('recycle', 22),
#   ('Henkel', 15),
#   ('Plastic', 12)],
#  [('iPhone', 42), ('11', 34), ('Pro', 34), ('Max', 22), ('The', 19)],
#  [('season', 27), ('could', 17), ('A', 16), ('League', 14), ('last', 12)],
#  [('iPhone', 42), ('11', 30), ('Pro', 29), ('The', 27), ('Apple', 13)],
#  [('say', 36), ('The', 30), ('police', 28), ('face', 27), ('recognition', 26)],
#  [('Surface', 31), ('Microsoft', 23), ('The', 18), ('screen', 15), ('new', 13)],
#  [('iPhone', 57), ('11', 33), ('Apple', 20), ('The', 20), ('camera', 19)],
#  [('I', 66), ('say', 16), ('university', 14), ('go', 14), ('freshers', 14)],
#  [('Echo', 14), ('Alexa', 12), ('Amazon', 11), ('99', 10), ('smart', 7)],
#  [('sound', 55), ('The', 43), ('good', 41), ('earbuds', 40), ('case', 35)],
#  [('film', 27), ('family', 14), ('Hassan', 10), ('Mahdavian', 9), ('phone', 9)],
#  [('The', 18), ('earbuds', 17), ('noise', 15), ('Track', 15), ('Air', 15)],
#  [('Huawei', 15), ('Google', 11), ('new', 10), ('It', 8), ('Mate', 7)],
#  [('Fairphone', 28), ('phone', 24), ('The', 23), ('3', 22), ('make', 12)],
#  [('iPhone', 63), ('11', 54), ('Pro', 35), ('Max', 21), ('The', 16)],
#  [('The', 21), ('Bose', 17), ('headphones', 17), ('noise', 15), ('sound', 13)],
#  [('Note', 27), ('10', 25), ('Samsung', 23), ('The', 22), ('screen', 21)],
#  [('iPhone', 40), ('11', 19), ('new', 16), ('Apple', 13), ('The', 13)],
#  [('I', 79), ('Nelson', 28), ('Mix', 19), ('say', 19), ('Little', 17)],
#  [('A', 2), ('The', 2), ('back', 2), ('Spelling', 1), ('single', 1)],
#  [('Android', 23), ('Google', 19), ('10', 14), ('phone', 12), ('update', 11)],
#  [('Huawei', 19), ('Google', 10), ('US', 9), ('Android', 7), ('company', 7)],
#  [('Hawke', 13), ('000', 9), ('I', 8), ('A', 7), ('sell', 6)],
#  [('S10', 41), ('5G', 40), ('Samsung', 26), ('phone', 25), ('The', 25)],
#  [('earbuds', 18), ('PowerBeats', 17), ('Pro', 17), ('case', 13), ('ear', 12)],
#  [('company', 9), ('dividends', 8), ('year', 7), ('global', 7), ('payouts', 6)],
#  [('phone', 13), ('computer', 11), ('The', 8), ('data', 7), ('federal', 5)],
#  [('Honor', 28), ('20', 26), ('The', 24), ('Pro', 22), ('camera', 16)],
#  [('earbuds', 19), ('noise', 16), ('The', 14), ('sound', 12), ('wireless', 10)],
#  [('regulation', 12),
#   ('Australia', 11),
#   ('people', 8),
#   ('red', 7),
#   ('tape', 7)],
#  [('Note', 15), ('Samsung', 11), ('10', 11), ('model', 8), ('Galaxy', 6)],
#  [('team', 7), ('Morris', 5), ('US', 5), ('Olympic', 4), ('sport', 4)],
#  [('I', 7), ('The', 3), ('quite', 3), ('something', 3), ('experience', 2)],
#  [('company', 15), ('market', 8), ('large', 6), ('small', 5), ('town', 3)],
#  [('5G', 37), ('network', 24), ('4G', 19), ('Australia', 17), ('higher', 13)],
#  [('Apple', 19), ('Siri', 17), ('record', 15), ('say', 10), ('The', 10)],
#  [('screen', 18), ('draw', 12), ('The', 12), ('tablets', 11), ('use', 9)],
#  [('phone', 42), ('The', 40), ('camera', 32), ('screen', 31), ('best', 25)],
#  [('screen', 19), ('The', 14), ('BlackBerry', 13), ('10', 10), ('I', 9)],
#  [('OnePlus', 31), ('7', 25), ('Pro', 17), ('The', 15), ('phone', 14)],
#  [('The', 26), ('Honor', 24), ('camera', 19), ('phone', 19), ('20', 18)],
#  [('Frames', 24), ('The', 19), ('Bose', 14), ('lenses', 12), ('earbuds', 10)],
#  [('USB', 24), ('charge', 16), ('C', 16), ('phone', 11), ('need', 11)],
#  [('service', 16), ('UK', 8), ('broadcasters', 8), ('content', 8), ('show', 7)],
#  [('Google', 20), ('phone', 16), ('The', 10), ('use', 10), ('smartphone', 8)],
#  [('iOS', 9), ('13', 7), ('iPadOS', 7), ('beta', 6), ('update', 6)],
#  [('Apple', 8), ('recall', 5), ('MacBook', 5), ('Pro', 5), ('The', 5)],
#  [('data', 15), ('99', 15), ('year', 12), ('month', 12), ('service', 11)],
#  [('Chinese', 20),
#   ('say', 13),
#   ('Huawei', 10),
#   ('Americans', 10),
#   ('concern', 10)],
#  [('S10e', 17), ('S10', 16), ('The', 16), ('phone', 11), ('camera', 10)],
#  [('excite', 3), ('new', 3), ('game', 2), ('deliver', 2), ('release', 2)],
#  [('cable', 45), ('charge', 23), ('USB', 18), ('phone', 16), ('need', 15)],
#  [('S10', 26), ('Galaxy', 21), ('The', 19), ('screen', 16), ('phone', 14)],
#  [('I', 4), ('week', 2), ('Guardian', 2), ('Money', 2), ('5G', 2)],
#  [('I', 71), ('Brooker', 33), ('say', 32), ('like', 24), ('show', 19)],
#  [('The', 25), ('OnePlus', 25), ('phone', 24), ('Pro', 20), ('7', 17)],
#  [('5G', 30), ('network', 16), ('4G', 12), ('phone', 8), ('I', 6)],
#  [('Huawei', 19), ('US', 11), ('say', 10), ('company', 9), ('The', 7)],
#  [('Honor', 17), ('camera', 15), ('20', 13), ('Huawei', 10), ('phone', 10)],
#  [('Pixel', 33), ('3a', 24), ('XL', 20), ('phone', 18), ('The', 16)],
#  [('SSD', 21), ('laptop', 10), ('drive', 10), ('one', 9), ('use', 9)],
#  [('OnePlus', 15), ('phone', 11), ('Pro', 10), ('7', 10), ('The', 9)],
#  [('Pixel', 32), ('3a', 20), ('The', 16), ('Google', 13), ('phone', 12)],
#  [('Apple', 19), ('China', 12), ('US', 11), ('cost', 7), ('could', 6)],
#  [('The', 18), ('earbuds', 16), ('They', 15), ('sound', 12), ('good', 10)],
#  [('Facebook', 34),
#   ('None', 26),
#   ('users', 22),
#   ('Zuckerberg', 13),
#   ('privacy', 12)],
#  [('Google', 13), ('Pixel', 11), ('3a', 7), ('phone', 6), ('mid', 6)],
#  [('I', 9), ('Currys', 5), ('letter', 4), ('It', 3), ('try', 3)],
#  [('Black', 3), ('Mirror', 3), ('question', 3), ('modern', 2), ('show', 2)],
#  [('Spotify', 14), ('music', 11), ('stream', 8), ('year', 8), ('service', 6)],
#  [('say', 11), ('form', 8), ('case', 8), ('police', 7), ('consent', 7)],
#  [('say', 9), ('5G', 8), ('Turnbull', 7), ('network', 7), ('Australia', 7)],
#  [('Turkish', 11), ('The', 8), ('Gallipoli', 7), ('New', 7), ('service', 7)],
#  [('Pro', 23), ('The', 20), ('P30', 17), ('Huawei', 15), ('camera', 12)],
#  [('phone', 10), ('Samsung', 7), ('company', 5), ('need', 4), ('fold', 4)],
#  [('None', 7), ('say', 7), ('US', 6), ('The', 6), ('Trump', 5)],
#  [('The', 18), ('say', 12), ('people', 7), ('kill', 7), ('Sri', 6)],
#  [('Huawei', 19), ('US', 11), ('company', 10), ('The', 8), ('yuan', 8)],
#  [('Samsung', 10), ('Galaxy', 10), ('screen', 8), ('Fold', 7), ('phone', 7)],
#  [('tomorrow', 4), ('know', 4), ('But', 3), ('today', 2), ('election', 2)],
#  [('I', 48), ('phone', 8), ('The', 8), ('get', 6), ('It', 6)],
#  [('5G', 17), ('South', 12), ('US', 10), ('service', 10), ('Korea', 9)],
#  [('lira', 4), ('Turkish', 3), ('say', 3), ('bond', 2), ('stock', 2)],
#  [('FOMC', 5), ('investors', 4), ('US', 4), ('interest', 4), ('rat', 4)],
#  [('zoom', 10), ('camera', 10), ('Huawei', 9), ('Pro', 8), ('smartphone', 8)],
#  [('Samsung', 9), ('chip', 8), ('Apple', 6), ('sales', 6), ('profit', 5)],
#  [('TV', 23), ('also', 10), ('screen', 10), ('set', 9), ('4k', 9)],
#  [('pop', 17), ('South', 15), ('K', 14), ('The', 12), ('say', 12)],
#  [('screen', 24), ('Galaxy', 23), ('S10', 23), ('Samsung', 17), ('The', 16)],
#  [('The', 11), ('network', 9), ('5G', 8), ('Huawei', 8), ('mobile', 6)],
#  [('phone', 17), ('screen', 16), ('one', 8), ('like', 7), ('It', 7)],
#  [('Mi', 17), ('3', 17), ('Mix', 16), ('good', 13), ('The', 13)],
#  [('screen', 12), ('Mate', 11), ('X', 10), ('Huawei', 9), ('The', 7)],
#  [('phone', 10), ('Galaxy', 9), ('Samsung', 6), ('Fold', 6), ('one', 6)],
#  [('Samsung', 9),
#   ('smartphone', 9),
#   ('phone', 8),
#   ('screen', 8),
#   ('Galaxy', 7)],
#  [('S10', 16), ('Samsung', 12), ('Galaxy', 11), ('The', 8), ('5G', 8)],
#  [('shop', 11), ('like', 10), ('Seoul', 9), ('Euljiro', 8), ('It', 8)],
#  [('I', 8), ('fridges', 5), ('Samsung', 4), ('way', 3), ('people', 3)],
#  [('The', 13), ('best', 12), ('phone', 11), ('iPhone', 10), ('camera', 9)],
#  [('Love', 8), ('computer', 4), ('US', 4), ('court', 4), ('hear', 4)],
#  [('Koreans', 21),
#   ('North', 20),
#   ('South', 18),
#   ('Korean', 16),
#   ('community', 8)],
#  [('The', 25), ('View20', 18), ('Honor', 15), ('phone', 15), ('camera', 12)],
#  [('colour', 22), ('print', 11), ('use', 11), ('image', 10), ('RGB', 10)],
#  [('batteries', 30),
#   ('battery', 28),
#   ('energy', 20),
#   ('power', 19),
#   ('say', 14)],
#  [('Guardian', 2), ('Money', 2), ('inch', 2), ('4K', 2), ('HDR', 2)],
#  [('The', 11), ('use', 10), ('TV', 7), ('CES', 6), ('year', 5)],
#  [('Apple', 13), ('service', 9), ('iTunes', 6), ('company', 6), ('The', 6)],
#  [('Apple', 16), ('The', 12), ('service', 10), ('price', 9), ('market', 8)],
#  [('The', 13), ('China', 12), ('iPhone', 10), ('Apple', 9), ('US', 8)],
#  [('company', 11), ('Sonos', 10), ('make', 10), ('hardware', 10), ('But', 9)],
#  [('The', 21), ('2019', 18), ('year', 15), ('first', 13), ('also', 11)],
#  [('China', 9), ('Huawei', 8), ('trade', 8), ('Chinese', 7), ('deal', 6)],
#  [('phone', 20), ('screen', 11), ('2019', 7), ('fold', 6), ('top', 5)],
#  [('Facebook', 27),
#   ('Sandberg', 23),
#   ('company', 15),
#   ('Zuckerberg', 14),
#   ('The', 13)],
#  [('Channel', 10), ('4', 9), ('deal', 5), ('Publicis', 5), ('clients', 4)],
#  [('Apple', 8), ('battery', 7), ('iPhone', 6), ('iPhones', 4), ('warranty', 4)],
#  [('I', 144), ('sleep', 87), ('night', 30), ('get', 28), ('The', 24)],
#  [('purpose', 12), ('find', 6), ('course', 5), ('us', 5), ('Mark', 5)],
#  [('inquiry', 36), ('The', 32), ('Grenfell', 20), ('fire', 20), ('I', 19)],
#  [('feature', 7), ('The', 5), ('say', 4), ('music', 4), ('high', 4)],
#  [('Huawei', 15),
#   ('network', 13),
#   ('The', 8),
#   ('equipment', 8),
#   ('sanction', 7)],
#  [('Huawei', 21), ('Ren', 15), ('company', 15), ('national', 8), ('The', 7)],
#  [('fall', 4), ('market', 4), ('company', 3), ('sell', 3), ('US', 3)],
#  [('Huawei', 15),
#   ('US', 11),
#   ('company', 10),
#   ('network', 9),
#   ('equipment', 9)],
#  [('Huawei', 17), ('US', 12), ('company', 10), ('China', 8), ('network', 8)],
#  [('What', 21), ('Where', 16), ('Cyber', 14), ('happen', 14), ('offer', 13)],
#  [('The', 22), ('track', 19), ('discount', 13), ('cod', 13), ('vouchers', 12)],
#  [('discount', 12), ('cod', 12), ('vouchers', 11), ('Buy', 10), ('check', 10)],
#  [('The', 18), ('best', 13), ('camera', 11), ('phone', 10), ('screen', 10)],
#  [('say', 14), ('mop', 13), ('use', 10), ('suspect', 8), ('police', 7)],
#  [('discount', 12),
#   ('cod', 12),
#   ('vouchers', 11),
#   ('check', 11),
#   ('screen', 10)],
#  [('What', 73), ('Where', 39), ('happen', 35), ('The', 33), ('Black', 29)],
#  [('vacuum', 18),
#   ('cleaner', 12),
#   ('discount', 10),
#   ('cod', 10),
#   ('vouchers', 9)],
#  [('I', 37), ('write', 19), ('Dyer', 11), ('book', 10), ('The', 9)],
#  [('Trump', 9), ('None', 8), ('The', 6), ('Russia', 5), ('make', 5)],
#  [('Samsung', 25), ('I', 19), ('workers', 12), ('company', 12), ('make', 10)],
#  [('The', 11), ('Trump', 8), ('say', 8), ('I', 6), ('today', 5)],
#  [('Argent', 15), ('Cross', 13), ('build', 13), ('King', 12), ('London', 12)],
#  [('OnePlus', 22), ('The', 20), ('phone', 15), ('6T', 13), ('camera', 9)],
#  [('iPhone', 51), ('XS', 25), ('The', 22), ('XR', 21), ('make', 13)],
#  [('OnePlus', 11), ('The', 9), ('phone', 7), ('6', 6), ('new', 5)],
#  [('The', 24), ('Huawei', 20), ('phone', 16), ('Pro', 16), ('It', 15)],
#  [('bed', 18), ('1', 12), ('The', 10), ('sq', 9), ('live', 8)],
#  [('Apple', 7), ('Samsung', 7), ('update', 7), ('software', 6), ('phone', 5)],
#  [('Pixel', 31), ('3', 28), ('Google', 21), ('The', 21), ('XL', 20)],
#  [('iPhone', 32), ('XR', 29), ('The', 18), ('XS', 17), ('I', 12)],
#  [('AI', 23), ('music', 22), ('The', 11), ('machine', 9), ('like', 9)],
#  [('screen', 28), ('monitor', 22), ('The', 10), ('PC', 9), ('HD', 9)],
#  [('The', 23), ('Pixel', 23), ('3', 20), ('Google', 14), ('use', 14)],
#  [('Huawei', 14), ('new', 11), ('Mate', 11), ('Pro', 11), ('20', 10)],
#  [('Google', 24), ('Pixel', 23), ('The', 19), ('3', 10), ('also', 10)],
#  [('say', 15), ('Opera', 14), ('House', 14), ('I', 12), ('decision', 9)],
#  [('Lee', 10), ('president', 6), ('The', 5), ('South', 5), ('court', 5)],
#  [('iPhone', 31), ('XS', 21), ('The', 15), ('screen', 10), ('make', 10)],
#  [('brand', 14), ('top', 11), ('Amazon', 9), ('100', 7), ('Interbrand', 6)],
#  [('Optane', 24), ('SSD', 18), ('drive', 17), ('chip', 15), ('I', 14)],
#  [('iPhone', 31), ('The', 20), ('XS', 18), ('screen', 17), ('Max', 15)],
#  [('legislation', 7),
#   ('could', 7),
#   ('access', 6),
#   ('government', 5),
#   ('devices', 5)],
#  [('I', 17), ('screen', 14), ('use', 11), ('daughter', 10), ('Windows', 10)],
#  [('doorbell', 20), ('Nest', 19), ('Hello', 19), ('The', 18), ('video', 14)],
#  [('game', 19), ('say', 12), ('make', 11), ('use', 10), ('monitor', 9)],
#  [('iPhone', 27), ('XS', 23), ('phone', 20), ('The', 16), ('Max', 14)],
#  [('travel', 8), ('TripAdvisor', 6), ('new', 4), ('review', 4), ('website', 3)],
#  [('North', 15), ('Moon', 14), ('Korean', 13), ('Kim', 13), ('Korea', 12)],
#  [('Honor', 26), ('phone', 17), ('The', 16), ('Play', 14), ('10', 12)],
#  [('women', 26), ('I', 14), ('City', 13), ('Joy', 12), ('say', 11)],
#  [('Turkey', 17), ('We', 7), ('The', 7), ('US', 6), ('anti', 6)],
#  [('laptops', 13), ('good', 10), ('memory', 8), ('PassMark', 8), ('cheap', 8)],
#  [('algorithms', 39),
#   ('I', 25),
#   ('The', 22),
#   ('algorithmic', 21),
#   ('make', 20)],
#  [('Note', 22), ('The', 20), ('9', 18), ('phone', 15), ('screen', 14)],
#  [('American', 15), ('company', 12), ('could', 10), ('You', 8), ('It', 8)],
#  [('Turkey', 6), ('US', 5), ('market', 4), ('Turkish', 3), ('also', 3)],
#  [('Facebook', 14), ('India', 14), ('right', 8), ('The', 8), ('show', 7)],
#  [('work', 26), ('hours', 18), ('people', 11), ('law', 10), ('Kim', 8)],
#  [('Android', 11), ('apps', 10), ('malware', 7), ('Store', 7), ('security', 7)],
#  [('Note', 16), ('Samsung', 14), ('The', 11), ('Galaxy', 10), ('phone', 10)],
#  [('Android', 20), ('Google', 18), ('apps', 13), ('button', 12), ('update', 9)],
#  [('game', 16), ('Android', 13), ('store', 10), ('Epic', 8), ('market', 8)],
#  [('I', 39), ('get', 16), ('chicken', 16), ('go', 16), ('say', 15)],
#  [('iPod', 5), ('Apple', 5), ('Windows', 3), ('The', 3), ('Mac', 2)],
#  [('Bank', 5), ('UK', 4), ('PMI', 3), ('months', 3), ('growth', 3)],
#  [('Huawei', 17), ('market', 12), ('say', 10), ('Apple', 7), ('year', 7)],
#  [('Mourinho', 11), ('United', 9), ('I', 7), ('think', 5), ('If', 4)],
#  [('Weirdly', 1),
#   ('indelible', 1),
#   ('memory', 1),
#   ('lacy', 1),
#   ('trousers', 1)],
#  [('deal', 9), ('sim', 9), ('phone', 8), ('best', 6), ('month', 6)],
#  [('A', 26), ('Build', 24), ('Bear', 24), ('bear', 23), ('I', 15)],
#  [('Glass', 10), ('Gorilla', 9), ('drop', 9), ('Corning', 6), ('say', 6)]]
