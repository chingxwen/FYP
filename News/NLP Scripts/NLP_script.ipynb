# %%
#Importing of all libraries

import pandas as pd
import numpy as np
import re
import nltk
from pprint import pprint
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk import FreqDist
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn

# %%
#Reading of .csv file

df = pd.read_csv("TheGuardianDataFinal.csv")
content = df['Text']
assert content.isnull().count() == len(content)

# %%
#Conversion Of Date Formatting 
# df = pd.read_csv("TheGuardianDataFinal.csv")

# date = pd.to_datetime(df['Date'])
# print(type(date[0]))

df["Date"] = pd.to_datetime(df["Date"]).dt.strftime('%Y-%m-%d')
df["Date"] = pd.to_datetime(df["Date"], format = "%Y/%m/%d")

print(df)
# for i in range(len(df)):
#     print(str(df["Date"][i].year) + "/" + str(df["Date"][i].month))
# Out:
#             Section                                              Title  \
# 0        Technology  Google Pixel 4 review: a good phone ruined by ...
# 1            Cities  Hex in the city: which terrifying town hits Ha...
# 2        Technology  Labour calls for halt to Google's acquisition ...
# 3        Technology  Google Pixel 4 XL review: not quite ready for ...
# 4        Technology  AirPods Pro: Apple launches noise-cancelling e...
# ..              ...                                                ...
# 196           Money  Why spend £1,000 on a smartphone when you coul...
# 197  Life and style  Fluffed it! The truth about Build-A-Bear's day...
# 198      Technology  Cracking news: improved smartphone glass twice...
# 199         UK news  Man who called for attack on Prince George jai...
# 200      Technology  Samsung phones sent photos to random contacts,...
#
#                                                    URL       Date  \
# 0    https://www.theguardian.com/technology/2019/oc... 2019-10-31
# 1    https://www.theguardian.com/cities/2019/oct/31... 2019-10-31
# 2    https://www.theguardian.com/technology/2019/oc... 2019-10-29
# 3    https://www.theguardian.com/technology/2019/oc... 2019-10-29
# 4    https://www.theguardian.com/technology/2019/oc... 2019-10-28
# ..                                                 ...        ...
# 196  https://www.theguardian.com/money/2018/jul/28/... 2018-07-28
# 197  https://www.theguardian.com/lifeandstyle/2018/... 2018-07-23
# 198  https://www.theguardian.com/technology/2018/ju... 2018-07-19
# 199  https://www.theguardian.com/uk-news/2018/jul/1... 2018-07-13
# 200  https://www.theguardian.com/technology/2018/ju... 2018-07-03
#
#                                                   Text  Sentiment
# 0    Brilliant camera, slick features and small siz...     11.375
# 1    On a dark, dark night, in a dark, dark town, o...      3.875
# 2    Labour has written to the competition regulato...      0.250
# 3    Google’s latest Pixel 4 XL smartphone is its b...     18.000
# 4    Apple has launched a new set of its popular tr...      1.500
# ..                                                 ...        ...
# 196  How do you find the best-value smartphone deal...     12.875
# 197  Thursday 12 July should have been a red-letter...      8.250
# 198  Glass-maker Corning has unveiled a new version...      2.125
# 199  An Islamic State supporter who called for an a...      2.250
# 200  Samsung is investigating reports that its defa...      2.125
#
# [201 rows x 6 columns]

# %%
#Word count of each article before removal of stop words

count = [len(content[i]) for i in range(len(content))]
# data['Count Before'] = count
print(count)
# Out:
# [8625, 9258, 2648, 13182, 1899, 7842, 11971, 8772, 5565, 9165, 3198, 2426, 8657, 9182, 12405, 11333, 25352, 7375, 12506, 12845, 3788, 23099, 7351, 7728, 4338, 10207, 11862, 10192, 10773, 5184, 13471, 1028, 6678, 3873, 4470, 10071, 7516, 2964, 3423, 6897, 7321, 6019, 2920, 1614, 1004, 3680, 8942, 6232, 8002, 16608, 7648, 7448, 8712, 8582, 7375, 4079, 8308, 2319, 1882, 7517, 5742, 6646, 638, 7839, 7870, 624, 20102, 10232, 5633, 4097, 3218, 7325, 6543, 3348, 7306, 4280, 9235, 9615, 3016, 1582, 1119, 4117, 6499, 4670, 3604, 10180, 3544, 5768, 9769, 6767, 3352, 828, 5165, 4172, 1195, 1460, 3413, 2723, 7797, 9302, 12164, 5348, 5273, 7782, 3729, 3376, 3347, 4418, 7799, 1798, 6489, 2310, 3982, 9678, 7603, 11839, 720, 5915, 3332, 7701, 5279, 9187, 13448, 5879, 5599, 8929, 2212, 1950, 26567, 3209, 21282, 5188, 4600, 8239, 1318, 4899, 4707, 4045, 7950, 6905, 5694, 4248, 6604, 13625, 5775, 6385, 6005, 7459, 9072, 16628, 8515, 7515, 2805, 11277, 4662, 3423, 9310, 6415, 9101, 7395, 10163, 3749, 6962, 6004, 2551, 7063, 3189, 7154, 9514, 3657, 8356, 9881, 12059, 7653, 2324, 5158, 7010, 8721, 6863, 7818, 31668, 8641, 8062, 1877, 3927, 5917, 3298, 4480, 6634, 4576, 10661, 1337, 2040, 3964, 5096, 270, 4200, 14125, 1955, 5755, 2008]

# %%
#Tokenization and removal of punctuations

data = []
tokenizer = RegexpTokenizer(r'\w+')

content = content.apply(lambda x: tokenizer.tokenize(x))
content.head(20)
# Out:
# 0     [Brilliant, camera, slick, features, and, smal...
# 1     [On, a, dark, dark, night, in, a, dark, dark, ...
# 2     [Labour, has, written, to, the, competition, r...
# 3     [Google, s, latest, Pixel, 4, XL, smartphone, ...
# 4     [Apple, has, launched, a, new, set, of, its, p...
# 5     [I, use, a, 9, 7in, Samsung, Galaxy, Tab, S2, ...
# 6     [Always, on, screen, completes, the, package, ...
# 7     [Still, an, absolute, beast, in, every, way, e...
# 8     [First, it, was, books, then, it, was, the, Ki...
# 9     [The, OnePlus, 7T, takes, the, best, bits, of,...
# 10    [In, a, country, where, the, biggest, companie...
# 11    [I, think, you, should, at, least, make, an, e...
# 12    [Plastic, packaging, has, many, amazing, quali...
# 13    [A, great, camera, screen, and, performance, c...
# 14    [After, a, period, of, stagnation, the, A, Lea...
# 15    [Apple, s, iPhone, has, gone, pro, for, its, 1...
# 16    [Gordon, s, wine, bar, is, reached, through, a...
# 17    [Microsoft, has, launched, the, Surface, Pro, ...
# 18    [Apple, s, lower, cost, model, has, latest, ch...
# 19    [In, the, autumn, of, 1997, I, was, a, fresher...
# Name: Text, dtype: object

# %%
#Removal of Stop Words

set(stopwords.words('english'))

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

content = content.apply(lambda x: remove_stopwords(x))

# %%
#Lemmatization (OLD VERSION)
# lemmatizer = WordNetLemmatizer()

# def word_lemmatizer(text):`
#     lem_text = [lemmatizer.lemmatize(i, pos="v") for i in text]
#     return lem_text

# content = content.apply(lambda x: word_lemmatizer(x))

# content_freq = content

# %%
#Lemmatization

lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i, pos="a") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="s") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="v") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="r") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="n") for i in text]
    return lem_text

content = content.apply(lambda x: word_lemmatizer(x))
print(content[0])
content_freq = content
# Out:
# ['Brilliant', 'camera', 'slick', 'feature', 'small', 'size', 'mean', 'nothing', 'phone', 'even', 'last', 'day', 'Google', 'one', 'handful', 'smartphone', 'manufacturer', 'still', 'making', 'flagship', 'phone', 'ginormous', 'beast', 'new', 'Pixel', '4', 'cheapest', 'significantly', 'undercut', 'competition', 'Priced', '669', 'Pixel', '4', '70', 'cheaper', 'last', 'year', 'Pixel', '3', '60', 'cheaper', 'Apple', 'iPhone', '11', 'It', 'also', 'cheaper', 'bigger', 'sibling', '829', 'Pixel', '4', 'XL', 'The', 'concern', 'corner', 'cut', 'matter', 'The', '5', '7in', 'FHD', 'OLED', 'display', '90Hz', 'refresh', 'rate', 'larger', '6', '3in', 'version', 'Pixel', '4', 'XL', 'It', 'look', 'similar', 'good', 'viewing', 'angle', 'inky', 'black', 'bold', 'colour', 'smooth', 'experience', 'thanks', 'high', 'refresh', 'rate', 'But', 'brightest', 'screen', 'available', 'make', 'fine', 'thing', 'quite', 'bright', 'I', 'would', 'like', 'direct', 'sunlight', 'There', 'large', 'forehead', 'containing', 'sensor', 'Google', 'new', 'Face', 'Unlock', 'Motion', 'Sense', 'system', 'The', 'side', 'aluminium', 'black', 'textured', 'coating', 'glass', 'back', 'frosted', 'texture', 'similar', 'super', 'smooth', 'skin', 'Buy', 'white', 'orange', 'version', 'contrasting', 'colour', 'make', 'Pixel', '4', 'stand', 'Combined', 'slender', 'proportion', '68', '8mm', 'wide', '162g', 'Pixel', '4', 'one', 'smallest', 'lightest', 'easiest', 'top', 'end', 'smartphones', 'hold', 'use', 'It', 'joy', 'able', 'easily', 'use', 'smartphone', 'one', 'handed', 'For', 'comparison', 'Apple', '1', '049', 'iPhone', '11', 'Pro', 'currently', 'best', 'smaller', 'phone', 'available', '71', '4mm', 'wide', '188g', '799', 'Samsung', 'Galaxy', 'S10', '70', '4mm', 'wide', '157g', 'The', 'Pixel', '4', '6GB', 'RAM', '64GB', 'storage', 'one', 'Qualcomm', 'Snapdragon', '855', 'Pixel', '4', 'XL', 'performs', 'identically', 'fast', 'fluid', 'quite', 'speedy', 'OnePlus', '7T', 'Battery', 'life', 'really', 'poor', 'The', 'Pixel', '4', 'last', '14', 'hour', 'charge', 'Remove', 'charger', '7am', 'dead', '9pm', 'Turning', 'bell', 'whistle', 'ambient', 'display', 'added', '40', 'minute', 'battery', 'life', 'Anything', '24', 'hour', 'simply', 'good', 'enough', 'particularly', 'given', 'I', 'play', 'game', 'anything', 'particularly', 'battery', 'draining', 'That', 'using', 'primary', 'device', '200', 'email', 'message', 'push', 'notification', 'two', 'hour', 'browsing', 'Chrome', 'four', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', '40', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', 'three', 'photo', 'For', 'comparison', 'similarly', 'sized', 'iPhone', '11', 'Pro', 'last', '32', 'hour', 'Pixel', '4', 'XL', 'last', '26', 'hour', 'similar', 'condition', 'majority', 'smartphones', '2019', 'last', 'least', '24', 'hour', 'heavy', 'usage', 'The', 'Pixel', '4', 'fast', 'charge', '18W', 'via', 'USB', 'C', 'Power', 'Delivery', 'charger', 'one', 'included', 'box', 'wirelessly', 'charge', '11W', 'A', 'full', 'charge', 'via', 'cable', 'took', '105', 'minute', 'hitting', '70', '45', 'minute', 'The', 'Pixel', '4', 'one', 'first', 'smartphones', 'ship', 'latest', 'version', 'Android', '10', 'complete', 'system', 'wide', 'dark', 'mode', 'full', 'theming', 'support', 'changing', 'colour', 'icon', 'shape', 'typeface', 'vastly', 'improved', 'gesture', 'navigation', 'At', 'least', 'three', 'year', 'software', 'update', 'phone', 'release', 'included', 'get', 'Android', 'version', 'update', 'device', 'The', 'Pixel', '4', 'also', 'new', 'device', 'natural', 'language', 'processing', 'impressive', 'larger', 'Pixel', '4', 'XL', 'Google', 'Assistant', 'much', 'faster', 'work', 'without', 'internet', 'connection', 'many', 'task', 'Google', 'voice', 'transcription', 'app', 'equally', 'excellent', 'Live', 'Caption', 'feature', 'The', 'new', 'Assistant', 'still', 'work', 'Google', 'commercial', 'G', 'Suite', 'account', 'though', 'bit', 'blunder', 'Google', 'say', 'still', 'working', 'fix', 'Motion', 'Sense', 'us', ...

# %%
#Word count of each article after removal of stop words

countaft = [len(content[i]) for i in range(len(content))]
print(countaft)
# Out:
# [944, 951, 241, 1399, 202, 834, 1237, 973, 558, 1007, 331, 255, 853, 1047, 1320, 1240, 2484, 802, 1348, 1366, 406, 2427, 710, 820, 468, 1057, 1288, 1063, 1156, 616, 1389, 112, 664, 383, 476, 1096, 754, 301, 317, 793, 766, 563, 320, 169, 96, 368, 861, 569, 876, 1827, 846, 809, 970, 879, 811, 393, 870, 253, 206, 801, 548, 709, 70, 835, 851, 67, 1956, 1132, 596, 424, 378, 824, 732, 367, 796, 455, 935, 995, 328, 171, 107, 432, 604, 441, 349, 1140, 345, 581, 1004, 723, 347, 78, 545, 449, 131, 148, 365, 298, 885, 919, 1288, 548, 556, 853, 407, 343, 345, 479, 792, 173, 686, 224, 394, 1034, 789, 1170, 82, 637, 341, 797, 579, 913, 1437, 580, 558, 892, 240, 205, 2776, 307, 1985, 545, 483, 807, 137, 494, 480, 426, 818, 731, 616, 428, 705, 1570, 591, 649, 628, 724, 904, 1585, 888, 806, 309, 1235, 550, 329, 1030, 705, 921, 799, 1094, 429, 762, 559, 260, 765, 329, 779, 1047, 343, 862, 960, 1240, 815, 230, 531, 779, 827, 664, 876, 3000, 937, 836, 199, 428, 641, 329, 486, 671, 458, 1089, 136, 220, 416, 502, 29, 443, 1447, 204, 585, 204]

# %%
#Part of Speech tagging

content_tag = [nltk.pos_tag(i) for i in content]
print(content_tag)
# Out:
# [[('Brilliant', 'NNP'), ('camera', 'NN'), ('slick', 'NN'), ('feature', 'NN'), ('small', 'JJ'), ('size', 'NN'), ('mean', 'JJ'), ('nothing', 'NN'), ('phone', 'NN'), ('even', 'RB'), ('last', 'JJ'), ('day', 'NN'), ('Google', 'NNP'), ('one', 'CD'), ('handful', 'NN'), ('smartphone', 'NN'), ('manufacturer', 'NN'), ('still', 'RB'), ('making', 'VBG'), ('flagship', 'NN'), ('phone', 'NN'), ('ginormous', 'JJ'), ('beast', 'VBD'), ('new', 'JJ'), ('Pixel', 'NNP'), ('4', 'CD'), ('cheapest', 'JJS'), ('significantly', 'RB'), ('undercut', 'JJ'), ('competition', 'NN'), ('Priced', 'VBD'), ('669', 'CD'), ('Pixel', 'NNP'), ('4', 'CD'), ('70', 'CD'), ('cheaper', 'JJR'), ('last', 'JJ'), ('year', 'NN'), ('Pixel', 'VBD'), ('3', 'CD'), ('60', 'CD'), ('cheaper', 'JJR'), ('Apple', 'NNP'), ('iPhone', 'NN'), ('11', 'CD'), ('It', 'PRP'), ('also', 'RB'), ('cheaper', 'VBZ'), ('bigger', 'JJR'), ('sibling', 'VBG'), ('829', 'CD'), ('Pixel', 'NNP'), ('4', 'CD'), ('XL', 'VBD'), ('The', 'DT'), ('concern', 'NN'), ('corner', 'NN'), ('cut', 'NN'), ('matter', 'NN'), ('The', 'DT'), ('5', 'CD'), ('7in', 'CD'), ('FHD', 'NNP'), ('OLED', 'NNP'), ('display', 'VBD'), ('90Hz', 'CD'), ('refresh', 'JJ'), ('rate', 'NN'), ('larger', 'JJR'), ('6', 'CD'), ('3in', 'CD'), ('version', 'NN'), ('Pixel', 'NNP'), ('4', 'CD'), ('XL', 'NNP'), ('It', 'PRP'), ('look', 'VBD'), ('similar', 'JJ'), ('good', 'JJ'), ('viewing', 'NN'), ('angle', 'NN'), ('inky', 'JJ'), ('black', 'JJ'), ('bold', 'JJ'), ('colour', 'NN'), ('smooth', 'JJ'), ('experience', 'NN'), ('thanks', 'NNS'), ('high', 'JJ'), ('refresh', 'JJ'), ('rate', 'NN'), ('But', 'CC'), ('brightest', 'JJS'), ('screen', 'NN'), ('available', 'JJ'), ('make', 'VBP'), ('fine', 'JJ'), ('thing', 'NN'), ('quite', 'RB'), ('bright', 'JJ'), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('direct', 'JJ'), ('sunlight', 'NN'), ('There', 'EX'), ('large', 'JJ'), ('forehead', 'NN'), ('containing', 'VBG'), ('sensor', 'NN'), ('Google', 'NNP'), ('new', 'JJ'), ('Face', 'NNP'), ('Unlock', 'NNP'), ('Motion', 'NNP'), ('Sense', 'NNP'), ('system', 'NN'), ('The', 'DT'), ('side', 'NN'), ('aluminium', 'NN'), ('black', 'JJ'), ('textured', 'VBD'), ('coating', 'VBG'), ('glass', 'NN'), ('back', 'RB'), ('frosted', 'VBN'), ('texture', 'NN'), ('similar', 'JJ'), ('super', 'JJ'), ('smooth', 'NN'), ('skin', 'FW'), ('Buy', 'NNP'), ('white', 'JJ'), ('orange', 'NN'), ('version', 'NN'), ('contrasting', 'VBG'), ('colour', 'NNS'), ('make', 'VBP'), ('Pixel', 'JJ'), ('4', 'CD'), ('stand', 'NN'), ('Combined', 'VBN'), ('slender', 'JJR'), ('proportion', 'NN'), ('68', 'CD'), ('8mm', 'CD'), ('wide', 'JJ'), ('162g', 'CD'), ('Pixel', 'NNP'), ('4', 'CD'), ('one', 'CD'), ('smallest', 'NN'), ('lightest', 'JJS'), ('easiest', 'JJS'), ('top', 'JJ'), ('end', 'NN'), ('smartphones', 'NNS'), ('hold', 'VBP'), ('use', 'IN'), ('It', 'PRP'), ('joy', 'VBZ'), ('able', 'JJ'), ('easily', 'RB'), ('use', 'VBP'), ('smartphone', 'NN'), ('one', 'CD'), ('handed', 'VBN'), ('For', 'IN'), ('comparison', 'NN'), ('Apple', 'NNP'), ('1', 'CD'), ('049', 'CD'), ('iPhone', 'NN'), ('11', 'CD'), ('Pro', 'NNP'), ('currently', 'RB'), ('best', 'JJS'), ('smaller', 'JJR'), ('phone', 'NN'), ('available', 'JJ'), ('71', 'CD'), ('4mm', 'CD'), ('wide', 'JJ'), ('188g', 'CD'), ('799', 'CD'), ('Samsung', 'NNP'), ('Galaxy', 'NNP'), ('S10', 'NNP'), ('70', 'CD'), ('4mm', 'CD'), ('wide', 'JJ'), ('157g', 'CD'), ('The', 'DT'), ('Pixel', 'NNP'), ('4', 'CD'), ('6GB', 'CD'), ('RAM', 'NNP'), ('64GB', 'CD'), ('storage', 'NN'), ('one', 'CD'), ('Qualcomm', 'NNP'), ('Snapdragon', 'NNP'), ('855', 'CD'), ('Pixel', 'NNP'), ('4', 'CD'), ('XL', 'NN'), ('performs', 'NNS'), ('identically', 'RB'), ('fast', 'RB'), ('fluid', 'JJ'), ('quite', 'RB'), ('speedy', 'JJ'), ('OnePlus', 'CC'), ('7T', 'CD'), ('Battery', 'NNP'), ('life', 'NN'), ('really', 'RB'), ('poor', 'JJ'), ('The', 'DT'), ('Pixel', 'NNP'), ('4', 'CD'), ('last', 'JJ'), ('14', 'CD'), ('hour', 'NN'), ('charge', 'NN'), ('Remove', 'NNP'), ('charger', 'NN'), ('7am', 'CD'), ('dead', 'JJ'), ('9pm', 'CD'), ('Turning', 'VB ...

# %%
#Difference of word count before and after stop word removal in percentage, rounded off to 1dp

count_diff = []
for i in range(len(count)):
    count_diff.append(round(((count[i] - countaft[i])/count[i])*100, 1))
print(count_diff)
# Out:
# [89.1, 89.7, 90.9, 89.4, 89.4, 89.4, 89.7, 88.9, 90.0, 89.0, 89.6, 89.5, 90.1, 88.6, 89.4, 89.1, 90.2, 89.1, 89.2, 89.4, 89.3, 89.5, 90.3, 89.4, 89.2, 89.6, 89.1, 89.6, 89.3, 88.1, 89.7, 89.1, 90.1, 90.1, 89.4, 89.1, 90.0, 89.8, 90.7, 88.5, 89.5, 90.6, 89.0, 89.5, 90.4, 90.0, 90.4, 90.9, 89.1, 89.0, 88.9, 89.1, 88.9, 89.8, 89.0, 90.4, 89.5, 89.1, 89.1, 89.3, 90.5, 89.3, 89.0, 89.3, 89.2, 89.3, 90.3, 88.9, 89.4, 89.7, 88.3, 88.8, 88.8, 89.0, 89.1, 89.4, 89.9, 89.7, 89.1, 89.2, 90.4, 89.5, 90.7, 90.6, 90.3, 88.8, 90.3, 89.9, 89.7, 89.3, 89.6, 90.6, 89.4, 89.2, 89.0, 89.9, 89.3, 89.1, 88.6, 90.1, 89.4, 89.8, 89.5, 89.0, 89.1, 89.8, 89.7, 89.2, 89.8, 90.4, 89.4, 90.3, 90.1, 89.3, 89.6, 90.1, 88.6, 89.2, 89.8, 89.7, 89.0, 90.1, 89.3, 90.1, 90.0, 90.0, 89.2, 89.5, 89.6, 90.4, 90.7, 89.5, 89.5, 90.2, 89.6, 89.9, 89.8, 89.5, 89.7, 89.4, 89.2, 89.9, 89.3, 88.5, 89.8, 89.8, 89.5, 90.3, 90.0, 90.5, 89.6, 89.3, 89.0, 89.0, 88.2, 90.4, 88.9, 89.0, 89.9, 89.2, 89.2, 88.6, 89.1, 90.7, 89.8, 89.2, 89.7, 89.1, 89.0, 90.6, 89.7, 90.3, 89.7, 89.4, 90.1, 89.7, 88.9, 90.5, 90.3, 88.8, 90.5, 89.2, 89.6, 89.4, 89.1, 89.2, 90.0, 89.2, 89.9, 90.0, 89.8, 89.8, 89.2, 89.5, 90.1, 89.3, 89.5, 89.8, 89.6, 89.8, 89.8]

# %%
# Freq = [FreqDist(content_freq[i]).most_common(5) for i in range(len(content_freq))]

# %%
# df['Amount Cleansed (%)'] = count_diff
# df['Frequency'] = Freq

# df.to_csv('Output.csv')

# %%
# word_count = 0
# word_total_count = 0
# NNP_words = []
# for articles in content:
#     word_total_count += len(articles)
#     for words in articles:
#         if words[1] == 'NNP':
#             NNP_words.append(words[0].upper())
#             word_count += 1
# print(word_count/word_total_count * 100)
# NNP_Freq = FreqDist(NNP_words).most_common(50)
# pprint(NNP_Freq)

# %%
# feeling_words = []
# for articles in content:
#     word_total_count += len(articles)
#     for words in articles:
#         if words[1] == 'JJ':
#             feeling_words.append((words[0].upper()))

# Feeling_Freq = FreqDist(feeling_words).most_common(50)
# pprint(Feeling_Freq)

# %%
#Creating a main list of the the total articles with feeling words that contain the feeling words for the respective articles

total_fw = []

for articles in content_tag:
    article_fw = []
    for words in articles:
        
#Extracting adjective words only
        if words[1].startswith('JJ'):
            article_fw.append(words)
    total_fw.append(article_fw)

# %%
#Mapping of the tags to match the WordNet's POS 

def penn_to_wn(tag):
    """
    Convert between the PennTreebank tags to simple Wordnet tags
    """
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

for article in total_fw:
    for words in article:
        penn_to_wn(words[1])

# %%
#To get the sentiments based on the dictionary from WordNet that reads the phrases/sentence and returns a numerical value for the positive and -negative sentiments

def get_sentiment(word,tag):
    """ returns list of pos neg and objective score. But returns empty list if not present in senti wordnet. """

    wn_tag = penn_to_wn(tag)
    if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
        return []

    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    if not lemma:
        return []

    synsets = wn.synsets(word, pos=wn_tag)
    if not synsets:
        return []

    # Take the first sense, the most common
    synset = synsets[0]
    swn_synset = swn.senti_synset(synset.name())

    return [swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score()]

# %%
#Retrieving of sentiments for all the words in each article

net_senti = []
for article in total_fw:
    article_senti = []
    for words in article:
        
        senti = get_sentiment(words[0], words[1])
        if len(senti) > 0:
            print([words[0], (senti[0] - senti[1])])
            article_senti.append([words[0], (senti[0] - senti[1])])
    net_senti.append(article_senti)
# Out:
# ['small', -0.375]
# ['mean', 0.0]
# ['last', -0.25]
# ['new', 0.375]
# ['cheapest', -0.25]
# ['cheaper', -0.25]
# ['last', -0.25]
# ['cheaper', -0.25]
# ['bigger', 0.125]
# ['larger', 0.125]
# ['similar', 0.125]
# ['good', 0.75]
# ['inky', 0.0]
# ['black', -0.375]
# ['bold', 0.375]
# ['smooth', 0.25]
# ['high', -0.125]
# ['brightest', 0.125]
# ['available', 0.375]
# ['fine', 0.375]
# ['bright', 0.125]
# ['direct', -0.25]
# ['large', 0.125]
# ['new', 0.375]
# ['black', -0.375]
# ['similar', 0.125]
# ['super', 0.625]
# ['white', -0.25]
# ['slender', 0.5]
# ['wide', 0.125]
# ['lightest', -0.25]
# ['easiest', 0.375]
# ['top', 0.0]
# ['able', 0.125]
# ['best', 0.75]
# ['smaller', -0.125]
# ['available', 0.375]
# ['wide', 0.125]
# ['wide', 0.125]
# ['fluid', 0.0]
# ['speedy', 0.5]
# ['poor', -0.75]
# ['last', -0.25]
# ['dead', -0.75]
# ['ambient', 0.375]
# ['good', 0.75]
# ['primary', 0.375]
# ['last', -0.25]
# ['last', -0.25]
# ['similar', 0.125]
# ['last', -0.25]
# ['least', 0.0]
# ['heavy', 0.0]
# ['full', 0.0]
# ['first', 0.0]
# ['latest', 0.125]
# ['complete', 0.0]
# ['wide', 0.125]
# ['full', 0.0]
# ['least', 0.0]
# ['new', 0.375]
# ['natural', 0.25]
# ['impressive', 0.125]
# ['larger', 0.125]
# ['much', 0.0]
# ['faster', 0.0]
# ['many', 0.0]
# ['excellent', 1.0]
# ['new', 0.375]
# ['commercial', 0.0]
# ['ambient', 0.375]
# ['impressive', 0.125]
# ['new', 0.375]
# ['similar', 0.125]
# ['fine', 0.375]
# ['straight', -0.375]
# ['last', -0.25]
# ['biggest', 0.125]
# ['third', 0.0]
# ['tedious', -0.25]
# ['new', 0.375]
# ['small', -0.375]
# ['traditional', 0.0]
# ['best', 0.75]
# ['new', 0.375]
# ['dual', 0.0]
# ['different', 0.625]
# ['fantastic', 0.375]
# ['difficult', -0.75]
# ['ultra', 0.0]
# ['low', -0.25]
# ['wide', 0.125]
# ['good', 0.75]
# ['good', 0.75]
# ['second', 0.0]
# ['new', 0.375]
# ['free', 0.375]
# ['high', -0.125]
# ['full', 0.0]
# ['original', 0.0]
# ['previous', 0.0]
# ['smaller', -0.125]
# ['great', 0.0]
# ['poor', -0.75]
# ['good', 0.75]
# ['real', 0.0]
# ['many', 0.0]
# ['smaller', -0.125]
# ['good', 0.75]
# ['big', 0.125]
# ['novel', 0.25]
# ['natural', 0.25]
# ['next', 0.0]
# ['impressive', 0.125]
# ['third', 0.0]
# ['lower', -0.25]
# ['bigger', 0.125]
# ['best', 0.75]
# ['great', 0.0]
# ['terrible', -0.625]
# ['ready', 0.0]
# ['best', 0.75]
# ['small', -0.375]
# ['available', 0.375]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['dark', 0.0]
# ['dark', 0.0]
# ['dark', 0.0]
# ['dark', 0.0]
# ['odd', 0.125]
# ['dead', -0.75]
# ['annual', 0.0]
# ['small', -0.375]
# ['fancy', -0.375]
# ['massive', 0.0]
# ['double', 0.25]
# ['unnoticed', -0.125]
# ['best', 0.75]
# ['safe', 0.0]
# ['outside', 0.0]
# ['local', 0.0]
# ['strange', 0.25]
# ['organised', 0.0]
# ['new', 0.375]
# ['full', 0.0]
# ['open', -0.375]
# ['last', -0.25]
# ['least', 0.0]
# ['local', 0.0]
# ['new', 0.375]
# ['ancient', 0.0]
# ['19th', 0.0]
# ['religious', 0.0]
# ['secular', 0.0]
# ['average', 0.0]
# ['nationwide', 0.0]
# ['total', 0.0]
# ['spent', 0.125]
# ['sweet', 0.0]
# ['lucrative', 0.75]
# ['additional', 0.0]
# ['freakish', 0.625]
# ['mad', 0.125]
# ['general', 0.0]
# ['average', 0.0]
# ['second', 0.0]
# ['annual', 0.0]
# ['popular', 0.125]
# ['top', 0.0]
# ['biggest', 0.125]
# ['largest', 0.125]
# ['full', 0.0]
# ['artistic', 0.0]
# ['individual', 0.0]
# ['constant', 0.375]
# ['ancient', 0.0]
# ['west', 0.0]
# ['theatrical', 0.0]
# ['pet', 0.25]
# ['several', -0.5]
# ['evil', -0.875]
# ['popular', 0.125]
# ['favourite', 0.125]
# ['Meridian', 0.0]
# ['several', -0.5]
# ['top', 0.0]
# ['scary', -0.75]
# ['main', 0.375]
# ['autumnal', 0.0]
# ['huge', -0.125]
# ['recent', 0.0]
# ['spent', 0.125]
# ['outside', 0.0]
# ['related', 0.0]
# ['old', 0.375]
# ['historic', 0.0]
# ['keen', 0.125]
# ['beautiful', 0.75]
# ['Georgian', 0.0]
# ['aesthetic', 0.0]
# ['whole', 0.125]
# ['local', 0.0]
# ['haunted', 0.125]
# ['spooky', -0.375]
# ['hidden', -0.375]
# ['creepy', -0.875]
# ['old', 0.375]
# ['spooky', -0.375]
# ['quality', 0.625]
# ['best', 0.75]
# ['sweet', 0.0]
# ['resident', 0.0]
# ['lucky', 0.75]
# ['average', 0.0]
# ['capital', 0.0]
# ['western', 0.0]
# ['supernatural', -0.75]
# ['biggest', 0.125]
# ['massive', 0.0]
# ['annual', 0.0]
# ['recent', 0.0]
# ['extra', -0.5]
# ['happy', 0.875]
# ['cultural', 0.0]
# ['better', 0.875]
# ['polish', 0.0]
# ['best', 0.75]
# ['weekly', 0.0]
# ['least', 0.0]
# ['undisclosed', -0.25]
# ['digital', 0.125]
# ['full', 0.0]
# ['competitive', 0.0]
# ['unprecedented', 0.0]
# ['huge', -0.125]
# ['digital', 0.125]
# ['unaccountable', -0.375]
# ['unregulated', -0.625]
# ['u', 0.0]
# ['rigorous', 0.125]
# ['possible', 0.5]
# ['single', 0.0]
# ['physical', 0.0]
# ['wearable', 0.25]
# ['sensitive', 0.0]
# ['significant', 0.375]
# ['online', 0.0]
# ['digital', 0.125]
# ['minimum', 0.0]
# ['third', 0.0]
# ['latest', 0.125]
# ['old', 0.375]
# ['special', 0.0]
# ['direct', -0.25]
# ['black', -0.375]
# ['super', 0.625]
# ['white', -0.25]
# ['variant', -0.375]
# ['big', 0.125]
# ['certain', -0.375]
# ['smoother', 0.25]
# ['colourful', 0.125]
# ['good', 0.75]
# ['new', 0.375]
# ['new', 0.375]
# ['large', 0.125]
# ['big', 0.125]
# ['textured', 0.125]
# ['thick', 0.0]
# ['wide', 0.125]
# ['bottom', 0.0]
# ['colour', 0.625]
# ['least', 0.0]
# ['top', 0.0]
# ['used', 0.0]
# ['fast', 0.0]
# ['super', 0.625]
# ['Most', 0.0]
# ['happy', 0.875]
# ['likely', 0.5]
# ['responsive', 0.0]
# ['previous', 0.0]
# ['great', 0.0]
# ['last', -0.25]
# ['mean', 0.0]
# ['enough', 0.125]
# ['alive', 0.125]
# ['primary', 0.375]
# ['last', -0.25]
# ['last', -0.25]
# ['shy', 0.0]
# ['similar', 0.125]
# ['full', 0.0]
# ['first', 0.0]
# ['latest', 0.125]
# ['polish', 0.0]
# ['exclusive', -0.75]
# ['third', 0.0]
# ['wide', 0.125]
# ['full', 0.0]
# ['large', 0.125]
# ['easier', 0.375]
# ['least', 0.0]
# ['major', 0.625]
# ['big', 0.125]
# ['new', 0.375]
# ['natural', 0.25]
# ['similar', 0.125]
# ['impressive', 0.125]
# ['new', 0.375]
# ['great', 0.0]
# ['open', -0.375]
# ['faster', 0.0]
# ['impressive', 0.125]
# ['real', 0.0]
# ['new', 0.375]
# ['perfect', 0.5]
# ['sound', 0.75]
# ['impressive', 0.125]
# ['new', 0.375]
# ['commercial', 0.0]
# ['new', 0.375]
# ['ambient', 0.375]
# ['ready', 0.0]
# ['novel', 0.25]
# ['new', 0.375]
# ['new', 0.375]
# ['little', -0.375]
# ['fast', 0.0]
# ['simple', -0.25]
# ['open', -0.375]
# ['open', -0.375]
# ['third', 0.0]
# ['new', 0.375]
# ['Most', 0.0]
# ['mean', 0.0]
# ['strong', 0.5]
# ['fantastic', 0.375]
# ['last', -0.25]
# ['Fewer', 0.0]
# ['traditional', 0.0]
# ['least', 0.0]
# ['best', 0.75]
# ['different', 0.625]
# ['dual', 0.0]
# ['best', 0.75]
# ['available', 0.375]
# ['full', 0.0]
# ['difficult', -0.75]
# ['firm', 0.25]
# ['fine', 0.375]
# ['optical', 0.0]
# ['digital', 0.125]
# ['astrological', 0.0]
# ['last', -0.25]
# ['single', 0.0]
# ['good', 0.75]
# ['solid', 0.875]
# ['popular', 0.125]
# ['free', 0.375]
# ['full', 0.0]
# ['new', 0.375]
# ['smaller', -0.125]
# ['great', 0.0]
# ['incredible', 0.0]
# ['new', 0.375]
# ['natural', 0.25]
# ['next', 0.0]
# ['smartest', 0.5]
# ['good', 0.75]
# ['great', 0.0]
# ['bright', 0.125]
# ['top', 0.0]
# ['new', 0.375]
# ['sure', -0.25]
# ['biggest', 0.125]
# ['ready', 0.0]
# ['great', 0.0]
# ['real', 0.0]
# ['average', 0.0]
# ['live', 0.0]
# ['mean', 0.0]
# ['reasonable', 0.5]
# ['free', 0.375]
# ['best', 0.75]
# ['bigger', 0.125]
# ['magic', -0.25]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['new', 0.375]
# ['popular', 0.125]
# ['true', 0.125]
# ['traditional', 0.0]
# ['similar', 0.125]
# ['current', 0.0]
# ['complete', 0.0]
# ['white', -0.25]
# ['ultra', 0.0]
# ['compact', 0.0]
# ['plastic', 0.0]
# ['sound', 0.75]
# ['outside', 0.0]
# ['impossible', -0.75]
# ['noisy', 0.0]
# ['public', -0.125]
# ['mean', 0.0]
# ['crank', 0.25]
# ['sound', 0.75]
# ['due', 0.0]
# ['new', 0.375]
# ['unwanted', -0.25]
# ['lower', -0.25]
# ['individual', 0.0]
# ['continuous', 0.0]
# ['active', -0.125]
# ['additional', 0.0]
# ['free', 0.375]
# ['resistant', -0.125]
# ['true', 0.125]
# ['general', 0.0]
# ['digital', 0.125]
# ['basic', 0.0]
# ['new', 0.375]
# ['fit', 0.5]
# ['better', 0.875]
# ['exact', 0.0]
# ['major', 0.625]
# ['graphic', 0.0]
# ['low', -0.25]
# ['high', -0.125]
# ['high', -0.125]
# ['little', -0.375]
# ['stuck', 0.0]
# ['hard', -0.75]
# ['obvious', 0.5]
# ['digital', 0.125]
# ['cheap', -0.25]
# ['free', 0.375]
# ['easy', 0.375]
# ['x', 0.0]
# ['much', 0.0]
# ['bigger', 0.125]
# ['Second', 0.0]
# ['rapid', 0.0]
# ['chuffed', 0.125]
# ['fit', 0.5]
# ['high', -0.125]
# ['fit', 0.5]
# ['extra', -0.5]
# ['massive', 0.0]
# ['short', 0.0]
# ['new', 0.375]
# ['current', 0.0]
# ['last', -0.25]
# ['dead', -0.75]
# ['good', 0.75]
# ['double', 0.25]
# ['new', 0.375]
# ['future', -0.125]
# ['real', 0.0]
# ['ultra', 0.0]
# ['thin', 0.0]
# ['next', 0.0]
# ['good', 0.75]
# ['high', -0.125]
# ['cheap', -0.25]
# ['convenient', 0.375]
# ['enough', 0.125]
# ['built', 0.0]
# ['much', 0.0]
# ['possible', 0.5]
# ['usable', 0.0]
# ['mobile', 0.0]
# ['green', -0.125]
# ['alternative', 0.125]
# ['several', -0.5]
# ['external', 0.0]
# ['hard', -0.75]
# ['physical', 0.0]
# ['several', -0.5]
# ['alternative', 0.125]
# ['local', 0.0]
# ['available', 0.375]
# ['extra', -0.5]
# ['extra', -0.5]
# ['hard', -0.75]
# ['main', 0.375]
# ['much', 0.0]
# ['several', -0.5]
# ['larger', 0.125]
# ['smaller', -0.125]
# ['extra', -0.5]
# ['similar', 0.125]
# ['new', 0.375]
# ['new', 0.375]
# ['better', 0.875]
# ['second', 0.0]
# ['original', 0.0]
# ['extra', -0.5]
# ['significant', 0.375]
# ['significant', 0.375]
# ['better', 0.875]
# ['better', 0.875]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['top', 0.0]
# ['lukewarm', 0.0]
# ['wearable', 0.25]
# ['expected', -0.125]
# ['latest', 0.125]
# ['likely', 0.5]
# ['unfamiliar', -0.625]
# ['important', 0.875]
# ['alternative', 0.125]
# ['extraordinary', 0.625]
# ['last', -0.25]
# ['larger', 0.125]
# ['small', -0.375]
# ['important', 0.875]
# ['important', 0.875]
# ['telling', 0.0]
# ['essential', 0.125]
# ['permanent', -0.625]
# ['elaborate', 0.625]
# ['many', 0.0]
# ['comfortable', -0.75]
# ['best', 0.75]
# ['Swiss', 0.0]
# ['heavy', 0.0]
# ['larger', 0.125]
# ['resistant', -0.125]
# ['bright', 0.125]
# ['visible', 0.125]
# ['rectangular', 0.125]
# ['circular', 0.25]
# ['last', -0.25]
# ['little', -0.375]
# ['original', 0.0]
# ['better', 0.875]
# ['many', 0.0]
# ['wild', 0.0]
# ['particular', 0.0]
# ['little', -0.375]
# ['better', 0.875]
# ['different', 0.625]
# ['many', 0.0]
# ['sizeable', 0.0]
# ['perfect', 0.5]
# ['new', 0.375]
# ['numeral', 0.0]
# ['round', 0.25]
# ['analogue', 0.0]
# ['hard', -0.75]
# ['small', -0.375]
# ['picky', 0.0]
# ['high', -0.125]
# ['little', -0.375]
# ['Most', 0.0]
# ['third', 0.0]
# ['straight', -0.375]
# ['full', 0.0]
# ['digital', 0.125]
# ['great', 0.0]
# ['big', 0.125]
# ['great', 0.0]
# ['poor', -0.75]
# ['great', 0.0]
# ['complex', 0.0]
# ['great', 0.0]
# ['major', 0.625]
# ['best', 0.75]
# ['available', 0.375]
# ['huge', -0.125]
# ['usual', 0.125]
# ['enough', 0.125]
# ['good', 0.75]
# ['abnormal', -0.75]
# ['high', -0.125]
# ['second', 0.0]
# ['real', 0.0]
# ['irregular', -0.5]
# ['Other', -0.625]
# ['daily', 0.0]
# ['complete', 0.0]
# ['third', 0.0]
# ['menstrual', 0.0]
# ['environmental', 0.0]
# ['similar', 0.125]
# ['old', 0.375]
# ['hard', -0.75]
# ['simple', -0.25]
# ['hard', -0.75]
# ['public', -0.125]
# ['similar', 0.125]
# ['useful', 0.0]
# ['various', -0.25]
# ['different', 0.625]
# ['available', 0.375]
# ['ceramic', 0.0]
# ['second', 0.0]
# ['best', 0.75]
# ['best', 0.75]
# ['solid', 0.875]
# ['first', 0.0]
# ['last', -0.25]
# ['meaningful', 0.125]
# ['great', 0.0]
# ['close', 0.0]
# ['least', 0.0]
# ['circular', 0.25]
# ['typical', 0.125]
# ['best', 0.75]
# ['right', 0.0]
# ['better', 0.875]
# ['best', 0.75]
# ['small', -0.375]
# ['available', 0.375]
# ['true', 0.125]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['absolute', 0.5]
# ['minor', -0.375]
# ['best', 0.75]
# ['good', 0.75]
# ['good', 0.75]
# ['better', 0.875]
# ['bad', -0.625]
# ['mid', 0.0]
# ['faster', 0.0]
# ['difficult', -0.75]
# ['thin', 0.0]
# ['side', 0.0]
# ['slim', 0.5]
# ['attractive', 0.875]
# ['modern', -0.25]
# ['excellent', 1.0]
# ['big', 0.125]
# ['tall', 0.5]
# ['wide', 0.125]
# ['much', 0.0]
# ['manageable', 0.625]
# ['wide', 0.125]
# ['right', 0.0]
# ['smaller', -0.125]
# ['smaller', -0.125]
# ['wide', 0.125]
# ['palpable', 0.625]
# ['gorgeous', 0.75]
# ['new', 0.375]
# ['vertical', 0.0]
# ['wired', 0.0]
# ['newer', 0.375]
# ['graphic', 0.0]
# ['able', 0.125]
# ['fastest', 0.0]
# ['available', 0.375]
# ['different', 0.625]
# ['available', 0.375]
# ['available', 0.375]
# ['new', 0.375]
# ['black', -0.375]
# ['available', 0.375]
# ['limited', 0.0]
# ['solid', 0.875]
# ['longer', 0.0]
# ['last', -0.25]
# ['primary', 0.375]
# ['usual', 0.125]
# ['wireless', 0.0]
# ['internal', 0.0]
# ['full', 0.0]
# ['latest', 0.125]
# ['first', 0.0]
# ['standard', 0.0]
# ['colour', 0.625]
# ['full', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['previous', 0.0]
# ['biggest', 0.125]
# ['right', 0.0]
# ['right', 0.0]
# ['lower', -0.25]
# ['third', 0.0]
# ['vast', -0.125]
# ['large', 0.125]
# ['easier', 0.375]
# ['traditional', 0.0]
# ['available', 0.375]
# ['welcome', 0.5]
# ['least', 0.0]
# ['monthly', 0.0]
# ['faster', 0.0]
# ['excellent', 1.0]
# ['optical', 0.0]
# ['standard', 0.0]
# ['traditional', 0.0]
# ['capacitive', 0.0]
# ['main', 0.375]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['primary', 0.375]
# ['great', 0.0]
# ['capable', 0.125]
# ['good', 0.75]
# ['best', 0.75]
# ['effective', 0.125]
# ['used', 0.0]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['good', 0.75]
# ['dull', 0.125]
# ['main', 0.375]
# ['optical', 0.0]
# ['cheaper', -0.25]
# ['digital', 0.125]
# ['best', 0.75]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['great', 0.0]
# ['new', 0.375]
# ['super', 0.625]
# ['minimum', 0.0]
# ['interesting', 0.375]
# ['rich', 0.0]
# ['human', 0.0]
# ['good', 0.75]
# ['yellow', 0.0]
# ['capable', 0.125]
# ['great', 0.0]
# ['rich', 0.0]
# ['good', 0.75]
# ['clear', 0.5]
# ['blue', 0.0]
# ['best', 0.75]
# ['exact', 0.0]
# ['best', 0.75]
# ['improved', 0.375]
# ['debatable', 0.0]
# ['rapid', 0.0]
# ['new', 0.375]
# ['great', 0.0]
# ['spectacular', 0.25]
# ['new', 0.375]
# ['easier', 0.375]
# ['latest', 0.125]
# ['top', 0.0]
# ['hard', -0.75]
# ['expandable', 0.0]
# ['good', 0.75]
# ['heavy', 0.0]
# ['gigantic', 0.0]
# ['gorgeous', 0.75]
# ['fast', 0.0]
# ['free', 0.375]
# ['manageable', 0.625]
# ['fast', 0.0]
# ['last', -0.25]
# ['better', 0.875]
# ['biggest', 0.125]
# ['cheaper', -0.25]
# ['smaller', -0.125]
# ['easier', 0.375]
# ['biggest', 0.125]
# ['best', 0.75]
# ['fastest', 0.0]
# ['worth', 0.25]
# ['bigger', 0.125]
# ['magic', -0.25]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['next', 0.0]
# ['iterative', -0.25]
# ['western', 0.0]
# ['visual', 0.0]
# ['high', -0.125]
# ['latter', 0.0]
# ['perfect', 0.5]
# ['immediate', 0.0]
# ['deep', 0.125]
# ['cultural', 0.0]
# ['cultural', 0.0]
# ['hard', -0.75]
# ['ongoing', 0.0]
# ['black', -0.375]
# ['new', 0.375]
# ['indie', -0.625]
# ['Japanese', 0.0]
# ['national', 0.0]
# ['average', 0.0]
# ['offensive', -0.375]
# ['banal', -0.375]
# ['excellent', 1.0]
# ['diverse', 0.125]
# ['new', 0.375]
# ['available', 0.375]
# ['cultural', 0.0]
# ['accessible', 0.625]
# ['easiest', 0.375]
# ['grassroots', 0.0]
# ['blue', 0.0]
# ['quality', 0.625]
# ['simplest', -0.25]
# ['last', -0.25]
# ['cool', 0.125]
# ['last', -0.25]
# ['big', 0.125]
# ['former', -0.125]
# ['third', 0.0]
# ['Next', 0.0]
# ['Other', -0.625]
# ['last', -0.25]
# ['strange', 0.25]
# ['aesthetic', 0.0]
# ['vast', -0.125]
# ['musical', 0.25]
# ['independent', 0.125]
# ['legitimate', -0.25]
# ['branded', 0.125]
# ['cultural', 0.0]
# ['imperative', 0.0]
# ['bereft', -0.75]
# ['cultural', 0.0]
# ['bracing', 0.375]
# ['glorious', -0.375]
# ['alcoholic', 0.0]
# ['best', 0.75]
# ['unobtrusive', -0.625]
# ['European', 0.0]
# ['public', -0.125]
# ['important', 0.875]
# ['psychic', 0.375]
# ['many', 0.0]
# ['important', 0.875]
# ['global', -0.375]
# ['true', 0.125]
# ['artistic', 0.0]
# ['cultural', 0.0]
# ['perfect', 0.5]
# ['new', 0.375]
# ['new', 0.375]
# ['brilliant', 0.875]
# ['smaller', -0.125]
# ['cheaper', -0.25]
# ['last', -0.25]
# ['new', 0.375]
# ['much', 0.0]
# ['better', 0.875]
# ['new', 0.375]
# ['small', -0.375]
# ['big', 0.125]
# ['new', 0.375]
# ['smaller', -0.125]
# ['cheaper', -0.25]
# ['longer', 0.0]
# ['smaller', -0.125]
# ['fresh', -0.25]
# ['massive', 0.0]
# ['smooth', 0.25]
# ['flat', 0.125]
# ['front', 0.0]
# ['narrow', 0.0]
# ['easiest', 0.375]
# ['large', 0.125]
# ['new', 0.375]
# ['large', 0.125]
# ['circular', 0.25]
# ['new', 0.375]
# ['triple', 0.0]
# ['attractive', 0.875]
# ['normal', -0.5]
# ['graphic', 0.0]
# ['many', 0.0]
# ['available', 0.375]
# ['cheapest', -0.25]
# ['fly', -0.5]
# ['enjoyable', 0.25]
# ['mundane', 0.125]
# ['social', 0.0]
# ['pleasurable', 0.25]
# ['worse', -0.75]
# ['new', 0.375]
# ['last', -0.25]
# ['heavy', 0.0]
# ['wireless', 0.0]
# ['full', 0.0]
# ['flat', 0.125]
# ['previous', 0.0]
# ['available', 0.375]
# ['latest', 0.125]
# ['first', 0.0]
# ['best', 0.75]
# ['complete', 0.0]
# ['usual', 0.125]
# ['colour', 0.625]
# ['new', 0.375]
# ['new', 0.375]
# ['traditional', 0.0]
# ['new', 0.375]
# ['right', 0.0]
# ['right', 0.0]
# ['lower', -0.25]
# ['third', 0.0]
# ['new', 0.375]
# ['large', 0.125]
# ['easier', 0.375]
# ['old', 0.375]
# ['optical', 0.0]
# ['accurate', 0.5]
# ['many', 0.0]
# ['huge', -0.125]
# ['overall', 0.0]
# ['traditional', 0.0]
# ['capacitive', 0.0]
# ['main', 0.375]
# ['optical', 0.0]
# ['optical', 0.0]
# ['digital', 0.125]
# ['similar', 0.125]
# ['main', 0.375]
# ['capable', 0.125]
# ['great', 0.0]
# ['full', 0.0]
# ['solid', 0.875]
# ['low', -0.25]
# ['light', -0.25]
# ['low', -0.25]
# ['good', 0.75]
# ['worse', -0.75]
# ['main', 0.375]
# ['digital', 0.125]
# ['macro', 0.0]
# ['minimum', 0.0]
# ['macro', 0.0]
# ['good', 0.75]
# ['unpredictable', -0.625]
# ['brighter', 0.125]
# ['little', -0.375]
# ['manual', 0.0]
# ['required', 0.125]
# ['right', 0.0]
# ['matching', 0.0]
# ['good', 0.75]
# ['good', 0.75]
# ['light', -0.25]
# ['second', 0.0]
# ['good', 0.75]
# ['best', 0.75]
# ['slow', 0.0]
# ['sharp', 0.25]
# ['alert', 0.5]
# ['wonderful', 0.75]
# ['little', -0.375]
# ['smaller', -0.125]
# ['included', 0.0]
# ['best', 0.75]
# ['first', 0.0]
# ['colour', 0.625]
# ['green', -0.125]
# ['dark', 0.0]
# ['various', -0.25]
# ['cut', 0.0]
# ['super', 0.625]
# ['fast', 0.0]
# ['smooth', 0.25]
# ['smaller', -0.125]
# ['cheaper', -0.25]
# ['large', 0.125]
# ['bright', 0.125]
# ['good', 0.75]
# ['manageable', 0.625]
# ['solid', 0.875]
# ['capable', 0.125]
# ['great', 0.0]
# ['best', 0.75]
# ['excellent', 1.0]
# ['least', 0.0]
# ['luxurious', 0.625]
# ['gigantic', 0.0]
# ['cheaper', -0.25]
# ['better', 0.875]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['biggest', 0.125]
# ['west', 0.0]
# ['South', 0.0]
# ['Korean', 0.0]
# ['bright', 0.125]
# ['upper', 0.125]
# ['various', -0.25]
# ['bigger', 0.125]
# ['South', 0.0]
# ['Korean', 0.0]
# ['biggest', 0.125]
# ['global', -0.375]
# ['top', 0.0]
# ['attractive', 0.875]
# ['high', -0.125]
# ['high', -0.125]
# ['slow', 0.0]
# ['traditional', 0.0]
# ['larger', 0.125]
# ['large', 0.125]
# ['new', 0.375]
# ['social', 0.0]
# ['popular', 0.125]
# ['positive', 0.625]
# ['negative', -0.875]
# ['steep', 0.375]
# ['enough', 0.125]
# ['able', 0.125]
# ['various', -0.25]
# ['wide', 0.125]
# ['senior', 0.375]
# ['experienced', 0.5]
# ['shy', 0.0]
# ['least', 0.0]
# ['new', 0.375]
# ['big', 0.125]
# ['international', -0.5]
# ['nonprofit', 0.0]
# ['standard', 0.0]
# ['various', -0.25]
# ['recent', 0.0]
# ['annual', 0.0]
# ['new', 0.375]
# ['first', 0.0]
# ['successful', 0.625]
# ['small', -0.375]
# ['useful', 0.0]
# ['possible', 0.5]
# ['communicative', 0.0]
# ['tired', 0.25]
# ['unconcerned', 0.0]
# ['dismissive', 0.25]
# ['mean', 0.0]
# ['yawning', 0.0]
# ['little', -0.375]
# ['responsible', 0.625]
# ['new', 0.375]
# ['due', 0.0]
# ['useful', 0.0]
# ['new', 0.375]
# ['available', 0.375]
# ['new', 0.375]
# ['late', 0.0]
# ['last', -0.25]
# ['many', 0.0]
# ['amazing', 0.25]
# ['fresh', -0.25]
# ['useful', 0.0]
# ['mean', 0.0]
# ['imperative', 0.0]
# ['plastic', 0.0]
# ['easier', 0.375]
# ['plastic', 0.0]
# ['biggest', 0.125]
# ['higher', 0.375]
# ['virgin', 0.0]
# ['new', 0.375]
# ['minimum', 0.0]
# ['sustainable', 0.625]
# ['material', 0.125]
# ['single', 0.0]
# ['content', 0.0]
# ['plastic', 0.0]
# ['reusable', 0.625]
# ['additional', 0.0]
# ['top', 0.0]
# ['current', 0.0]
# ['circular', 0.25]
# ['plastic', 0.0]
# ['used', 0.0]
# ['ready', 0.0]
# ['high', -0.125]
# ['near', -0.25]
# ['infrared', 0.0]
# ['plastic', 0.0]
# ['light', -0.25]
# ['different', 0.625]
# ['due', 0.0]
# ['black', -0.375]
# ['ready', 0.0]
# ['black', -0.375]
# ['global', -0.375]
# ['good', 0.75]
# ['black', -0.375]
# ['black', -0.375]
# ['alternative', 0.125]
# ['free', 0.375]
# ['black', -0.375]
# ['international', -0.5]
# ['free', 0.375]
# ['black', -0.375]
# ['recyclable', 0.625]
# ['reusable', 0.625]
# ['plastic', 0.0]
# ['European', 0.0]
# ['good', 0.75]
# ['main', 0.375]
# ['better', 0.875]
# ['circular', 0.25]
# ['social', 0.0]
# ['plastic', 0.0]
# ['plastic', 0.0]
# ['good', 0.75]
# ['plastic', 0.0]
# ['total', 0.0]
# ['global', -0.375]
# ['proven', 0.0]
# ['environmental', 0.0]
# ['social', 0.0]
# ['many', 0.0]
# ['Early', 0.0]
# ['charitable', 0.25]
# ['initiative', 0.0]
# ['successful', 0.625]
# ['personal', 0.0]
# ['professional', 0.0]
# ['young', 0.0]
# ['steady', -0.5]
# ['plastic', 0.0]
# ['plastic', 0.0]
# ['varied', -0.25]
# ['hard', -0.75]
# ['large', 0.125]
# ['transparent', 0.0]
# ['yellowish', 0.0]
# ['huge', -0.125]
# ['attractive', 0.875]
# ['coloured', 0.0]
# ['transparent', 0.0]
# ['mean', 0.0]
# ['plastic', 0.0]
# ['greyish', 0.0]
# ['nice', 0.875]
# ['smart', 0.5]
# ['plastic', 0.0]
# ['sustainable', 0.625]
# ['multiple', 0.0]
# ['plastic', 0.0]
# ['resistant', -0.125]
# ['good', 0.75]
# ['external', 0.0]
# ['difficult', -0.75]
# ['separate', -0.5]
# ['padded', 0.0]
# ['used', 0.0]
# ['heavy', 0.0]
# ['environmental', 0.0]
# ['lighter', -0.25]
# ['new', 0.375]
# ['recyclable', 0.625]
# ['straight', -0.375]
# ['global', -0.375]
# ['circular', 0.25]
# ['traditional', 0.0]
# ['different', 0.625]
# ['plastic', 0.0]
# ['sustainable', 0.625]
# ['new', 0.375]
# ['recyclable', 0.625]
# ['plastic', 0.0]
# ['sustainable', 0.625]
# ['plastic', 0.0]
# ['plastic', 0.0]
# ['future', -0.125]
# ['sustainable', 0.625]
# ['great', 0.0]
# ['horrendous', -0.625]
# ['least', 0.0]
# ['last', -0.25]
# ['biggest', 0.125]
# ['expensive', 0.5]
# ['new', 0.375]
# ['small', -0.375]
# ['new', 0.375]
# ['smaller', -0.125]
# ['exact', 0.0]
# ['different', 0.625]
# ['difficult', -0.75]
# ['wide', 0.125]
# ['massive', 0.0]
# ['gigantic', 0.0]
# ['heavier', 0.0]
# ['full', 0.0]
# ['top', 0.0]
# ['unforgiving', -0.75]
# ['bigger', 0.125]
# ['giant', 0.375]
# ['public', -0.125]
# ['wonderful', 0.75]
# ['smaller', -0.125]
# ['massive', 0.0]
# ['cheaper', -0.25]
# ['metallic', 0.0]
# ['new', 0.375]
# ['least', 0.0]
# ['intensive', 0.375]
# ['top', 0.0]
# ['adaptable', 0.0]
# ['useful', 0.0]
# ['starting', 0.0]
# ['massive', 0.0]
# ['last', -0.25]
# ['longer', 0.0]
# ['shy', 0.0]
# ['full', 0.0]
# ['last', -0.25]
# ['top', 0.0]
# ['primary', 0.375]
# ['full', 0.0]
# ['flat', 0.125]
# ['hot', 0.0]
# ['worth', 0.25]
# ['quick', 0.0]
# ['menstrual', 0.0]
# ['new', 0.375]
# ['large', 0.125]
# ['present', -0.125]
# ['smaller', -0.125]
# ['top', 0.0]
# ['difficult', -0.75]
# ['right', 0.0]
# ['equal', 0.125]
# ['least', 0.0]
# ['surprising', -0.625]
# ['quick', 0.0]
# ['new', 0.375]
# ['triple', 0.0]
# ['smaller', -0.125]
# ['wide', 0.125]
# ['optical', 0.0]
# ['digital', 0.125]
# ['massive', 0.0]
# ['previous', 0.0]
# ['new', 0.375]
# ['best', 0.75]
# ['low', -0.25]
# ['new', 0.375]
# ['deep', 0.125]
# ['closer', 0.0]
# ['fine', 0.375]
# ['large', 0.125]
# ['ultra', 0.0]
# ['competitive', 0.0]
# ['resistant', -0.125]
# ['last', -0.25]
# ['stronger', 0.5]
# ['weakest', -0.375]
# ['best', 0.75]
# ['new', 0.375]
# ['directional', 0.0]
# ['polished', 0.25]
# ['easy', 0.375]
# ['careful', 0.5]
# ['general', 0.0]
# ['sensitive', 0.0]
# ['previous', 0.0]
# ['black', -0.375]
# ['green', -0.125]
# ['excellent', 1.0]
# ['super', 0.625]
# ['smaller', -0.125]
# ['biggest', 0.125]
# ['terrible', -0.625]
# ['worse', -0.75]
# ['massive', 0.0]
# ['heavy', 0.0]
# ['serious', 0.125]
# ['great', 0.0]
# ['epic', 0.75]
# ['expensive', 0.5]
# ['easier', 0.375]
# ['big', 0.125]
# ['available', 0.375]
# ['wonderful', 0.75]
# ['bigger', 0.125]
# ['magic', -0.25]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['rancorous', 0.125]
# ['first', 0.0]
# ['new', 0.375]
# ['soft', -0.25]
# ['Western', 0.0]
# ['biggest', 0.125]
# ['final', 0.0]
# ['third', 0.0]
# ['mean', 0.0]
# ['new', 0.375]
# ['solid', 0.875]
# ['last', -0.25]
# ['first', 0.0]
# ['former', -0.125]
# ['last', -0.25]
# ['top', 0.0]
# ['influential', 0.125]
# ['short', 0.0]
# ['international', -0.5]
# ['brightest', 0.125]
# ['short', 0.0]
# ['final', 0.0]
# ['early', 0.0]
# ['former', -0.125]
# ['safe', 0.0]
# ['abject', -0.875]
# ['wholesale', 0.25]
# ['clean', 0.125]
# ['unknown', -0.25]
# ['right', 0.0]
# ['wrong', -0.625]
# ['positive', 0.625]
# ['literal', 0.25]
# ['perfect', 0.5]
# ['unequivocal', -0.125]
# ['last', -0.25]
# ['solid', 0.875]
# ['handy', 0.0]
# ['last', -0.25]
# ['good', 0.75]
# ['new', 0.375]
# ['massive', 0.0]
# ['variable', 0.375]
# ['foreign', -0.125]
# ['sound', 0.75]
# ['competitive', 0.0]
# ['top', 0.0]
# ['worst', -0.5]
# ['faithful', 0.625]
# ['tumultuous', -0.75]
# ['steady', -0.5]
# ['competitive', 0.0]
# ['worth', 0.25]
# ['talented', 0.5]
# ['local', 0.0]
# ['regular', 0.0]
# ['short', 0.0]
# ['last', -0.25]
# ['open', -0.375]
# ['last', -0.25]
# ['mean', 0.0]
# ['new', 0.375]
# ['unknown', -0.25]
# ['new', 0.375]
# ['final', 0.0]
# ['highest', -0.125]
# ['real', 0.0]
# ['potential', -0.25]
# ['rich', 0.0]
# ['young', 0.0]
# ['biggest', 0.125]
# ['Last', -0.25]
# ['new', 0.375]
# ['full', 0.0]
# ['youthful', 0.375]
# ['golden', 0.0]
# ['first', 0.0]
# ['broader', 0.125]
# ['last', -0.25]
# ['new', 0.375]
# ['mean', 0.0]
# ['key', 0.0]
# ['immediate', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['greater', 0.25]
# ['forlorn', -0.375]
# ['upfront', 0.5]
# ['due', 0.0]
# ['free', 0.375]
# ['precarious', -0.5]
# ['financial', 0.25]
# ['veteran', 0.5]
# ['solid', 0.875]
# ['huge', -0.125]
# ['alliterative', 0.0]
# ['faithful', 0.625]
# ['Last', -0.25]
# ['full', 0.0]
# ['proven', 0.0]
# ['top', 0.0]
# ['painful', -0.625]
# ['Asian', 0.0]
# ['many', 0.0]
# ['nearer', -0.25]
# ['obvious', 0.5]
# ['weak', -0.375]
# ['quiet', -0.5]
# ['last', -0.25]
# ['consistent', 0.25]
# ['big', 0.125]
# ['several', -0.5]
# ['able', 0.125]
# ['old', 0.375]
# ['injured', -0.625]
# ['lit', 0.0]
# ['blue', 0.0]
# ['high', -0.125]
# ['pedigree', 0.0]
# ['handy', 0.0]
# ['last', -0.25]
# ['rare', 0.25]
# ['back', 0.0]
# ['consistent', 0.25]
# ['young', 0.0]
# ['good', 0.75]
# ['much', 0.0]
# ['last', -0.25]
# ['fancy', -0.375]
# ['good', 0.75]
# ['quiet', -0.5]
# ['genuine', -0.272]
# ['single', 0.0]
# ['mercurial', -0.25]
# ['best', 0.75]
# ['last', -0.25]
# ['Australian', 0.0]
# ['familiar', 0.125]
# ['real', 0.0]
# ['fit', 0.5]
# ['tough', -0.75]
# ['new', 0.375]
# ['genuine', -0.272]
# ['disappointed', -0.5]
# ['decisive', 0.0]
# ['spectacular', 0.25]
# ['raucous', -0.5]
# ['early', 0.0]
# ['poor', -0.75]
# ['unsatisfactory', -0.5]
# ['temporary', 0.375]
# ['dramatic', 0.5]
# ['last', -0.25]
# ['final', 0.0]
# ['long', 0.0]
# ['obvious', 0.5]
# ['stronger', 0.5]
# ['final', 0.0]
# ['newest', 0.375]
# ['mere', 0.125]
# ['true', 0.125]
# ['impressive', 0.125]
# ['young', 0.0]
# ['Australian', 0.0]
# ['international', -0.5]
# ['inevitable', -0.625]
# ['least', 0.0]
# ['Western', 0.0]
# ['raw', 0.0]
# ['pro', 0.0]
# ['smaller', -0.125]
# ['manageable', 0.625]
# ['premium', 0.75]
# ['small', -0.375]
# ['relative', -0.25]
# ['larger', 0.125]
# ['modern', -0.25]
# ['pocketable', 0.0]
# ['new', 0.375]
# ['heavier', 0.0]
# ['side', 0.0]
# ['heavy', 0.0]
# ['easiest', 0.375]
# ['new', 0.375]
# ['regular', 0.0]
# ['gorgeous', 0.75]
# ['bright', 0.125]
# ['rich', 0.0]
# ['full', 0.0]
# ['smooth', 0.25]
# ['new', 0.375]
# ['previous', 0.0]
# ['small', -0.375]
# ['least', 0.0]
# ['intensive', 0.375]
# ['likely', 0.5]
# ['top', 0.0]
# ['small', -0.375]
# ['new', 0.375]
# ['old', 0.375]
# ['much', 0.0]
# ['powerful', 0.25]
# ['adaptable', 0.0]
# ['recent', 0.0]
# ['pro', 0.0]
# ['creative', 0.0]
# ['short', 0.0]
# ['last', -0.25]
# ['worse', -0.75]
# ['last', -0.25]
# ['longer', 0.0]
# ['negligible', -0.125]
# ['primary', 0.375]
# ['full', 0.0]
# ['flat', 0.125]
# ['much', 0.0]
# ['hot', 0.0]
# ['worth', 0.25]
# ['big', 0.125]
# ['new', 0.375]
# ['black', -0.375]
# ['white', -0.25]
# ['black', -0.375]
# ['white', -0.25]
# ['black', -0.375]
# ['efficient', 0.0]
# ['black', -0.375]
# ['white', -0.25]
# ['meaningful', 0.125]
# ['black', -0.375]
# ['Other', -0.625]
# ['long', 0.0]
# ['open', -0.375]
# ['quick', 0.0]
# ['unknown', -0.25]
# ['menstrual', 0.0]
# ['new', 0.375]
# ['useful', 0.0]
# ['summary', -0.125]
# ['least', 0.0]
# ['surprising', -0.625]
# ['quick', 0.0]
# ['normal', -0.5]
# ['previous', 0.0]
# ['new', 0.375]
# ['optical', 0.0]
# ['digital', 0.125]
# ['dual', 0.0]
# ['noticeable', 0.625]
# ['last', -0.25]
# ['best', 0.75]
# ['different', 0.625]
# ['new', 0.375]
# ['low', -0.25]
# ['light', -0.25]
# ['main', 0.375]
# ['automatic', 0.0]
# ['multiple', 0.0]
# ['second', 0.0]
# ['available', 0.375]
# ['light', -0.25]
# ['second', 0.0]
# ['dank', -0.25]
# ['bright', 0.125]
# ['flat', 0.125]
# ['dramatic', 0.5]
# ['last', -0.25]
# ['good', 0.75]
# ['deep', 0.125]
# ['huge', -0.125]
# ['fine', 0.375]
# ['first', 0.0]
# ['full', 0.0]
# ['large', 0.125]
# ['past', -0.25]
# ['fantastic', 0.375]
# ['best', 0.75]
# ['third', 0.0]
# ['useful', 0.0]
# ['capable', 0.125]
# ['good', 0.75]
# ['slow', 0.0]
# ['big', 0.125]
# ['big', 0.125]
# ['first', 0.0]
# ['important', 0.875]
# ['last', -0.25]
# ['stronger', 0.5]
# ['weakest', -0.375]
# ['best', 0.75]
# ['new', 0.375]
# ['directional', 0.0]
# ['polished', 0.25]
# ['easy', 0.375]
# ['careful', 0.5]
# ['general', 0.0]
# ['sensitive', 0.0]
# ['previous', 0.0]
# ['black', -0.375]
# ['green', -0.125]
# ['last', -0.25]
# ['top', 0.0]
# ['best', 0.75]
# ['smaller', -0.125]
# ['available', 0.375]
# ['longer', 0.0]
# ['excellent', 1.0]
# ['big', 0.125]
# ['fine', 0.375]
# ['low', -0.25]
# ['digital', 0.125]
# ['professional', 0.0]
# ['right', 0.0]
# ['perfect', 0.5]
# ['larger', 0.125]
# ['easy', 0.375]
# ['biggest', 0.125]
# ['likely', 0.5]
# ['large', 0.125]
# ['good', 0.75]
# ['unrivalled', 0.5]
# ['hefty', 0.125]
# ['premium', 0.75]
# ['ethical', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['discreet', 0.625]
# ['professional', 0.0]
# ['steep', 0.375]
# ['dusty', -0.375]
# ['minor', -0.375]
# ['Dickensian', -0.625]
# ['quiet', -0.5]
# ['whole', 0.125]
# ['chubbier', 0.125]
# ['early', 0.0]
# ['sandy', 0.0]
# ['tan', 0.0]
# ['regular', 0.0]
# ['Italian', 0.0]
# ['unlikely', -0.625]
# ['incident', -0.25]
# ['facial', 0.0]
# ['available', 0.375]
# ['active', -0.125]
# ['former', -0.125]
# ['facial', 0.0]
# ['private', -0.125]
# ['aggressive', 0.5]
# ['vanished', 0.0]
# ['rolled', 0.125]
# ['least', 0.0]
# ['high', -0.125]
# ['close', 0.0]
# ['mobile', 0.0]
# ['second', 0.0]
# ['front', 0.0]
# ['old', 0.375]
# ['subject', -0.125]
# ['front', 0.0]
# ['facial', 0.0]
# ['ultimate', -0.125]
# ['major', 0.625]
# ['conservative', 0.0]
# ['Brazilian', 0.0]
# ['several', -0.5]
# ['dressed', -0.125]
# ['potential', -0.25]
# ['facial', 0.0]
# ['personal', 0.0]
# ['worried', -0.875]
# ['safest', 0.0]
# ['past', -0.25]
# ['facial', 0.0]
# ['private', -0.125]
# ['personal', 0.0]
# ['private', -0.125]
# ['facial', 0.0]
# ['unknown', -0.25]
# ['public', -0.125]
# ['legal', 0.0]
# ['facial', 0.0]
# ['enough', 0.125]
# ['facial', 0.0]
# ['noticed', 0.125]
# ['peaceful', 0.25]
# ['major', 0.625]
# ['recent', 0.0]
# ['local', 0.0]
# ['human', 0.0]
# ['right', 0.0]
# ['last', -0.25]
# ['high', -0.125]
# ['lawful', 0.125]
# ['new', 0.375]
# ['facial', 0.0]
# ['suspect', -0.5]
# ['false', -0.75]
# ['quick', 0.0]
# ['judicial', 0.0]
# ['domestic', 0.0]
# ['certain', -0.375]
# ['individual', 0.0]
# ['specific', 0.0]
# ['facial', 0.0]
# ['large', 0.125]
# ['big', 0.125]
# ['legal', 0.0]
# ['legal', 0.0]
# ['u', 0.0]
# ['expansive', -0.5]
# ['potential', -0.25]
# ['facial', 0.0]
# ['major', 0.625]
# ['north', 0.0]
# ['western', 0.0]
# ['ethnic', 0.0]
# ['half', 0.0]
# ['first', 0.0]
# ['major', 0.625]
# ['good', 0.75]
# ['harsh', -0.625]
# ['chaotic', -0.125]
# ['clear', 0.5]
# ['political', 0.0]
# ['u', 0.0]
# ['new', 0.375]
# ['great', 0.0]
# ['early', 0.0]
# ['vain', -0.75]
# ['fake', -0.75]
# ['facial', 0.0]
# ['Independent', 0.125]
# ['rapid', 0.0]
# ['bespoke', 0.0]
# ['different', 0.625]
# ['different', 0.625]
# ['multiple', 0.0]
# ['tagged', 0.125]
# ['Creative', 0.0]
# ['Chinese', 0.0]
# ['parallel', -0.25]
# ['new', 0.375]
# ['powerful', 0.25]
# ['second', 0.0]
# ['big', 0.125]
# ['new', 0.375]
# ['facial', 0.0]
# ['deep', 0.125]
# ['incredible', 0.0]
# ['standard', 0.0]
# ['human', 0.0]
# ['intuitive', 0.0]
# ['abstract', 0.0]
# ['mathematical', 0.375]
# ['limited', 0.0]
# ['best', 0.75]
# ['deep', 0.125]
# ['first', 0.0]
# ['random', 0.125]
# ['little', -0.375]
# ['better', 0.875]
# ['right', 0.0]
# ['wrong', -0.625]
# ['facial', 0.0]
# ['useful', 0.0]
# ['facial', 0.0]
# ['effective', 0.125]
# ['available', 0.375]
# ['high', -0.125]
# ['clear', 0.5]
# ['real', 0.0]
# ['potential', -0.25]
# ['false', -0.75]
# ['positive', 0.625]
# ['inaccurate', -0.5]
# ['similar', 0.125]
# ['false', -0.75]
# ['positive', 0.625]
# ['general', 0.0]
# ['public', -0.125]
# ['facial', 0.0]
# ['aware', 0.5]
# ['new', 0.375]
# ['huge', -0.125]
# ['suspect', -0.5]
# ['similar', 0.125]
# ['local', 0.0]
# ['related', 0.0]
# ['many', 0.0]
# ['sharp', 0.25]
# ['mobile', 0.0]
# ['real', 0.0]
# ['surprising', -0.625]
# ['facial', 0.0]
# ['light', -0.25]
# ['top', 0.0]
# ['average', 0.0]
# ['largest', 0.125]
# ['black', -0.375]
# ['British', 0.0]
# ['acceptable', 0.625]
# ['ambiguous', 0.125]
# ['worst', -0.5]
# ['blameless', 0.25]
# ['individual', 0.0]
# ['human', 0.0]
# ['several', -0.5]
# ['demographic', 0.0]
# ['small', -0.375]
# ['many', 0.0]
# ['illegal', 0.0]
# ['incomprehensible', -0.375]
# ['Indian', 0.0]
# ['mean', 0.0]
# ['last', -0.25]
# ['various', -0.25]
# ['many', 0.0]
# ['impossible', -0.75]
# ['rural', 0.0]
# ['better', 0.875]
# ['facial', 0.0]
# ['centralised', 0.0]
# ['recent', 0.0]
# ['last', -0.25]
# ['facial', 0.0]
# ['international', -0.5]
# ['potential', -0.25]
# ['difficult', -0.75]
# ['many', 0.0]
# ['possible', 0.5]
# ['unofficial', -0.75]
# ['technological', 0.0]
# ['available', 0.375]
# ['recent', 0.0]
# ['hard', -0.75]
# ['open', -0.375]
# ['new', 0.375]
# ['real', 0.0]
# ['criminal', -0.875]
# ['Real', 0.0]
# ['facial', 0.0]
# ['largest', 0.125]
# ['perfect', 0.5]
# ['legal', 0.0]
# ['human', 0.0]
# ['right', 0.0]
# ['Indian', 0.0]
# ['difficult', -0.75]
# ['dangerous', -0.75]
# ['good', 0.75]
# ['civil', 0.125]
# ['instinct', -0.5]
# ['much', 0.0]
# ['private', -0.125]
# ['common', 0.0]
# ['undesirable', -0.375]
# ['recent', 0.0]
# ['facial', 0.0]
# ['digital', 0.125]
# ['facial', 0.0]
# ['mobile', 0.0]
# ['opposite', -0.125]
# ['facial', 0.0]
# ['single', 0.0]
# ['strategic', 0.0]
# ['future', -0.125]
# ['social', 0.0]
# ['political', 0.0]
# ['facial', 0.0]
# ['u', 0.0]
# ['new', 0.375]
# ['unsafe', -0.125]
# ['red', 0.0]
# ['longer', 0.0]
# ['free', 0.375]
# ['real', 0.0]
# ['thin', 0.0]
# ['light', -0.25]
# ['traditional', 0.0]
# ['dual', 0.0]
# ['unveiled', 0.0]
# ['next', 0.0]
# ['mobile', 0.0]
# ['fit', 0.5]
# ['larger', 0.125]
# ['high', -0.125]
# ['thick', 0.0]
# ['detachable', 0.25]
# ['new', 0.375]
# ['fit', 0.5]
# ['biggest', 0.125]
# ['new', 0.375]
# ['mobile', 0.0]
# ['full', 0.0]
# ['powerful', 0.25]
# ['Better', 0.875]
# ['unprecedented', 0.0]
# ['full', 0.0]
# ['chief', 0.375]
# ['new', 0.375]
# ['similar', 0.125]
# ['excess', -0.5]
# ['traditional', 0.0]
# ['early', 0.0]
# ['new', 0.375]
# ['traditional', 0.0]
# ['10th', 0.0]
# ['powerful', 0.25]
# ['outgoing', 0.0]
# ['new', 0.375]
# ['fast', 0.0]
# ['mean', 0.0]
# ['biggest', 0.125]
# ['traditional', 0.0]
# ['new', 0.375]
# ['larger', 0.125]
# ['first', 0.0]
# ['found', 0.0]
# ['powerful', 0.25]
# ['larger', 0.125]
# ['longtime', 0.0]
# ['fastest', 0.0]
# ['graphic', 0.0]
# ['new', 0.375]
# ['removable', 0.625]
# ['hard', -0.75]
# ['clear', 0.5]
# ['difficult', -0.75]
# ['able', 0.125]
# ['critical', -0.5]
# ['new', 0.375]
# ['true', 0.125]
# ['direct', -0.25]
# ['dual', 0.0]
# ['real', 0.0]
# ['many', 0.0]
# ['due', 0.0]
# ['full', 0.0]
# ['open', -0.375]
# ['folding', 0.375]
# ['continuous', 0.0]
# ['flexible', 0.375]
# ['open', -0.375]
# ['absolute', 0.5]
# ['best', 0.75]
# ['best', 0.75]
# ['elegant', 0.5]
# ['vague', -0.125]
# ['flexible', 0.375]
# ['dual', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['detachable', 0.25]
# ['virtual', 0.5]
# ['new', 0.375]
# ['dual', 0.0]
# ['thick', 0.0]
# ['next', 0.0]
# ['unlimited', -0.5]
# ['interrupted', 0.0]
# ['available', 0.375]
# ['More', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['lower', -0.25]
# ['latest', 0.125]
# ['longer', 0.0]
# ['identical', -0.375]
# ['latest', 0.125]
# ['lower', -0.25]
# ['broader', 0.125]
# ['top', 0.0]
# ['cheaper', -0.25]
# ['last', -0.25]
# ['identical', -0.375]
# ['large', 0.125]
# ['lower', -0.25]
# ['biggest', 0.125]
# ['new', 0.375]
# ['large', 0.125]
# ['new', 0.375]
# ['dual', 0.0]
# ['solid', 0.875]
# ['best', 0.75]
# ['likely', 0.5]
# ['good', 0.75]
# ['rich', 0.0]
# ['bright', 0.125]
# ['high', -0.125]
# ['many', 0.0]
# ['heavy', 0.0]
# ['wide', 0.125]
# ['little', -0.375]
# ['latest', 0.125]
# ['least', 0.0]
# ['fastest', 0.0]
# ['efficient', 0.0]
# ['difficult', -0.75]
# ['last', -0.25]
# ['unusual', -0.5]
# ['top', 0.0]
# ['last', -0.25]
# ['happy', 0.875]
# ['last', -0.25]
# ['closer', 0.0]
# ['longest', 0.0]
# ['primary', 0.375]
# ['slow', 0.0]
# ['pathetic', -0.75]
# ['minute', 0.0]
# ['higher', 0.375]
# ['worth', 0.25]
# ['regardless', -0.625]
# ['worth', 0.25]
# ['much', 0.0]
# ['good', 0.75]
# ['prior', 0.0]
# ['different', 0.625]
# ['several', -0.5]
# ['hard', -0.75]
# ['Most', 0.0]
# ['extra', -0.5]
# ['big', 0.125]
# ['new', 0.375]
# ['black', -0.375]
# ['white', -0.25]
# ['white', -0.25]
# ['first', 0.0]
# ['open', -0.375]
# ['second', 0.0]
# ['open', -0.375]
# ['quick', 0.0]
# ['straight', -0.375]
# ['appropriate', 0.0]
# ['extensive', 0.0]
# ['friendly', 0.125]
# ['good', 0.75]
# ['new', 0.375]
# ['unknown', -0.25]
# ['new', 0.375]
# ['summary', -0.125]
# ['friendly', 0.125]
# ['useful', 0.0]
# ['longest', 0.0]
# ['best', 0.75]
# ['important', 0.875]
# ['new', 0.375]
# ['new', 0.375]
# ['dual', 0.0]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['standard', 0.0]
# ['typical', 0.125]
# ['optical', 0.0]
# ['optical', 0.0]
# ['digital', 0.125]
# ['good', 0.75]
# ['real', 0.0]
# ['optical', 0.0]
# ['poor', -0.75]
# ['good', 0.75]
# ['best', 0.75]
# ['rich', 0.0]
# ['main', 0.375]
# ['good', 0.75]
# ['best', 0.75]
# ['Other', -0.625]
# ['typical', 0.125]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['new', 0.375]
# ['main', 0.375]
# ['good', 0.75]
# ['smart', 0.5]
# ['closer', 0.0]
# ['biggest', 0.125]
# ['new', 0.375]
# ['low', -0.25]
# ['light', -0.25]
# ['special', 0.0]
# ['similar', 0.125]
# ['dramatic', 0.5]
# ['automatic', 0.0]
# ['multiple', 0.0]
# ['second', 0.0]
# ['available', 0.375]
# ['light', -0.25]
# ['second', 0.0]
# ['dank', -0.25]
# ['little', -0.375]
# ['indoor', 0.125]
# ['dark', 0.0]
# ['little', -0.375]
# ['dark', 0.0]
# ['particular', 0.0]
# ['grainy', 0.0]
# ['great', 0.0]
# ['fantastic', 0.375]
# ['easy', 0.375]
# ['slow', 0.0]
# ['big', 0.125]
# ['first', 0.0]
# ['important', 0.875]
# ['optical', 0.0]
# ['resistant', -0.125]
# ['second', 0.0]
# ['last', -0.25]
# ['stronger', 0.5]
# ['weakest', -0.375]
# ['best', 0.75]
# ['new', 0.375]
# ['directional', 0.0]
# ['useful', 0.0]
# ['available', 0.375]
# ['white', -0.25]
# ['black', -0.375]
# ['green', -0.125]
# ['yellow', 0.0]
# ['excellent', 1.0]
# ['old', 0.375]
# ['dated', -0.375]
# ['large', 0.125]
# ['heavy', 0.0]
# ['difficult', -0.75]
# ['solid', 0.875]
# ['new', 0.375]
# ['last', -0.25]
# ['cheap', -0.25]
# ['top', 0.0]
# ['latest', 0.125]
# ['top', 0.0]
# ['second', 0.0]
# ['third', 0.0]
# ['careful', 0.5]
# ['best', 0.75]
# ['optical', 0.0]
# ['ultra', 0.0]
# ['wide', 0.125]
# ['last', -0.25]
# ['tough', -0.75]
# ['real', 0.0]
# ['new', 0.375]
# ['second', 0.0]
# ['least', 0.0]
# ['third', 0.0]
# ['best', 0.75]
# ['primary', 0.375]
# ['best', 0.75]
# ['best', 0.75]
# ['new', 0.375]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['old', 0.375]
# ['British', 0.0]
# ['Indian', 0.0]
# ['equal', 0.125]
# ['first', 0.0]
# ['live', 0.0]
# ['ignorant', -0.5]
# ['north', 0.0]
# ['true', 0.125]
# ['north', 0.0]
# ['west', 0.0]
# ['momentous', 0.25]
# ['great', 0.0]
# ['gothic', 0.0]
# ['fourth', 0.0]
# ['oldest', 0.375]
# ['cathedral', 0.0]
# ['old', 0.375]
# ['cocky', 0.25]
# ['west', 0.0]
# ['fresher', -0.25]
# ['social', 0.0]
# ['financial', 0.25]
# ['unstable', -0.125]
# ['epidemic', 0.25]
# ['sexual', 0.25]
# ['fresh', -0.25]
# ['young', 0.0]
# ['young', 0.0]
# ['general', 0.0]
# ['living', -0.125]
# ['turbulent', -0.75]
# ['British', 0.0]
# ['first', 0.0]
# ['busy', 0.375]
# ['free', 0.375]
# ['main', 0.375]
# ['tinny', 0.0]
# ['full', 0.0]
# ['blue', 0.0]
# ['pink', 0.0]
# ['cheap', -0.25]
# ['free', 0.375]
# ['south', 0.0]
# ['incomprehensible', -0.375]
# ['south', 0.0]
# ['nice', 0.875]
# ['scary', -0.75]
# ['German', 0.0]
# ['wide', 0.125]
# ['sure', -0.25]
# ['full', 0.0]
# ['next', 0.0]
# ['live', 0.0]
# ['lyric', -0.25]
# ['giant', 0.375]
# ['fresher', -0.25]
# ['overpriced', 0.125]
# ['private', -0.125]
# ['good', 0.75]
# ['social', 0.0]
# ['clear', 0.5]
# ['flat', 0.125]
# ['wide', 0.125]
# ['certain', -0.375]
# ['old', 0.375]
# ['first', 0.0]
# ['French', 0.0]
# ['Spanish', 0.0]
# ['common', 0.0]
# ['young', 0.0]
# ['early', 0.0]
# ['free', 0.375]
# ['struck', -0.375]
# ['white', -0.25]
# ['English', 0.0]
# ['different', 0.625]
# ['clear', 0.5]
# ['international', -0.5]
# ['European', 0.0]
# ['u', 0.0]
# ['welcome', 0.5]
# ['high', -0.125]
# ['huge', -0.125]
# ['unearthly', 0.375]
# ['fresher', -0.25]
# ['intense', -0.125]
# ['light', -0.25]
# ['fancy', -0.375]
# ['like', -0.25]
# ['good', 0.75]
# ['biggest', 0.125]
# ['old', 0.375]
# ['full', 0.0]
# ['nervous', 0.125]
# ['surreal', -0.25]
# ['free', 0.375]
# ['front', 0.0]
# ['wide', 0.125]
# ['first', 0.0]
# ['digital', 0.125]
# ['native', 0.125]
# ['higher', 0.375]
# ['criminal', -0.875]
# ['persistent', -0.125]
# ['direct', -0.25]
# ['much', 0.0]
# ['higher', 0.375]
# ['safe', 0.0]
# ['online', 0.0]
# ['nervous', 0.125]
# ['new', 0.375]
# ['primary', 0.375]
# ['online', 0.0]
# ['right', 0.0]
# ['fair', 0.625]
# ['apparent', 0.625]
# ['mental', 0.125]
# ['unspoken', -0.25]
# ['lucky', 0.75]
# ['serious', 0.125]
# ['mental', 0.125]
# ['top', 0.0]
# ['unprecedented', 0.0]
# ['young', 0.0]
# ['assistant', 0.0]
# ['average', 0.0]
# ['old', 0.375]
# ['much', 0.0]
# ['greater', 0.25]
# ['smug', -0.25]
# ['apathetic', -0.5]
# ['prepared', 0.625]
# ['much', 0.0]
# ['greater', 0.25]
# ['golden', 0.0]
# ['future', -0.125]
# ['enough', 0.125]
# ['free', 0.375]
# ['obscene', -0.625]
# ['ready', 0.0]
# ['Scottish', 0.0]
# ['collect', 0.0]
# ['ready', 0.0]
# ['middle', 0.0]
# ['wearable', 0.25]
# ['new', 0.375]
# ['smart', 0.5]
# ['directional', 0.0]
# ['similar', 0.125]
# ['smart', 0.5]
# ['smart', 0.5]
# ['smart', 0.5]
# ['akin', 0.0]
# ['secret', -0.25]
# ['wide', 0.125]
# ['true', 0.125]
# ['active', -0.125]
# ['similar', 0.125]
# ['second', 0.0]
# ['best', 0.75]
# ['new', 0.375]
# ['new', 0.375]
# ['new', 0.375]
# ['lower', -0.25]
# ['significant', 0.375]
# ['smart', 0.5]
# ['integrated', 0.0]
# ['standard', 0.0]
# ['smaller', -0.125]
# ['cheaper', -0.25]
# ['smart', 0.5]
# ['new', 0.375]
# ['long', 0.0]
# ['low', -0.25]
# ['cheaper', -0.25]
# ['indoor', 0.125]
# ['improved', 0.375]
# ['responsible', 0.625]
# ['last', -0.25]
# ['false', -0.75]
# ['potential', -0.25]
# ['private', -0.125]
# ['private', -0.125]
# ['first', 0.0]
# ['available', 0.375]
# ['clean', 0.125]
# ['next', 0.0]
# ['true', 0.125]
# ['great', 0.0]
# ['wireless', 0.0]
# ['best', 0.75]
# ['long', 0.0]
# ['true', 0.125]
# ['good', 0.75]
# ['common', 0.0]
# ['woeful', -0.75]
# ['free', 0.375]
# ['wireless', 0.0]
# ['difficult', -0.75]
# ['separate', -0.5]
# ['true', 0.125]
# ['last', -0.25]
# ['available', 0.375]
# ['new', 0.375]
# ['right', 0.0]
# ['sound', 0.75]
# ['difficult', -0.75]
# ['wireless', 0.0]
# ['third', 0.0]
# ['small', -0.375]
# ['comfortable', -0.75]
# ['traditional', 0.0]
# ['small', -0.375]
# ['small', -0.375]
# ['soft', -0.25]
# ['fine', 0.375]
# ['double', 0.25]
# ['triple', 0.0]
# ['ambient', 0.375]
# ['assistant', 0.0]
# ['right', 0.0]
# ['ambient', 0.375]
# ['good', 0.75]
# ['reasonable', 0.5]
# ['treble', 0.0]
# ['good', 0.75]
# ['capable', 0.125]
# ['uncomfortable', -0.75]
# ['limited', 0.0]
# ['available', 0.375]
# ['good', 0.75]
# ['solid', 0.875]
# ['hot', 0.0]
# ['right', 0.0]
# ['capable', 0.125]
# ['proprietary', 0.0]
# ['scalable', 0.5]
# ['high', -0.125]
# ['noticeable', 0.625]
# ['good', 0.75]
# ['little', -0.375]
# ['distant', 0.0]
# ['similar', 0.125]
# ['good', 0.75]
# ['open', -0.375]
# ['small', -0.375]
# ['fit', 0.5]
# ['full', 0.0]
# ['mean', 0.0]
# ['last', -0.25]
# ['continuous', 0.0]
# ['additional', 0.0]
# ['mean', 0.0]
# ['compatible', 0.5]
# ['easy', 0.375]
# ['quick', 0.0]
# ['various', -0.25]
# ['useful', 0.0]
# ['sound', 0.75]
# ['mean', 0.0]
# ['least', 0.0]
# ['sure', -0.25]
# ['best', 0.75]
# ['simple', -0.25]
# ['wireless', 0.0]
# ['live', 0.0]
# ['effective', 0.125]
# ['great', 0.0]
# ['excellent', 1.0]
# ['sound', 0.75]
# ['true', 0.125]
# ['effective', 0.125]
# ['free', 0.375]
# ['comfortable', -0.75]
# ['full', 0.0]
# ['strong', 0.5]
# ['attractive', 0.875]
# ['black', -0.375]
# ['massive', 0.0]
# ['fit', 0.5]
# ['right', 0.0]
# ['good', 0.75]
# ['lasting', -0.625]
# ['active', -0.125]
# ['large', 0.125]
# ['difficult', -0.75]
# ['great', 0.0]
# ['sound', 0.75]
# ['excellent', 1.0]
# ['solid', 0.875]
# ['solid', 0.875]
# ['attractive', 0.875]
# ['best', 0.75]
# ['true', 0.125]
# ['best', 0.75]
# ['great', 0.0]
# ['smaller', -0.125]
# ['second', 0.0]
# ['little', -0.375]
# ['white', -0.25]
# ['sound', 0.75]
# ['able', 0.125]
# ['loud', 0.25]
# ['maximum', 0.25]
# ['good', 0.75]
# ['reasonable', 0.5]
# ['recent', 0.0]
# ['double', 0.25]
# ['second', 0.0]
# ['little', -0.375]
# ['slow', 0.0]
# ['poor', -0.75]
# ['odd', 0.125]
# ['public', -0.125]
# ['good', 0.75]
# ['best', 0.75]
# ['last', -0.25]
# ['available', 0.375]
# ['new', 0.375]
# ['extra', -0.5]
# ['compatible', 0.5]
# ['sound', 0.75]
# ['good', 0.75]
# ['excellent', 1.0]
# ['decent', 0.875]
# ['alternative', 0.125]
# ['sound', 0.75]
# ['smallest', -0.375]
# ['available', 0.375]
# ['tiny', 0.0]
# ['flat', 0.125]
# ['sensitive', 0.0]
# ['visible', 0.125]
# ['Available', 0.375]
# ['black', -0.375]
# ['white', -0.25]
# ['easy', 0.375]
# ['flat', 0.125]
# ['good', 0.75]
# ['treble', 0.0]
# ['crisp', 0.25]
# ['sparkling', 0.125]
# ['good', 0.75]
# ['good', 0.75]
# ['great', 0.0]
# ['old', 0.375]
# ['fine', 0.375]
# ['left', 0.0]
# ['right', 0.0]
# ['stable', 0.0]
# ['magnetic', 0.0]
# ['free', 0.375]
# ['good', 0.75]
# ['little', -0.375]
# ['quiet', -0.5]
# ['difficult', -0.75]
# ['loud', 0.25]
# ['last', -0.25]
# ['good', 0.75]
# ['constant', 0.375]
# ['cylindrical', 0.0]
# ['open', -0.375]
# ['small', -0.375]
# ['possible', 0.5]
# ['good', 0.75]
# ['great', 0.0]
# ['good', 0.75]
# ['smallest', -0.375]
# ['wireless', 0.0]
# ['smaller', -0.125]
# ['better', 0.875]
# ['great', 0.0]
# ['solid', 0.875]
# ['excellent', 1.0]
# ['proper', 0.75]
# ['flexible', 0.375]
# ['free', 0.375]
# ['resistant', -0.125]
# ['fine', 0.375]
# ['hard', -0.75]
# ['energetic', 0.375]
# ['good', 0.75]
# ['enormous', 0.0]
# ['worst', -0.5]
# ['robust', -0.375]
# ['able', 0.125]
# ['fit', 0.5]
# ['basic', 0.0]
# ['good', 0.75]
# ['excellent', 1.0]
# ['real', 0.0]
# ['solid', 0.875]
# ['smaller', -0.125]
# ['cheaper', -0.25]
# ['known', 0.5]
# ['best', 0.75]
# ['true', 0.125]
# ['available', 0.375]
# ['expensive', 0.5]
# ['comfortable', -0.75]
# ['hard', -0.75]
# ['fleshy', 0.0]
# ['traditional', 0.0]
# ['extra', -0.5]
# ['good', 0.75]
# ['best', 0.75]
# ['last', -0.25]
# ['double', 0.25]
# ['average', 0.0]
# ['true', 0.125]
# ['big', 0.125]
# ['pocketable', 0.0]
# ['full', 0.0]
# ['good', 0.75]
# ['good', 0.75]
# ['least', 0.0]
# ['good', 0.75]
# ['best', 0.75]
# ['stiff', -0.5]
# ['right', 0.0]
# ['left', 0.0]
# ['right', 0.0]
# ['good', 0.75]
# ['little', -0.375]
# ['audible', 0.375]
# ['fine', 0.375]
# ['similar', 0.125]
# ['poor', -0.75]
# ['sound', 0.75]
# ['solid', 0.875]
# ['OK', 0.375]
# ['excellent', 1.0]
# ['true', 0.125]
# ['great', 0.0]
# ['wireless', 0.0]
# ['small', -0.375]
# ['worth', 0.25]
# ['top', 0.0]
# ['fit', 0.5]
# ['true', 0.125]
# ['second', 0.0]
# ['best', 0.75]
# ['great', 0.0]
# ['sound', 0.75]
# ['solid', 0.875]
# ['comfortable', -0.75]
# ['basic', 0.0]
# ['excellent', 1.0]
# ['smaller', -0.125]
# ['easier', 0.375]
# ['extra', -0.5]
# ['smaller', -0.125]
# ['true', 0.125]
# ['excellent', 1.0]
# ['larger', 0.125]
# ['cheaper', -0.25]
# ['worth', 0.25]
# ['good', 0.75]
# ['second', 0.0]
# ['solid', 0.875]
# ['small', -0.375]
# ['last', -0.25]
# ['full', 0.0]
# ['reasonable', 0.5]
# ['biggest', 0.125]
# ['massive', 0.0]
# ['stable', 0.0]
# ['good', 0.75]
# ['flexible', 0.375]
# ['good', 0.75]
# ['good', 0.75]
# ['last', -0.25]
# ['large', 0.125]
# ['full', 0.0]
# ['biggest', 0.125]
# ['huge', -0.125]
# ['least', 0.0]
# ['solid', 0.875]
# ['good', 0.75]
# ['good', 0.75]
# ['available', 0.375]
# ['pocketable', 0.0]
# ['huge', -0.125]
# ['large', 0.125]
# ['classic', 0.375]
# ['big', 0.125]
# ['uncomfortable', -0.75]
# ['minute', 0.0]
# ['real', 0.0]
# ['good', 0.75]
# ['alternative', 0.125]
# ['solid', 0.875]
# ['noticeable', 0.625]
# ['good', 0.75]
# ['full', 0.0]
# ['right', 0.0]
# ['sound', 0.75]
# ['good', 0.75]
# ['clear', 0.5]
# ['little', -0.375]
# ['pretty', 0.75]
# ['compact', 0.0]
# ['large', 0.125]
# ['uncomfortable', -0.75]
# ['longer', 0.0]
# ['smaller', -0.125]
# ['best', 0.75]
# ['true', 0.125]
# ['available', 0.375]
# ['general', 0.0]
# ['attractive', 0.875]
# ['great', 0.0]
# ['effective', 0.125]
# ['tiny', 0.0]
# ['fit', 0.5]
# ['shy', 0.0]
# ['great', 0.0]
# ['sound', 0.75]
# ['worth', 0.25]
# ['good', 0.75]
# ['pronounced', 0.5]
# ['high', -0.125]
# ['short', 0.0]
# ['slight', -0.375]
# ['solid', 0.875]
# ['large', 0.125]
# ['uncomfortable', -0.75]
# ['good', 0.75]
# ['heavy', 0.0]
# ['great', 0.0]
# ['black', -0.375]
# ['traditional', 0.0]
# ['good', 0.75]
# ['strong', 0.5]
# ['solid', 0.875]
# ['poor', -0.75]
# ['good', 0.75]
# ['occasional', 0.0]
# ['minimal', 0.0]
# ['last', -0.25]
# ['full', 0.0]
# ['attractive', 0.875]
# ['accessible', 0.625]
# ['multiple', 0.0]
# ['mushy', 0.0]
# ['best', 0.75]
# ['true', 0.125]
# ['great', 0.0]
# ['large', 0.125]
# ['comfortable', -0.75]
# ['solid', 0.875]
# ['last', -0.25]
# ['better', 0.875]
# ['pocketable', 0.0]
# ['best', 0.75]
# ['new', 0.375]
# ['Low', -0.25]
# ['good', 0.75]
# ['distant', 0.0]
# ['best', 0.75]
# ['sound', 0.75]
# ['rich', 0.0]
# ['warm', 0.375]
# ['high', -0.125]
# ['deep', 0.125]
# ['great', 0.0]
# ['solid', 0.875]
# ['true', 0.125]
# ['good', 0.75]
# ['weak', -0.375]
# ['small', -0.375]
# ['newer', 0.375]
# ['constant', 0.375]
# ['small', -0.375]
# ['serious', 0.125]
# ['ok', 0.375]
# ['stuck', 0.0]
# ['cheap', -0.25]
# ['questionable', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['young', 0.0]
# ['available', 0.375]
# ['mobile', 0.0]
# ['documentary', 0.0]
# ['unfinished', -0.625]
# ['largest', 0.125]
# ['second', 0.0]
# ['documented', 0.0]
# ['old', 0.375]
# ['many', 0.0]
# ['broad', 0.125]
# ['unspecific', -0.125]
# ['unfathomable', -0.625]
# ['formative', 0.5]
# ['much', 0.0]
# ['journalistic', 0.0]
# ['valid', 0.125]
# ['side', 0.0]
# ['soft', -0.25]
# ['nostalgic', -0.75]
# ['logistical', 0.0]
# ['u', 0.0]
# ['u', 0.0]
# ['u', 0.0]
# ['older', 0.5]
# ['younger', -0.375]
# ['Serbian', 0.0]
# ['filthy', -0.875]
# ['vile', -0.5]
# ['long', 0.0]
# ['hard', -0.75]
# ['pivotal', 0.5]
# ['characteristic', 0.0]
# ['dramatic', 0.5]
# ['small', -0.375]
# ['European', 0.0]
# ['unheralded', -0.5]
# ['aesthetic', 0.0]
# ['mobile', 0.0]
# ['small', -0.375]
# ['external', 0.0]
# ['audible', 0.375]
# ['extensive', 0.0]
# ['sound', 0.75]
# ['unclean', -0.75]
# ['aware', 0.5]
# ['mobile', 0.0]
# ['enough', 0.125]
# ...
# ['usual', 0.125]
# ['next', 0.0]
# ['useful', 0.0]
# ['great', 0.0]
# ['resistant', -0.125]
# ['good', 0.75]
# ['big', 0.125]
# ['viable', 0.375]
# ['better', 0.875]
# ['big', 0.125]
# ['loud', 0.25]
# ['good', 0.75]
# ['able', 0.125]
# ['massive', 0.0]
# ['biggest', 0.125]
# ['difficult', -0.75]
# ['much', 0.0]
# ['smaller', -0.125]
# ['great', 0.0]
# ['useful', 0.0]
# ['myriad', 0.0]
# ['maximum', 0.25]
# ['workable', 0.375]
# ['light', -0.25]
# ['good', 0.75]
# ['better', 0.875]
# ['new', 0.375]
# ['last', -0.25]
# ['much', 0.0]
# ['different', 0.625]
# ['huge', -0.125]
# ['older', 0.5]
# ['happy', 0.875]
# ['best', 0.75]
# ['big', 0.125]
# ['best', 0.75]
# ['big', 0.125]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['American', 0.0]
# ['ethical', 0.0]
# ['live', 0.0]
# ['top', 0.0]
# ['important', 0.875]
# ['big', 0.125]
# ['substantial', 0.0]
# ['red', 0.0]
# ['Taiwanese', 0.0]
# ['several', -0.5]
# ['main', 0.375]
# ['British', 0.0]
# ['hard', -0.75]
# ['least', 0.0]
# ['South', 0.0]
# ['African', 0.0]
# ['private', -0.125]
# ['little', -0.375]
# ['original', 0.0]
# ['alternative', 0.125]
# ['free', 0.375]
# ['excellent', 1.0]
# ['Chinese', 0.0]
# ['many', 0.0]
# ['alternative', 0.125]
# ['open', -0.375]
# ['great', 0.0]
# ['easy', 0.375]
# ['alternative', 0.125]
# ['Japanese', 0.0]
# ['South', 0.0]
# ['Korean', 0.0]
# ['long', 0.0]
# ['Russian', 0.0]
# ['giant', 0.375]
# ['national', 0.0]
# ['many', 0.0]
# ['first', 0.0]
# ['European', 0.0]
# ['popular', 0.125]
# ['real', 0.0]
# ['past', -0.25]
# ['unlikely', -0.625]
# ['social', 0.0]
# ['improved', 0.375]
# ['American', 0.0]
# ['equivalent', 0.125]
# ['combined', 0.0]
# ['second', 0.0]
# ['largest', 0.125]
# ['social', 0.0]
# ['many', 0.0]
# ['virtual', 0.5]
# ['equivalent', 0.125]
# ['huge', -0.125]
# ['international', -0.5]
# ['many', 0.0]
# ['giant', 0.375]
# ['equivalent', 0.125]
# ['social', 0.0]
# ['digital', 0.125]
# ['biggest', 0.125]
# ['international', -0.5]
# ['recent', 0.0]
# ['small', -0.375]
# ['independent', 0.125]
# ['commercial', 0.0]
# ['third', 0.0]
# ['More', 0.0]
# ['recent', 0.0]
# ['electronic', 0.0]
# ['stronger', 0.5]
# ['political', 0.0]
# ['Turkish', 0.0]
# ['diplomatic', 0.0]
# ['American', 0.0]
# ['evangelical', 0.0]
# ['decisive', 0.0]
# ['current', 0.0]
# ['low', -0.25]
# ['Indian', 0.0]
# ['central', 0.0]
# ['new', 0.375]
# ['low', -0.25]
# ['slow', 0.0]
# ['last', -0.25]
# ['wider', 0.125]
# ['right', 0.0]
# ['Spanish', 0.0]
# ['top', 0.0]
# ['Indian', 0.0]
# ['latest', 0.125]
# ['exclusive', -0.75]
# ['new', 0.375]
# ['free', 0.375]
# ['much', 0.0]
# ['right', 0.0]
# ['last', -0.25]
# ['right', 0.0]
# ['popular', 0.125]
# ['satellite', 0.0]
# ['worldwide', 0.0]
# ['next', 0.0]
# ['right', 0.0]
# ['live', 0.0]
# ['global', -0.375]
# ['live', 0.0]
# ['big', 0.125]
# ['latest', 0.125]
# ['first', 0.0]
# ['successful', 0.625]
# ['possible', 0.5]
# ['south', 0.0]
# ['Asian', 0.0]
# ['crucial', 0.25]
# ['untapped', -0.625]
# ['social', 0.0]
# ['largest', 0.125]
# ['single', 0.0]
# ['first', 0.0]
# ['affordable', 0.0]
# ['mobile', 0.0]
# ['chief', 0.375]
# ['next', 0.0]
# ['local', 0.0]
# ['free', 0.375]
# ['select', 0.625]
# ['net', 0.0]
# ['original', 0.0]
# ['local', 0.0]
# ['plus', 0.0]
# ['main', 0.375]
# ['social', 0.0]
# ['Last', -0.25]
# ['right', 0.0]
# ['Indian', 0.0]
# ['suitable', 0.125]
# ['alternative', 0.125]
# ['wealthier', -0.25]
# ['cosmetic', 0.375]
# ['many', 0.0]
# ['extra', -0.5]
# ['free', 0.375]
# ['maximum', 0.25]
# ['weekly', 0.0]
# ['new', 0.375]
# ['many', 0.0]
# ['manual', 0.0]
# ['irregular', -0.5]
# ['national', 0.0]
# ['new', 0.375]
# ['early', 0.0]
# ['happy', 0.875]
# ['free', 0.375]
# ['old', 0.375]
# ['new', 0.375]
# ['powerful', 0.25]
# ['wealthy', -0.25]
# ['due', 0.0]
# ['second', 0.0]
# ['unofficial', -0.75]
# ['average', 0.0]
# ['due', 0.0]
# ['third', 0.0]
# ['irregular', -0.5]
# ['53', 0.0]
# ['largest', 0.125]
# ['national', 0.0]
# ['massive', 0.0]
# ['significant', 0.375]
# ['political', 0.0]
# ['South', 0.0]
# ['Korean', 0.0]
# ['longest', 0.0]
# ['Last', -0.25]
# ['average', 0.0]
# ['low', -0.25]
# ['additional', 0.0]
# ['similar', 0.125]
# ['average', 0.0]
# ['additional', 0.0]
# ['strong', 0.5]
# ['little', -0.375]
# ['different', 0.625]
# ['new', 0.375]
# ['long', 0.0]
# ['extra', -0.5]
# ['normal', -0.5]
# ['many', 0.0]
# ['private', -0.125]
# ['opening', 0.0]
# ['aggressive', 0.5]
# ['hefty', 0.125]
# ['difficult', -0.75]
# ['possible', 0.5]
# ['new', 0.375]
# ['second', 0.0]
# ['third', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['new', 0.375]
# ['largest', 0.125]
# ['legal', 0.0]
# ['stable', 0.0]
# ['high', -0.125]
# ['civil', 0.125]
# ['corporate', 0.0]
# ['second', 0.0]
# ['last', -0.25]
# ['popular', 0.125]
# ['available', 0.375]
# ['available', 0.375]
# ['unusual', -0.5]
# ['main', 0.375]
# ['good', 0.75]
# ['outside', 0.0]
# ['poor', -0.75]
# ['susceptible', 0.5]
# ['greatest', 0.875]
# ['malicious', -0.375]
# ['outside', 0.0]
# ['vulnerable', 0.125]
# ['malicious', -0.375]
# ['wrong', -0.625]
# ['hypothetical', 0.125]
# ['malicious', -0.375]
# ['naive', 0.5]
# ['additional', 0.0]
# ['young', 0.0]
# ['immune', 0.0]
# ['free', 0.375]
# ['best', 0.75]
# ['immediate', 0.0]
# ['general', 0.0]
# ['popular', 0.125]
# ['vulnerable', 0.125]
# ['unknown', -0.25]
# ['malicious', -0.375]
# ['long', 0.0]
# ['mixed', -0.125]
# ['effective', 0.125]
# ['fine', 0.375]
# ['latest', 0.125]
# ['larger', 0.125]
# ['lasting', -0.625]
# ['last', -0.25]
# ['replete', 0.25]
# ['bigger', 0.125]
# ['last', -0.25]
# ['heavier', 0.0]
# ['larger', 0.125]
# ['heaviest', 0.0]
# ['premium', 0.75]
# ['busy', 0.375]
# ['first', 0.0]
# ['able', 0.125]
# ['popular', 0.125]
# ['exclusive', -0.75]
# ['limited', 0.0]
# ['available', 0.375]
# ['traditional', 0.0]
# ['available', 0.375]
# ['available', 0.375]
# ['new', 0.375]
# ['similar', 0.125]
# ['bottom', 0.0]
# ['dual', 0.0]
# ['variable', 0.375]
# ['optical', 0.0]
# ['shot', 0.0]
# ['lower', -0.25]
# ['easier', 0.375]
# ['mobile', 0.0]
# ['loyal', 0.5]
# ['new', 0.375]
# ['wary', 0.625]
# ['previous', 0.0]
# ['enough', 0.125]
# ['loyal', 0.5]
# ['able', 0.125]
# ['recent', 0.0]
# ['top', 0.0]
# ['colour', 0.625]
# ['black', -0.375]
# ['available', 0.375]
# ['new', 0.375]
# ['new', 0.375]
# ['current', 0.0]
# ['available', 0.375]
# ['new', 0.375]
# ['new', 0.375]
# ['greatest', 0.875]
# ['best', 0.75]
# ['big', 0.125]
# ['next', 0.0]
# ['new', 0.375]
# ['new', 0.375]
# ['biggest', 0.125]
# ['colourful', 0.125]
# ['new', 0.375]
# ['least', 0.0]
# ['Right', 0.0]
# ['recent', 0.0]
# ['last', -0.25]
# ['much', 0.0]
# ['free', 0.375]
# ['eligible', 0.5]
# ['biggest', 0.125]
# ['traditional', 0.0]
# ['new', 0.375]
# ['traditional', 0.0]
# ['right', 0.0]
# ['last', -0.25]
# ['similar', 0.125]
# ['double', 0.25]
# ['back', 0.0]
# ['needed', 0.125]
# ['mean', 0.0]
# ['small', -0.375]
# ['useful', 0.0]
# ['little', -0.375]
# ['perfect', 0.5]
# ['top', 0.0]
# ['dramatic', 0.5]
# ['able', 0.125]
# ['least', 0.0]
# ['biggest', 0.125]
# ['individual', 0.0]
# ['predictable', 0.0]
# ['manual', 0.0]
# ['several', -0.5]
# ['accessible', 0.625]
# ['easy', 0.375]
# ['particular', 0.0]
# ['right', 0.0]
# ['magnified', -0.5]
# ['fine', 0.375]
# ['easier', 0.375]
# ['tiny', 0.0]
# ['able', 0.125]
# ['idle', -0.625]
# ['mean', 0.0]
# ['recent', 0.0]
# ['big', 0.125]
# ['new', 0.375]
# ['similar', 0.125]
# ['live', 0.0]
# ['select', 0.625]
# ['much', 0.0]
# ['certain', -0.375]
# ['visual', 0.0]
# ['audible', 0.375]
# ['available', 0.375]
# ['available', 0.375]
# ['official', 0.0]
# ['available', 0.375]
# ['possible', 0.5]
# ['physical', 0.0]
# ['mobile', 0.0]
# ['fastest', 0.0]
# ['active', -0.125]
# ['official', 0.0]
# ['last', -0.25]
# ['outside', 0.0]
# ['direct', -0.25]
# ['major', 0.625]
# ['mobile', 0.0]
# ['able', 0.125]
# ['smooth', 0.25]
# ['trusted', 0.5]
# ['high', -0.125]
# ['enormous', 0.0]
# ['broad', 0.125]
# ['open', -0.375]
# ['fake', -0.75]
# ['malicious', -0.375]
# ['open', -0.375]
# ['various', -0.25]
# ['third', 0.0]
# ['available', 0.375]
# ['third', 0.0]
# ['mobile', 0.0]
# ['main', 0.375]
# ['tougher', -0.75]
# ['lucrative', 0.75]
# ['new', 0.375]
# ['mobile', 0.0]
# ['Chinese', 0.0]
# ['successful', 0.625]
# ['large', 0.125]
# ['exclusive', -0.75]
# ['small', -0.375]
# ['key', 0.0]
# ['cross', 0.0]
# ['mobile', 0.0]
# ['free', 0.375]
# ['sign', 0.0]
# ['last', -0.25]
# ['new', 0.375]
# ['mid', 0.0]
# ['hot', 0.0]
# ['legendary', 0.875]
# ['free', 0.375]
# ['last', -0.25]
# ['pink', 0.0]
# ['chicken', -0.5]
# ['worst', -0.5]
# ['dead', -0.75]
# ['problematic', 0.0]
# ['memorable', 0.125]
# ['good', 0.75]
# ['bad', -0.625]
# ['bad', -0.625]
# ['viral', 0.0]
# ['expensive', 0.5]
# ['last', -0.25]
# ['limited', 0.0]
# ['chicken', -0.5]
# ['special', 0.0]
# ['last', -0.25]
# ['unlikely', -0.625]
# ['chicken', -0.5]
# ['u', 0.0]
# ['chicken', -0.5]
# ['u', 0.0]
# ['vocational', 0.0]
# ['chicken', -0.5]
# ['best', 0.75]
# ['difficult', -0.75]
# ['successful', 0.625]
# ['willing', 0.5]
# ['difficult', -0.75]
# ['different', 0.625]
# ['total', 0.0]
# ['creative', 0.0]
# ['better', 0.875]
# ['nervous', 0.125]
# ['u', 0.0]
# ['best', 0.75]
# ['final', 0.0]
# ['recent', 0.0]
# ['inescapable', -0.5]
# ['chicken', -0.5]
# ['worth', 0.25]
# ['regular', 0.0]
# ['little', -0.375]
# ['whole', 0.125]
# ['essential', 0.125]
# ['dry', -0.25]
# ['big', 0.125]
# ['pretty', 0.75]
# ['decent', 0.875]
# ['substantial', 0.0]
# ['defensive', 0.0]
# ['weird', -0.75]
# ['mum', 0.0]
# ['certain', -0.375]
# ['big', 0.125]
# ['young', 0.0]
# ['forgettable', 0.5]
# ['steady', -0.5]
# ['dead', -0.75]
# ['mean', 0.0]
# ['normal', -0.5]
# ['viral', 0.0]
# ['full', 0.0]
# ['demographic', 0.0]
# ['certain', -0.375]
# ['young', 0.0]
# ['black', -0.375]
# ['successful', 0.625]
# ['good', 0.75]
# ['next', 0.0]
# ['demographic', 0.0]
# ['much', 0.0]
# ['new', 0.375]
# ['international', -0.5]
# ['larger', 0.125]
# ['hard', -0.75]
# ['replaceable', 0.5]
# ['obvious', 0.5]
# ['cool', 0.125]
# ['sleek', 0.375]
# ['physical', 0.0]
# ['successful', 0.625]
# ['white', -0.25]
# ['fundamental', 0.0]
# ['latest', 0.125]
# ['lowest', -0.125]
# ['domestic', 0.0]
# ['new', 0.375]
# ['lowest', -0.125]
# ['high', -0.125]
# ['global', -0.375]
# ['recent', 0.0]
# ['unlikely', -0.625]
# ['easier', 0.375]
# ['recent', 0.0]
# ['biggest', 0.125]
# ['huge', -0.125]
# ['suspect', -0.5]
# ['next', 0.0]
# ['low', -0.25]
# ['late', 0.0]
# ['latest', 0.125]
# ['positive', 0.625]
# ['low', -0.25]
# ['unlikely', -0.625]
# ['small', -0.375]
# ['recent', 0.0]
# ['much', 0.0]
# ['larger', 0.125]
# ['weak', -0.375]
# ['first', 0.0]
# ['key', 0.0]
# ['next', 0.0]
# ['ideal', 0.75]
# ['much', 0.0]
# ['second', 0.0]
# ['largest', 0.125]
# ['second', 0.0]
# ['first', 0.0]
# ['split', 0.0]
# ['top', 0.0]
# ['Multiple', 0.0]
# ['largest', 0.125]
# ['recent', 0.0]
# ['weak', -0.375]
# ['second', 0.0]
# ['significant', 0.375]
# ['first', 0.0]
# ['top', 0.0]
# ['second', 0.0]
# ['due', 0.0]
# ['willing', 0.5]
# ['numerous', -0.125]
# ['previous', 0.0]
# ['worst', -0.5]
# ['big', 0.125]
# ['second', 0.0]
# ['impressive', 0.125]
# ['least', 0.0]
# ['unknown', -0.25]
# ['competitive', 0.0]
# ['top', 0.0]
# ['popular', 0.125]
# ['top', 0.0]
# ['Chinese', 0.0]
# ['key', 0.0]
# ['Chinese', 0.0]
# ['private', -0.125]
# ['Chinese', 0.0]
# ['subject', -0.125]
# ['good', 0.75]
# ['significant', 0.375]
# ['major', 0.625]
# ['higher', 0.375]
# ['steady', -0.5]
# ['third', 0.0]
# ['total', 0.0]
# ['last', -0.25]
# ['half', 0.0]
# ['last', -0.25]
# ['fourth', 0.0]
# ['American', 0.0]
# ['much', 0.0]
# ['much', 0.0]
# ['insolent', -0.25]
# ['long', 0.0]
# ['vague', -0.125]
# ['sour', -0.375]
# ['proverbial', 0.0]
# ['whole', 0.125]
# ['many', 0.0]
# ['famous', 0.375]
# ['third', 0.0]
# ['executive', 0.0]
# ['real', 0.0]
# ['actual', -0.375]
# ['last', -0.25]
# ['better', 0.875]
# ['recent', 0.0]
# ['biggest', 0.125]
# ['social', 0.0]
# ['next', 0.0]
# ['perfect', 0.5]
# ['classic', 0.375]
# ['content', 0.0]
# ['particular', 0.0]
# ['top', 0.0]
# ['proper', 0.75]
# ['responsible', 0.625]
# ['controversial', 0.5]
# ['biological', 0.0]
# ['outside', 0.0]
# ['trashy', -0.875]
# ['repulsive', -0.75]
# ['able', 0.125]
# ['biggest', 0.125]
# ['eternal', 0.25]
# ['next', 0.0]
# ['unscripted', -0.625]
# ['least', 0.0]
# ['indelible', -0.125]
# ['good', 0.75]
# ['best', 0.75]
# ['different', 0.625]
# ['monthly', 0.0]
# ['old', 0.375]
# ['mobile', 0.0]
# ['many', 0.0]
# ['recent', 0.0]
# ['little', -0.375]
# ['latest', 0.125]
# ['Chinese', 0.0]
# ['mobile', 0.0]
# ['able', 0.125]
# ['domestic', 0.0]
# ['old', 0.375]
# ['usual', 0.125]
# ['teen', 0.125]
# ['social', 0.0]
# ['good', 0.75]
# ['pricey', 0.5]
# ['online', 0.0]
# ['best', 0.75]
# ['free', 0.375]
# ['previous', 0.0]
# ['next', 0.0]
# ['great', 0.0]
# ['great', 0.0]
# ['old', 0.375]
# ['old', 0.375]
# ['big', 0.125]
# ['happy', 0.875]
# ['u', 0.0]
# ['prepared', 0.625]
# ['latest', 0.125]
# ['free', 0.375]
# ['expensive', 0.5]
# ['better', 0.875]
# ['cheaper', -0.25]
# ['good', 0.75]
# ['absolute', 0.5]
# ['competitive', 0.0]
# ['best', 0.75]
# ['free', 0.375]
# ['better', 0.875]
# ['unlocked', -0.5]
# ['local', 0.0]
# ['best', 0.75]
# ['best', 0.75]
# ['great', 0.0]
# ['much', 0.0]
# ['red', 0.0]
# ['normal', -0.5]
# ['top', 0.0]
# ['old', 0.375]
# ['brilliant', 0.875]
# ['young', 0.0]
# ['human', 0.0]
# ['huge', -0.125]
# ['outside', 0.0]
# ['early', 0.0]
# ['disappointed', -0.5]
# ['next', 0.0]
# ['urgent', 0.0]
# ['different', 0.625]
# ['old', 0.375]
# ['local', 0.0]
# ['several', -0.5]
# ['wound', 0.0]
# ['like', -0.25]
# ['complete', 0.0]
# ['upset', -0.875]
# ['unexpected', -0.25]
# ['many', 0.0]
# ['representative', 0.0]
# ['u', 0.0]
# ['major', 0.625]
# ['rare', 0.25]
# ['little', -0.375]
# ['new', 0.375]
# ['homespun', -0.25]
# ['first', 0.0]
# ['important', 0.875]
# ['experiential', 0.0]
# ['influential', 0.125]
# ['next', 0.0]
# ['competitive', 0.0]
# ['amorphous', -0.5]
# ['real', 0.0]
# ['good', 0.75]
# ['easier', 0.375]
# ['last', -0.25]
# ['great', 0.0]
# ['economic', 0.0]
# ['industrial', 0.0]
# ['outer', 0.0]
# ['small', -0.375]
# ['manipulative', 0.25]
# ['right', 0.0]
# ['unique', 0.375]
# ['future', -0.125]
# ['local', 0.0]
# ['special', 0.0]
# ['clever', 0.5]
# ['valuable', 0.0]
# ['global', -0.375]
# ['tangible', 0.5]
# ['incredible', 0.0]
# ['intangible', -0.625]
# ['intangible', -0.625]
# ['magical', -0.25]
# ['old', 0.375]
# ['accessory', 0.375]
# ['huge', -0.125]
# ['reasonable', 0.5]
# ['capable', 0.125]
# ['hard', -0.75]
# ['actual', -0.375]
# ['overpriced', 0.125]
# ['good', 0.75]
# ['important', 0.875]
# ['last', -0.25]
# ['helpful', 0.25]
# ['special', 0.0]
# ['second', 0.0]
# ['unchanged', -0.625]
# ['soft', -0.25]
# ['simple', -0.25]
# ['much', 0.0]
# ['popular', 0.125]
# ['nice', 0.875]
# ['animal', 0.125]
# ['human', 0.0]
# ['universal', 0.0]
# ['easy', 0.375]
# ['human', 0.0]
# ['human', 0.0]
# ['animal', 0.125]
# ['perfect', 0.5]
# ['universal', 0.0]
# ['new', 0.375]
# ['unique', 0.375]
# ['young', 0.0]
# ['virtual', 0.5]
# ['online', 0.0]
# ['valuable', 0.0]
# ['senior', 0.375]
# ['particular', 0.0]
# ['old', 0.375]
# ['old', 0.375]
# ['additional', 0.0]
# ['accessory', 0.375]
# ['digital', 0.125]
# ['experiential', 0.0]
# ['close', 0.0]
# ['directional', 0.0]
# ['interactive', 0.0]
# ['specific', 0.0]
# ['directional', 0.0]
# ['specific', 0.0]
# ['sound', 0.75]
# ['similar', 0.125]
# ['memorable', 0.125]
# ['directional', 0.0]
# ['interactive', 0.0]
# ['burdensome', -0.25]
# ['physical', 0.0]
# ['personal', 0.0]
# ['traditional', 0.0]
# ['easy', 0.375]
# ['annual', 0.0]
# ['total', 0.0]
# ['last', -0.25]
# ['little', -0.375]
# ['half', 0.0]
# ['main', 0.375]
# ['net', 0.0]
# ['previous', 0.0]
# ['short', 0.0]
# ['big', 0.125]
# ['new', 0.375]
# ['open', -0.375]
# ['new', 0.375]
# ['good', 0.75]
# ['negative', -0.875]
# ['avoidable', 0.625]
# ['whole', 0.125]
# ['mean', 0.0]
# ['steady', -0.5]
# ['last', -0.25]
# ['factual', 0.5]
# ['due', 0.0]
# ['able', 0.125]
# ['full', 0.0]
# ['last', -0.25]
# ['north', 0.0]
# ['inside', 0.0]
# ['willing', 0.5]
# ['panicked', 0.0]
# ['broken', -0.125]
# ['new', 0.375]
# ['likely', 0.5]
# ['bigger', 0.125]
# ['front', 0.0]
# ['shattered', -0.5]
# ['new', 0.375]
# ['compressed', 0.0]
# ['probabilistic', 0.0]
# ['average', 0.0]
# ['multiple', 0.0]
# ['new', 0.375]
# ['average', 0.0]
# ['rough', -0.375]
# ['previous', 0.0]
# ['resistant', -0.125]
# ['multiple', 0.0]
# ['higher', 0.375]
# ['multiple', 0.0]
# ['general', 0.0]
# ['similar', 0.125]
# ['older', 0.5]
# ['current', 0.0]
# ['older', 0.5]
# ['next', 0.0]
# ['several', -0.5]
# ['top', 0.0]
# ['second', 0.0]
# ['multiple', 0.0]
# ['new', 0.375]
# ['next', 0.0]
# ['old', 0.375]
# ['west', 0.0]
# ['last', -0.25]
# ['tiny', 0.0]
# ['last', -0.25]
# ['old', 0.375]
# ['overwhelming', 0.0]
# ['senior', 0.375]
# ['north', 0.0]
# ['west', 0.0]
# ['different', 0.625]
# ['general', 0.0]
# ['clear', 0.5]
# ['royal', 0.0]
# ['potential', -0.25]
# ['minimum', 0.0]
# ['martial', 0.125]
# ['military', 0.0]
# ['successful', 0.625]
# ['many', 0.0]
# ['successful', 0.625]
# ['online', 0.0]
# ['new', 0.375]
# ['busy', 0.375]
# ['great', 0.0]
# ['hard', -0.75]
# ['strong', 0.5]
# ['unable', -0.75]
# ['different', 0.625]
# ['vast', -0.125]
# ['elderly', 0.5]
# ['former', -0.125]
# ['online', 0.0]
# ['real', 0.0]
# ['former', -0.125]
# ['desperate', -0.5]
# ['torn', -0.75]
# ['glossy', 0.0]
# ['similar', 0.125]
# ['strange', 0.25]
# ['sign', 0.0]
# ['unaware', -0.25]
# ['Last', -0.25]
# ['entire', 0.0]
# ['enough', 0.125]
# ['last', -0.25]
# ['similar', 0.125]
# ['low', -0.25]
# ['maximum', 0.25]
# ['routine', 0.125]
# ['Good', 0.75]
# ['clear', 0.5]
# ['random', 0.125]
# ['long', 0.0]
# ['awaited', 0.25]
# ['aware', 0.5]
# ['technical', 0.125]

# %%
#Final printing and to count the number of articles that are positive, negative or neutral based on the sentiment values

article_senti = []
for article in net_senti:
    sentiment = 0
    article_word_count = 0
    for senti in article:
        print(senti[0], senti[1])
        sentiment += senti[1]
        article_word_count += 1
    print("\n********************************************\nTotal Sentiment: ", sentiment)
    print("Word Count In Article: ", article_word_count, "\n********************************************")
    print("\n**********************\n NEXT ARTICLE \n**********************")
    article_senti.append(sentiment)
# Out:
# small -0.375
# mean 0.0
# last -0.25
# new 0.375
# cheapest -0.25
# cheaper -0.25
# last -0.25
# cheaper -0.25
# bigger 0.125
# larger 0.125
# similar 0.125
# good 0.75
# inky 0.0
# black -0.375
# bold 0.375
# smooth 0.25
# high -0.125
# brightest 0.125
# available 0.375
# fine 0.375
# bright 0.125
# direct -0.25
# large 0.125
# new 0.375
# black -0.375
# similar 0.125
# super 0.625
# white -0.25
# slender 0.5
# wide 0.125
# lightest -0.25
# easiest 0.375
# top 0.0
# able 0.125
# best 0.75
# smaller -0.125
# available 0.375
# wide 0.125
# wide 0.125
# fluid 0.0
# speedy 0.5
# poor -0.75
# last -0.25
# dead -0.75
# ambient 0.375
# good 0.75
# primary 0.375
# last -0.25
# last -0.25
# similar 0.125
# last -0.25
# least 0.0
# heavy 0.0
# full 0.0
# first 0.0
# latest 0.125
# complete 0.0
# wide 0.125
# full 0.0
# least 0.0
# new 0.375
# natural 0.25
# impressive 0.125
# larger 0.125
# much 0.0
# faster 0.0
# many 0.0
# excellent 1.0
# new 0.375
# commercial 0.0
# ambient 0.375
# impressive 0.125
# new 0.375
# similar 0.125
# fine 0.375
# straight -0.375
# last -0.25
# biggest 0.125
# third 0.0
# tedious -0.25
# new 0.375
# small -0.375
# traditional 0.0
# best 0.75
# new 0.375
# dual 0.0
# different 0.625
# fantastic 0.375
# difficult -0.75
# ultra 0.0
# low -0.25
# wide 0.125
# good 0.75
# good 0.75
# second 0.0
# new 0.375
# free 0.375
# high -0.125
# full 0.0
# original 0.0
# previous 0.0
# smaller -0.125
# great 0.0
# poor -0.75
# good 0.75
# real 0.0
# many 0.0
# smaller -0.125
# good 0.75
# big 0.125
# novel 0.25
# natural 0.25
# next 0.0
# impressive 0.125
# third 0.0
# lower -0.25
# bigger 0.125
# best 0.75
# great 0.0
# terrible -0.625
# ready 0.0
# best 0.75
# small -0.375
# available 0.375
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  11.375
# Word Count In Article:  130
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# dark 0.0
# dark 0.0
# dark 0.0
# dark 0.0
# odd 0.125
# dead -0.75
# annual 0.0
# small -0.375
# fancy -0.375
# massive 0.0
# double 0.25
# unnoticed -0.125
# best 0.75
# safe 0.0
# outside 0.0
# local 0.0
# strange 0.25
# organised 0.0
# new 0.375
# full 0.0
# open -0.375
# last -0.25
# least 0.0
# local 0.0
# new 0.375
# ancient 0.0
# 19th 0.0
# religious 0.0
# secular 0.0
# average 0.0
# nationwide 0.0
# total 0.0
# spent 0.125
# sweet 0.0
# lucrative 0.75
# additional 0.0
# freakish 0.625
# mad 0.125
# general 0.0
# average 0.0
# second 0.0
# annual 0.0
# popular 0.125
# top 0.0
# biggest 0.125
# largest 0.125
# full 0.0
# artistic 0.0
# individual 0.0
# constant 0.375
# ancient 0.0
# west 0.0
# theatrical 0.0
# pet 0.25
# several -0.5
# evil -0.875
# popular 0.125
# favourite 0.125
# Meridian 0.0
# several -0.5
# top 0.0
# scary -0.75
# main 0.375
# autumnal 0.0
# huge -0.125
# recent 0.0
# spent 0.125
# outside 0.0
# related 0.0
# old 0.375
# historic 0.0
# keen 0.125
# beautiful 0.75
# Georgian 0.0
# aesthetic 0.0
# whole 0.125
# local 0.0
# haunted 0.125
# spooky -0.375
# hidden -0.375
# creepy -0.875
# old 0.375
# spooky -0.375
# quality 0.625
# best 0.75
# sweet 0.0
# resident 0.0
# lucky 0.75
# average 0.0
# capital 0.0
# western 0.0
# supernatural -0.75
# biggest 0.125
# massive 0.0
# annual 0.0
# recent 0.0
# extra -0.5
# happy 0.875
# cultural 0.0
# better 0.875
# polish 0.0
# best 0.75
# weekly 0.0
#
# ********************************************
# Total Sentiment:  3.875
# Word Count In Article:  103
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# least 0.0
# undisclosed -0.25
# digital 0.125
# full 0.0
# competitive 0.0
# unprecedented 0.0
# huge -0.125
# digital 0.125
# unaccountable -0.375
# unregulated -0.625
# u 0.0
# rigorous 0.125
# possible 0.5
# single 0.0
# physical 0.0
# wearable 0.25
# sensitive 0.0
# significant 0.375
# online 0.0
# digital 0.125
# minimum 0.0
# third 0.0
#
# ********************************************
# Total Sentiment:  0.25
# Word Count In Article:  22
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# latest 0.125
# old 0.375
# special 0.0
# direct -0.25
# black -0.375
# super 0.625
# white -0.25
# variant -0.375
# big 0.125
# certain -0.375
# smoother 0.25
# colourful 0.125
# good 0.75
# new 0.375
# new 0.375
# large 0.125
# big 0.125
# textured 0.125
# thick 0.0
# wide 0.125
# bottom 0.0
# colour 0.625
# least 0.0
# top 0.0
# used 0.0
# fast 0.0
# super 0.625
# Most 0.0
# happy 0.875
# likely 0.5
# responsive 0.0
# previous 0.0
# great 0.0
# last -0.25
# mean 0.0
# enough 0.125
# alive 0.125
# primary 0.375
# last -0.25
# last -0.25
# shy 0.0
# similar 0.125
# full 0.0
# first 0.0
# latest 0.125
# polish 0.0
# exclusive -0.75
# third 0.0
# wide 0.125
# full 0.0
# large 0.125
# easier 0.375
# least 0.0
# major 0.625
# big 0.125
# new 0.375
# natural 0.25
# similar 0.125
# impressive 0.125
# new 0.375
# great 0.0
# open -0.375
# faster 0.0
# impressive 0.125
# real 0.0
# new 0.375
# perfect 0.5
# sound 0.75
# impressive 0.125
# new 0.375
# commercial 0.0
# new 0.375
# ambient 0.375
# ready 0.0
# novel 0.25
# new 0.375
# new 0.375
# little -0.375
# fast 0.0
# simple -0.25
# open -0.375
# open -0.375
# third 0.0
# new 0.375
# Most 0.0
# mean 0.0
# strong 0.5
# fantastic 0.375
# last -0.25
# Fewer 0.0
# traditional 0.0
# least 0.0
# best 0.75
# different 0.625
# dual 0.0
# best 0.75
# available 0.375
# full 0.0
# difficult -0.75
# firm 0.25
# fine 0.375
# optical 0.0
# digital 0.125
# astrological 0.0
# last -0.25
# single 0.0
# good 0.75
# solid 0.875
# popular 0.125
# free 0.375
# full 0.0
# new 0.375
# smaller -0.125
# great 0.0
# incredible 0.0
# new 0.375
# natural 0.25
# next 0.0
# smartest 0.5
# good 0.75
# great 0.0
# bright 0.125
# top 0.0
# new 0.375
# sure -0.25
# biggest 0.125
# ready 0.0
# great 0.0
# real 0.0
# average 0.0
# live 0.0
# mean 0.0
# reasonable 0.5
# free 0.375
# best 0.75
# bigger 0.125
# magic -0.25
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  18.0
# Word Count In Article:  143
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# new 0.375
# popular 0.125
# true 0.125
# traditional 0.0
# similar 0.125
# current 0.0
# complete 0.0
# white -0.25
# ultra 0.0
# compact 0.0
# plastic 0.0
# sound 0.75
# outside 0.0
# impossible -0.75
# noisy 0.0
# public -0.125
# mean 0.0
# crank 0.25
# sound 0.75
# due 0.0
# new 0.375
# unwanted -0.25
# lower -0.25
# individual 0.0
# continuous 0.0
# active -0.125
# additional 0.0
# free 0.375
# resistant -0.125
# true 0.125
#
# ********************************************
# Total Sentiment:  1.5
# Word Count In Article:  30
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# general 0.0
# digital 0.125
# basic 0.0
# new 0.375
# fit 0.5
# better 0.875
# exact 0.0
# major 0.625
# graphic 0.0
# low -0.25
# high -0.125
# high -0.125
# little -0.375
# stuck 0.0
# hard -0.75
# obvious 0.5
# digital 0.125
# cheap -0.25
# free 0.375
# easy 0.375
# x 0.0
# much 0.0
# bigger 0.125
# Second 0.0
# rapid 0.0
# chuffed 0.125
# fit 0.5
# high -0.125
# fit 0.5
# extra -0.5
# massive 0.0
# short 0.0
# new 0.375
# current 0.0
# last -0.25
# dead -0.75
# good 0.75
# double 0.25
# new 0.375
# future -0.125
# real 0.0
# ultra 0.0
# thin 0.0
# next 0.0
# good 0.75
# high -0.125
# cheap -0.25
# convenient 0.375
# enough 0.125
# built 0.0
# much 0.0
# possible 0.5
# usable 0.0
# mobile 0.0
# green -0.125
# alternative 0.125
# several -0.5
# external 0.0
# hard -0.75
# physical 0.0
# several -0.5
# alternative 0.125
# local 0.0
# available 0.375
# extra -0.5
# extra -0.5
# hard -0.75
# main 0.375
# much 0.0
# several -0.5
# larger 0.125
# smaller -0.125
# extra -0.5
# similar 0.125
# new 0.375
# new 0.375
# better 0.875
# second 0.0
# original 0.0
# extra -0.5
# significant 0.375
# significant 0.375
# better 0.875
# better 0.875
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  4.5
# Word Count In Article:  89
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# top 0.0
# lukewarm 0.0
# wearable 0.25
# expected -0.125
# latest 0.125
# likely 0.5
# unfamiliar -0.625
# important 0.875
# alternative 0.125
# extraordinary 0.625
# last -0.25
# larger 0.125
# small -0.375
# important 0.875
# important 0.875
# telling 0.0
# essential 0.125
# permanent -0.625
# elaborate 0.625
# many 0.0
# comfortable -0.75
# best 0.75
# Swiss 0.0
# heavy 0.0
# larger 0.125
# resistant -0.125
# bright 0.125
# visible 0.125
# rectangular 0.125
# circular 0.25
# last -0.25
# little -0.375
# original 0.0
# better 0.875
# many 0.0
# wild 0.0
# particular 0.0
# little -0.375
# better 0.875
# different 0.625
# many 0.0
# sizeable 0.0
# perfect 0.5
# new 0.375
# numeral 0.0
# round 0.25
# analogue 0.0
# hard -0.75
# small -0.375
# picky 0.0
# high -0.125
# little -0.375
# Most 0.0
# third 0.0
# straight -0.375
# full 0.0
# digital 0.125
# great 0.0
# big 0.125
# great 0.0
# poor -0.75
# great 0.0
# complex 0.0
# great 0.0
# major 0.625
# best 0.75
# available 0.375
# huge -0.125
# usual 0.125
# enough 0.125
# good 0.75
# abnormal -0.75
# high -0.125
# second 0.0
# real 0.0
# irregular -0.5
# Other -0.625
# daily 0.0
# complete 0.0
# third 0.0
# menstrual 0.0
# environmental 0.0
# similar 0.125
# old 0.375
# hard -0.75
# simple -0.25
# hard -0.75
# public -0.125
# similar 0.125
# useful 0.0
# various -0.25
# different 0.625
# available 0.375
# ceramic 0.0
# second 0.0
# best 0.75
# best 0.75
# solid 0.875
# first 0.0
# last -0.25
# meaningful 0.125
# great 0.0
# close 0.0
# least 0.0
# circular 0.25
# typical 0.125
# best 0.75
# right 0.0
# better 0.875
# best 0.75
# small -0.375
# available 0.375
# true 0.125
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  8.75
# Word Count In Article:  118
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# absolute 0.5
# minor -0.375
# best 0.75
# good 0.75
# good 0.75
# better 0.875
# bad -0.625
# mid 0.0
# faster 0.0
# difficult -0.75
# thin 0.0
# side 0.0
# slim 0.5
# attractive 0.875
# modern -0.25
# excellent 1.0
# big 0.125
# tall 0.5
# wide 0.125
# much 0.0
# manageable 0.625
# wide 0.125
# right 0.0
# smaller -0.125
# smaller -0.125
# wide 0.125
# palpable 0.625
# gorgeous 0.75
# new 0.375
# vertical 0.0
# wired 0.0
# newer 0.375
# graphic 0.0
# able 0.125
# fastest 0.0
# available 0.375
# different 0.625
# available 0.375
# available 0.375
# new 0.375
# black -0.375
# available 0.375
# limited 0.0
# solid 0.875
# longer 0.0
# last -0.25
# primary 0.375
# usual 0.125
# wireless 0.0
# internal 0.0
# full 0.0
# latest 0.125
# first 0.0
# standard 0.0
# colour 0.625
# full 0.0
# new 0.375
# new 0.375
# previous 0.0
# biggest 0.125
# right 0.0
# right 0.0
# lower -0.25
# third 0.0
# vast -0.125
# large 0.125
# easier 0.375
# traditional 0.0
# available 0.375
# welcome 0.5
# least 0.0
# monthly 0.0
# faster 0.0
# excellent 1.0
# optical 0.0
# standard 0.0
# traditional 0.0
# capacitive 0.0
# main 0.375
# ultra 0.0
# wide 0.125
# primary 0.375
# great 0.0
# capable 0.125
# good 0.75
# best 0.75
# effective 0.125
# used 0.0
# ultra 0.0
# wide 0.125
# good 0.75
# dull 0.125
# main 0.375
# optical 0.0
# cheaper -0.25
# digital 0.125
# best 0.75
# ultra 0.0
# wide 0.125
# great 0.0
# new 0.375
# super 0.625
# minimum 0.0
# interesting 0.375
# rich 0.0
# human 0.0
# good 0.75
# yellow 0.0
# capable 0.125
# great 0.0
# rich 0.0
# good 0.75
# clear 0.5
# blue 0.0
# best 0.75
# exact 0.0
# best 0.75
# improved 0.375
# debatable 0.0
# rapid 0.0
# new 0.375
# great 0.0
# spectacular 0.25
# new 0.375
# easier 0.375
# latest 0.125
# top 0.0
# hard -0.75
# expandable 0.0
# good 0.75
# heavy 0.0
# gigantic 0.0
# gorgeous 0.75
# fast 0.0
# free 0.375
# manageable 0.625
# fast 0.0
# last -0.25
# better 0.875
# biggest 0.125
# cheaper -0.25
# smaller -0.125
# easier 0.375
# biggest 0.125
# best 0.75
# fastest 0.0
# worth 0.25
# bigger 0.125
# magic -0.25
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  29.375
# Word Count In Article:  155
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# next 0.0
# iterative -0.25
# western 0.0
# visual 0.0
# high -0.125
# latter 0.0
# perfect 0.5
# immediate 0.0
# deep 0.125
# cultural 0.0
# cultural 0.0
# hard -0.75
# ongoing 0.0
# black -0.375
# new 0.375
# indie -0.625
# Japanese 0.0
# national 0.0
# average 0.0
# offensive -0.375
# banal -0.375
# excellent 1.0
# diverse 0.125
# new 0.375
# available 0.375
# cultural 0.0
# accessible 0.625
# easiest 0.375
# grassroots 0.0
# blue 0.0
# quality 0.625
# simplest -0.25
# last -0.25
# cool 0.125
# last -0.25
# big 0.125
# former -0.125
# third 0.0
# Next 0.0
# Other -0.625
# last -0.25
# strange 0.25
# aesthetic 0.0
# vast -0.125
# musical 0.25
# independent 0.125
# legitimate -0.25
# branded 0.125
# cultural 0.0
# imperative 0.0
# bereft -0.75
# cultural 0.0
# bracing 0.375
# glorious -0.375
# alcoholic 0.0
# best 0.75
# unobtrusive -0.625
# European 0.0
# public -0.125
# important 0.875
# psychic 0.375
# many 0.0
# important 0.875
# global -0.375
# true 0.125
# artistic 0.0
# cultural 0.0
# perfect 0.5
# new 0.375
# new 0.375
#
# ********************************************
# Total Sentiment:  2.875
# Word Count In Article:  70
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# brilliant 0.875
# smaller -0.125
# cheaper -0.25
# last -0.25
# new 0.375
# much 0.0
# better 0.875
# new 0.375
# small -0.375
# big 0.125
# new 0.375
# smaller -0.125
# cheaper -0.25
# longer 0.0
# smaller -0.125
# fresh -0.25
# massive 0.0
# smooth 0.25
# flat 0.125
# front 0.0
# narrow 0.0
# easiest 0.375
# large 0.125
# new 0.375
# large 0.125
# circular 0.25
# new 0.375
# triple 0.0
# attractive 0.875
# normal -0.5
# graphic 0.0
# many 0.0
# available 0.375
# cheapest -0.25
# fly -0.5
# enjoyable 0.25
# mundane 0.125
# social 0.0
# pleasurable 0.25
# worse -0.75
# new 0.375
# last -0.25
# heavy 0.0
# wireless 0.0
# full 0.0
# flat 0.125
# previous 0.0
# available 0.375
# latest 0.125
# first 0.0
# best 0.75
# complete 0.0
# usual 0.125
# colour 0.625
# new 0.375
# new 0.375
# traditional 0.0
# new 0.375
# right 0.0
# right 0.0
# lower -0.25
# third 0.0
# new 0.375
# large 0.125
# easier 0.375
# old 0.375
# optical 0.0
# accurate 0.5
# many 0.0
# huge -0.125
# overall 0.0
# traditional 0.0
# capacitive 0.0
# main 0.375
# optical 0.0
# optical 0.0
# digital 0.125
# similar 0.125
# main 0.375
# capable 0.125
# great 0.0
# full 0.0
# solid 0.875
# low -0.25
# light -0.25
# low -0.25
# good 0.75
# worse -0.75
# main 0.375
# digital 0.125
# macro 0.0
# minimum 0.0
# macro 0.0
# good 0.75
# unpredictable -0.625
# brighter 0.125
# little -0.375
# manual 0.0
# required 0.125
# right 0.0
# matching 0.0
# good 0.75
# good 0.75
# light -0.25
# second 0.0
# good 0.75
# best 0.75
# slow 0.0
# sharp 0.25
# alert 0.5
# wonderful 0.75
# little -0.375
# smaller -0.125
# included 0.0
# best 0.75
# first 0.0
# colour 0.625
# green -0.125
# dark 0.0
# various -0.25
# cut 0.0
# super 0.625
# fast 0.0
# smooth 0.25
# smaller -0.125
# cheaper -0.25
# large 0.125
# bright 0.125
# good 0.75
# manageable 0.625
# solid 0.875
# capable 0.125
# great 0.0
# best 0.75
# excellent 1.0
# least 0.0
# luxurious 0.625
# gigantic 0.0
# cheaper -0.25
# better 0.875
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  20.25
# Word Count In Article:  146
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# biggest 0.125
# west 0.0
# South 0.0
# Korean 0.0
# bright 0.125
# upper 0.125
# various -0.25
# bigger 0.125
# South 0.0
# Korean 0.0
# biggest 0.125
# global -0.375
# top 0.0
# attractive 0.875
# high -0.125
# high -0.125
# slow 0.0
# traditional 0.0
# larger 0.125
# large 0.125
# new 0.375
# social 0.0
# popular 0.125
# positive 0.625
# negative -0.875
# steep 0.375
# enough 0.125
# able 0.125
# various -0.25
# wide 0.125
# senior 0.375
# experienced 0.5
# shy 0.0
#
# ********************************************
# Total Sentiment:  2.5
# Word Count In Article:  33
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# least 0.0
# new 0.375
# big 0.125
# international -0.5
# nonprofit 0.0
# standard 0.0
# various -0.25
# recent 0.0
# annual 0.0
# new 0.375
# first 0.0
# successful 0.625
# small -0.375
# useful 0.0
# possible 0.5
# communicative 0.0
# tired 0.25
# unconcerned 0.0
# dismissive 0.25
# mean 0.0
# yawning 0.0
# little -0.375
# responsible 0.625
# new 0.375
# due 0.0
# useful 0.0
# new 0.375
# available 0.375
# new 0.375
# late 0.0
# last -0.25
#
# ********************************************
# Total Sentiment:  2.875
# Word Count In Article:  31
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# many 0.0
# amazing 0.25
# fresh -0.25
# useful 0.0
# mean 0.0
# imperative 0.0
# plastic 0.0
# easier 0.375
# plastic 0.0
# biggest 0.125
# higher 0.375
# virgin 0.0
# new 0.375
# minimum 0.0
# sustainable 0.625
# material 0.125
# single 0.0
# content 0.0
# plastic 0.0
# reusable 0.625
# additional 0.0
# top 0.0
# current 0.0
# circular 0.25
# plastic 0.0
# used 0.0
# ready 0.0
# high -0.125
# near -0.25
# infrared 0.0
# plastic 0.0
# light -0.25
# different 0.625
# due 0.0
# black -0.375
# ready 0.0
# black -0.375
# global -0.375
# good 0.75
# black -0.375
# black -0.375
# alternative 0.125
# free 0.375
# black -0.375
# international -0.5
# free 0.375
# black -0.375
# recyclable 0.625
# reusable 0.625
# plastic 0.0
# European 0.0
# good 0.75
# main 0.375
# better 0.875
# circular 0.25
# social 0.0
# plastic 0.0
# plastic 0.0
# good 0.75
# plastic 0.0
# total 0.0
# global -0.375
# proven 0.0
# environmental 0.0
# social 0.0
# many 0.0
# Early 0.0
# charitable 0.25
# initiative 0.0
# successful 0.625
# personal 0.0
# professional 0.0
# young 0.0
# steady -0.5
# plastic 0.0
# plastic 0.0
# varied -0.25
# hard -0.75
# large 0.125
# transparent 0.0
# yellowish 0.0
# huge -0.125
# attractive 0.875
# coloured 0.0
# transparent 0.0
# mean 0.0
# plastic 0.0
# greyish 0.0
# nice 0.875
# smart 0.5
# plastic 0.0
# sustainable 0.625
# multiple 0.0
# plastic 0.0
# resistant -0.125
# good 0.75
# external 0.0
# difficult -0.75
# separate -0.5
# padded 0.0
# used 0.0
# heavy 0.0
# environmental 0.0
# lighter -0.25
# new 0.375
# recyclable 0.625
# straight -0.375
# global -0.375
# circular 0.25
# traditional 0.0
# different 0.625
# plastic 0.0
# sustainable 0.625
# new 0.375
# recyclable 0.625
# plastic 0.0
# sustainable 0.625
# plastic 0.0
# plastic 0.0
# future -0.125
# sustainable 0.625
#
# ********************************************
# Total Sentiment:  10.5
# Word Count In Article:  121
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# great 0.0
# horrendous -0.625
# least 0.0
# last -0.25
# biggest 0.125
# expensive 0.5
# new 0.375
# small -0.375
# new 0.375
# smaller -0.125
# exact 0.0
# different 0.625
# difficult -0.75
# wide 0.125
# massive 0.0
# gigantic 0.0
# heavier 0.0
# full 0.0
# top 0.0
# unforgiving -0.75
# bigger 0.125
# giant 0.375
# public -0.125
# wonderful 0.75
# smaller -0.125
# massive 0.0
# cheaper -0.25
# metallic 0.0
# new 0.375
# least 0.0
# intensive 0.375
# top 0.0
# adaptable 0.0
# useful 0.0
# starting 0.0
# massive 0.0
# last -0.25
# longer 0.0
# shy 0.0
# full 0.0
# last -0.25
# top 0.0
# primary 0.375
# full 0.0
# flat 0.125
# hot 0.0
# worth 0.25
# quick 0.0
# menstrual 0.0
# new 0.375
# large 0.125
# present -0.125
# smaller -0.125
# top 0.0
# difficult -0.75
# right 0.0
# equal 0.125
# least 0.0
# surprising -0.625
# quick 0.0
# new 0.375
# triple 0.0
# smaller -0.125
# wide 0.125
# optical 0.0
# digital 0.125
# massive 0.0
# previous 0.0
# new 0.375
# best 0.75
# low -0.25
# new 0.375
# deep 0.125
# closer 0.0
# fine 0.375
# large 0.125
# ultra 0.0
# competitive 0.0
# resistant -0.125
# last -0.25
# stronger 0.5
# weakest -0.375
# best 0.75
# new 0.375
# directional 0.0
# polished 0.25
# easy 0.375
# careful 0.5
# general 0.0
# sensitive 0.0
# previous 0.0
# black -0.375
# green -0.125
# excellent 1.0
# super 0.625
# smaller -0.125
# biggest 0.125
# terrible -0.625
# worse -0.75
# massive 0.0
# heavy 0.0
# serious 0.125
# great 0.0
# epic 0.75
# expensive 0.5
# easier 0.375
# big 0.125
# available 0.375
# wonderful 0.75
# bigger 0.125
# magic -0.25
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  6.75
# Word Count In Article:  117
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# rancorous 0.125
# first 0.0
# new 0.375
# soft -0.25
# Western 0.0
# biggest 0.125
# final 0.0
# third 0.0
# mean 0.0
# new 0.375
# solid 0.875
# last -0.25
# first 0.0
# former -0.125
# last -0.25
# top 0.0
# influential 0.125
# short 0.0
# international -0.5
# brightest 0.125
# short 0.0
# final 0.0
# early 0.0
# former -0.125
# safe 0.0
# abject -0.875
# wholesale 0.25
# clean 0.125
# unknown -0.25
# right 0.0
# wrong -0.625
# positive 0.625
# literal 0.25
# perfect 0.5
# unequivocal -0.125
# last -0.25
# solid 0.875
# handy 0.0
# last -0.25
# good 0.75
# new 0.375
# massive 0.0
# variable 0.375
# foreign -0.125
# sound 0.75
# competitive 0.0
# top 0.0
# worst -0.5
# faithful 0.625
# tumultuous -0.75
# steady -0.5
# competitive 0.0
# worth 0.25
# talented 0.5
# local 0.0
# regular 0.0
# short 0.0
# last -0.25
# open -0.375
# last -0.25
# mean 0.0
# new 0.375
# unknown -0.25
# new 0.375
# final 0.0
# highest -0.125
# real 0.0
# potential -0.25
# rich 0.0
# young 0.0
# biggest 0.125
# Last -0.25
# new 0.375
# full 0.0
# youthful 0.375
# golden 0.0
# first 0.0
# broader 0.125
# last -0.25
# new 0.375
# mean 0.0
# key 0.0
# immediate 0.0
# new 0.375
# new 0.375
# greater 0.25
# forlorn -0.375
# upfront 0.5
# due 0.0
# free 0.375
# precarious -0.5
# financial 0.25
# veteran 0.5
# solid 0.875
# huge -0.125
# alliterative 0.0
# faithful 0.625
# Last -0.25
# full 0.0
# proven 0.0
# top 0.0
# painful -0.625
# Asian 0.0
# many 0.0
# nearer -0.25
# obvious 0.5
# weak -0.375
# quiet -0.5
# last -0.25
# consistent 0.25
# big 0.125
# several -0.5
# able 0.125
# old 0.375
# injured -0.625
# lit 0.0
# blue 0.0
# high -0.125
# pedigree 0.0
# handy 0.0
# last -0.25
# rare 0.25
# back 0.0
# consistent 0.25
# young 0.0
# good 0.75
# much 0.0
# last -0.25
# fancy -0.375
# good 0.75
# quiet -0.5
# genuine -0.272
# single 0.0
# mercurial -0.25
# best 0.75
# last -0.25
# Australian 0.0
# familiar 0.125
# real 0.0
# fit 0.5
# tough -0.75
# new 0.375
# genuine -0.272
# disappointed -0.5
# decisive 0.0
# spectacular 0.25
# raucous -0.5
# early 0.0
# poor -0.75
# unsatisfactory -0.5
# temporary 0.375
# dramatic 0.5
# last -0.25
# final 0.0
# long 0.0
# obvious 0.5
# stronger 0.5
# final 0.0
# newest 0.375
# mere 0.125
# true 0.125
# impressive 0.125
# young 0.0
# Australian 0.0
# international -0.5
# inevitable -0.625
# least 0.0
# Western 0.0
# raw 0.0
#
# ********************************************
# Total Sentiment:  3.5809999999999995
# Word Count In Article:  169
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# pro 0.0
# smaller -0.125
# manageable 0.625
# premium 0.75
# small -0.375
# relative -0.25
# larger 0.125
# modern -0.25
# pocketable 0.0
# new 0.375
# heavier 0.0
# side 0.0
# heavy 0.0
# easiest 0.375
# new 0.375
# regular 0.0
# gorgeous 0.75
# bright 0.125
# rich 0.0
# full 0.0
# smooth 0.25
# new 0.375
# previous 0.0
# small -0.375
# least 0.0
# intensive 0.375
# likely 0.5
# top 0.0
# small -0.375
# new 0.375
# old 0.375
# much 0.0
# powerful 0.25
# adaptable 0.0
# recent 0.0
# pro 0.0
# creative 0.0
# short 0.0
# last -0.25
# worse -0.75
# last -0.25
# longer 0.0
# negligible -0.125
# primary 0.375
# full 0.0
# flat 0.125
# much 0.0
# hot 0.0
# worth 0.25
# big 0.125
# new 0.375
# black -0.375
# white -0.25
# black -0.375
# white -0.25
# black -0.375
# efficient 0.0
# black -0.375
# white -0.25
# meaningful 0.125
# black -0.375
# Other -0.625
# long 0.0
# open -0.375
# quick 0.0
# unknown -0.25
# menstrual 0.0
# new 0.375
# useful 0.0
# summary -0.125
# least 0.0
# surprising -0.625
# quick 0.0
# normal -0.5
# previous 0.0
# new 0.375
# optical 0.0
# digital 0.125
# dual 0.0
# noticeable 0.625
# last -0.25
# best 0.75
# different 0.625
# new 0.375
# low -0.25
# light -0.25
# main 0.375
# automatic 0.0
# multiple 0.0
# second 0.0
# available 0.375
# light -0.25
# second 0.0
# dank -0.25
# bright 0.125
# flat 0.125
# dramatic 0.5
# last -0.25
# good 0.75
# deep 0.125
# huge -0.125
# fine 0.375
# first 0.0
# full 0.0
# large 0.125
# past -0.25
# fantastic 0.375
# best 0.75
# third 0.0
# useful 0.0
# capable 0.125
# good 0.75
# slow 0.0
# big 0.125
# big 0.125
# first 0.0
# important 0.875
# last -0.25
# stronger 0.5
# weakest -0.375
# best 0.75
# new 0.375
# directional 0.0
# polished 0.25
# easy 0.375
# careful 0.5
# general 0.0
# sensitive 0.0
# previous 0.0
# black -0.375
# green -0.125
# last -0.25
# top 0.0
# best 0.75
# smaller -0.125
# available 0.375
# longer 0.0
# excellent 1.0
# big 0.125
# fine 0.375
# low -0.25
# digital 0.125
# professional 0.0
# right 0.0
# perfect 0.5
# larger 0.125
# easy 0.375
# biggest 0.125
# likely 0.5
# large 0.125
# good 0.75
# unrivalled 0.5
# hefty 0.125
# premium 0.75
# ethical 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  13.875
# Word Count In Article:  160
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# discreet 0.625
# professional 0.0
# steep 0.375
# dusty -0.375
# minor -0.375
# Dickensian -0.625
# quiet -0.5
# whole 0.125
# chubbier 0.125
# early 0.0
# sandy 0.0
# tan 0.0
# regular 0.0
# Italian 0.0
# unlikely -0.625
# incident -0.25
# facial 0.0
# available 0.375
# active -0.125
# former -0.125
# facial 0.0
# private -0.125
# aggressive 0.5
# vanished 0.0
# rolled 0.125
# least 0.0
# high -0.125
# close 0.0
# mobile 0.0
# second 0.0
# front 0.0
# old 0.375
# subject -0.125
# front 0.0
# facial 0.0
# ultimate -0.125
# major 0.625
# conservative 0.0
# Brazilian 0.0
# several -0.5
# dressed -0.125
# potential -0.25
# facial 0.0
# personal 0.0
# worried -0.875
# safest 0.0
# past -0.25
# facial 0.0
# private -0.125
# personal 0.0
# private -0.125
# facial 0.0
# unknown -0.25
# public -0.125
# legal 0.0
# facial 0.0
# enough 0.125
# facial 0.0
# noticed 0.125
# peaceful 0.25
# major 0.625
# recent 0.0
# local 0.0
# human 0.0
# right 0.0
# last -0.25
# high -0.125
# lawful 0.125
# new 0.375
# facial 0.0
# suspect -0.5
# false -0.75
# quick 0.0
# judicial 0.0
# domestic 0.0
# certain -0.375
# individual 0.0
# specific 0.0
# facial 0.0
# large 0.125
# big 0.125
# legal 0.0
# legal 0.0
# u 0.0
# expansive -0.5
# potential -0.25
# facial 0.0
# major 0.625
# north 0.0
# western 0.0
# ethnic 0.0
# half 0.0
# first 0.0
# major 0.625
# good 0.75
# harsh -0.625
# chaotic -0.125
# clear 0.5
# political 0.0
# u 0.0
# new 0.375
# great 0.0
# early 0.0
# vain -0.75
# fake -0.75
# facial 0.0
# Independent 0.125
# rapid 0.0
# bespoke 0.0
# different 0.625
# different 0.625
# multiple 0.0
# tagged 0.125
# Creative 0.0
# Chinese 0.0
# parallel -0.25
# new 0.375
# powerful 0.25
# second 0.0
# big 0.125
# new 0.375
# facial 0.0
# deep 0.125
# incredible 0.0
# standard 0.0
# human 0.0
# intuitive 0.0
# abstract 0.0
# mathematical 0.375
# limited 0.0
# best 0.75
# deep 0.125
# first 0.0
# random 0.125
# little -0.375
# better 0.875
# right 0.0
# wrong -0.625
# facial 0.0
# useful 0.0
# facial 0.0
# effective 0.125
# available 0.375
# high -0.125
# clear 0.5
# real 0.0
# potential -0.25
# false -0.75
# positive 0.625
# inaccurate -0.5
# similar 0.125
# false -0.75
# positive 0.625
# general 0.0
# public -0.125
# facial 0.0
# aware 0.5
# new 0.375
# huge -0.125
# suspect -0.5
# similar 0.125
# local 0.0
# related 0.0
# many 0.0
# sharp 0.25
# mobile 0.0
# real 0.0
# surprising -0.625
# facial 0.0
# light -0.25
# top 0.0
# average 0.0
# largest 0.125
# black -0.375
# British 0.0
# acceptable 0.625
# ambiguous 0.125
# worst -0.5
# blameless 0.25
# individual 0.0
# human 0.0
# several -0.5
# demographic 0.0
# small -0.375
# many 0.0
# illegal 0.0
# incomprehensible -0.375
# Indian 0.0
# mean 0.0
# last -0.25
# various -0.25
# many 0.0
# impossible -0.75
# rural 0.0
# better 0.875
# facial 0.0
# centralised 0.0
# recent 0.0
# last -0.25
# facial 0.0
# international -0.5
# potential -0.25
# difficult -0.75
# many 0.0
# possible 0.5
# unofficial -0.75
# technological 0.0
# available 0.375
# recent 0.0
# hard -0.75
# open -0.375
# new 0.375
# real 0.0
# criminal -0.875
# Real 0.0
# facial 0.0
# largest 0.125
# perfect 0.5
# legal 0.0
# human 0.0
# right 0.0
# Indian 0.0
# difficult -0.75
# dangerous -0.75
# good 0.75
# civil 0.125
# instinct -0.5
# much 0.0
# private -0.125
# common 0.0
# undesirable -0.375
# recent 0.0
# facial 0.0
# digital 0.125
# facial 0.0
# mobile 0.0
# opposite -0.125
# facial 0.0
# single 0.0
# strategic 0.0
# future -0.125
# social 0.0
# political 0.0
# facial 0.0
# u 0.0
# new 0.375
# unsafe -0.125
# red 0.0
# longer 0.0
# free 0.375
# real 0.0
#
# ********************************************
# Total Sentiment:  -4.875
# Word Count In Article:  251
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# thin 0.0
# light -0.25
# traditional 0.0
# dual 0.0
# unveiled 0.0
# next 0.0
# mobile 0.0
# fit 0.5
# larger 0.125
# high -0.125
# thick 0.0
# detachable 0.25
# new 0.375
# fit 0.5
# biggest 0.125
# new 0.375
# mobile 0.0
# full 0.0
# powerful 0.25
# Better 0.875
# unprecedented 0.0
# full 0.0
# chief 0.375
# new 0.375
# similar 0.125
# excess -0.5
# traditional 0.0
# early 0.0
# new 0.375
# traditional 0.0
# 10th 0.0
# powerful 0.25
# outgoing 0.0
# new 0.375
# fast 0.0
# mean 0.0
# biggest 0.125
# traditional 0.0
# new 0.375
# larger 0.125
# first 0.0
# found 0.0
# powerful 0.25
# larger 0.125
# longtime 0.0
# fastest 0.0
# graphic 0.0
# new 0.375
# removable 0.625
# hard -0.75
# clear 0.5
# difficult -0.75
# able 0.125
# critical -0.5
# new 0.375
# true 0.125
# direct -0.25
# dual 0.0
# real 0.0
# many 0.0
# due 0.0
# full 0.0
# open -0.375
# folding 0.375
# continuous 0.0
# flexible 0.375
# open -0.375
# absolute 0.5
# best 0.75
# best 0.75
# elegant 0.5
# vague -0.125
# flexible 0.375
# dual 0.0
# new 0.375
# new 0.375
# detachable 0.25
# virtual 0.5
# new 0.375
# dual 0.0
# thick 0.0
# next 0.0
# unlimited -0.5
# interrupted 0.0
# available 0.375
# More 0.0
# new 0.375
# new 0.375
#
# ********************************************
# Total Sentiment:  10.5
# Word Count In Article:  88
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# lower -0.25
# latest 0.125
# longer 0.0
# identical -0.375
# latest 0.125
# lower -0.25
# broader 0.125
# top 0.0
# cheaper -0.25
# last -0.25
# identical -0.375
# large 0.125
# lower -0.25
# biggest 0.125
# new 0.375
# large 0.125
# new 0.375
# dual 0.0
# solid 0.875
# best 0.75
# likely 0.5
# good 0.75
# rich 0.0
# bright 0.125
# high -0.125
# many 0.0
# heavy 0.0
# wide 0.125
# little -0.375
# latest 0.125
# least 0.0
# fastest 0.0
# efficient 0.0
# difficult -0.75
# last -0.25
# unusual -0.5
# top 0.0
# last -0.25
# happy 0.875
# last -0.25
# closer 0.0
# longest 0.0
# primary 0.375
# slow 0.0
# pathetic -0.75
# minute 0.0
# higher 0.375
# worth 0.25
# regardless -0.625
# worth 0.25
# much 0.0
# good 0.75
# prior 0.0
# different 0.625
# several -0.5
# hard -0.75
# Most 0.0
# extra -0.5
# big 0.125
# new 0.375
# black -0.375
# white -0.25
# white -0.25
# first 0.0
# open -0.375
# second 0.0
# open -0.375
# quick 0.0
# straight -0.375
# appropriate 0.0
# extensive 0.0
# friendly 0.125
# good 0.75
# new 0.375
# unknown -0.25
# new 0.375
# summary -0.125
# friendly 0.125
# useful 0.0
# longest 0.0
# best 0.75
# important 0.875
# new 0.375
# new 0.375
# dual 0.0
# ultra 0.0
# wide 0.125
# standard 0.0
# typical 0.125
# optical 0.0
# optical 0.0
# digital 0.125
# good 0.75
# real 0.0
# optical 0.0
# poor -0.75
# good 0.75
# best 0.75
# rich 0.0
# main 0.375
# good 0.75
# best 0.75
# Other -0.625
# typical 0.125
# ultra 0.0
# wide 0.125
# new 0.375
# main 0.375
# good 0.75
# smart 0.5
# closer 0.0
# biggest 0.125
# new 0.375
# low -0.25
# light -0.25
# special 0.0
# similar 0.125
# dramatic 0.5
# automatic 0.0
# multiple 0.0
# second 0.0
# available 0.375
# light -0.25
# second 0.0
# dank -0.25
# little -0.375
# indoor 0.125
# dark 0.0
# little -0.375
# dark 0.0
# particular 0.0
# grainy 0.0
# great 0.0
# fantastic 0.375
# easy 0.375
# slow 0.0
# big 0.125
# first 0.0
# important 0.875
# optical 0.0
# resistant -0.125
# second 0.0
# last -0.25
# stronger 0.5
# weakest -0.375
# best 0.75
# new 0.375
# directional 0.0
# useful 0.0
# available 0.375
# white -0.25
# black -0.375
# green -0.125
# yellow 0.0
# excellent 1.0
# old 0.375
# dated -0.375
# large 0.125
# heavy 0.0
# difficult -0.75
# solid 0.875
# new 0.375
# last -0.25
# cheap -0.25
# top 0.0
# latest 0.125
# top 0.0
# second 0.0
# third 0.0
# careful 0.5
# best 0.75
# optical 0.0
# ultra 0.0
# wide 0.125
# last -0.25
# tough -0.75
# real 0.0
# new 0.375
# second 0.0
# least 0.0
# third 0.0
# best 0.75
# primary 0.375
# best 0.75
# best 0.75
# new 0.375
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  15.125
# Word Count In Article:  191
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# old 0.375
# British 0.0
# Indian 0.0
# equal 0.125
# first 0.0
# live 0.0
# ignorant -0.5
# north 0.0
# true 0.125
# north 0.0
# west 0.0
# momentous 0.25
# great 0.0
# gothic 0.0
# fourth 0.0
# oldest 0.375
# cathedral 0.0
# old 0.375
# cocky 0.25
# west 0.0
# fresher -0.25
# social 0.0
# financial 0.25
# unstable -0.125
# epidemic 0.25
# sexual 0.25
# fresh -0.25
# young 0.0
# young 0.0
# general 0.0
# living -0.125
# turbulent -0.75
# British 0.0
# first 0.0
# busy 0.375
# free 0.375
# main 0.375
# tinny 0.0
# full 0.0
# blue 0.0
# pink 0.0
# cheap -0.25
# free 0.375
# south 0.0
# incomprehensible -0.375
# south 0.0
# nice 0.875
# scary -0.75
# German 0.0
# wide 0.125
# sure -0.25
# full 0.0
# next 0.0
# live 0.0
# lyric -0.25
# giant 0.375
# fresher -0.25
# overpriced 0.125
# private -0.125
# good 0.75
# social 0.0
# clear 0.5
# flat 0.125
# wide 0.125
# certain -0.375
# old 0.375
# first 0.0
# French 0.0
# Spanish 0.0
# common 0.0
# young 0.0
# early 0.0
# free 0.375
# struck -0.375
# white -0.25
# English 0.0
# different 0.625
# clear 0.5
# international -0.5
# European 0.0
# u 0.0
# welcome 0.5
# high -0.125
# huge -0.125
# unearthly 0.375
# fresher -0.25
# intense -0.125
# light -0.25
# fancy -0.375
# like -0.25
# good 0.75
# biggest 0.125
# old 0.375
# full 0.0
# nervous 0.125
# surreal -0.25
# free 0.375
# front 0.0
# wide 0.125
# first 0.0
# digital 0.125
# native 0.125
# higher 0.375
# criminal -0.875
# persistent -0.125
# direct -0.25
# much 0.0
# higher 0.375
# safe 0.0
# online 0.0
# nervous 0.125
# new 0.375
# primary 0.375
# online 0.0
# right 0.0
# fair 0.625
# apparent 0.625
# mental 0.125
# unspoken -0.25
# lucky 0.75
# serious 0.125
# mental 0.125
# top 0.0
# unprecedented 0.0
# young 0.0
# assistant 0.0
# average 0.0
# old 0.375
# much 0.0
# greater 0.25
# smug -0.25
# apathetic -0.5
# prepared 0.625
# much 0.0
# greater 0.25
# golden 0.0
# future -0.125
# enough 0.125
# free 0.375
# obscene -0.625
# ready 0.0
# Scottish 0.0
# collect 0.0
# ready 0.0
# middle 0.0
#
# ********************************************
# Total Sentiment:  7.5
# Word Count In Article:  145
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# wearable 0.25
# new 0.375
# smart 0.5
# directional 0.0
# similar 0.125
# smart 0.5
# smart 0.5
# smart 0.5
# akin 0.0
# secret -0.25
# wide 0.125
# true 0.125
# active -0.125
# similar 0.125
# second 0.0
# best 0.75
# new 0.375
# new 0.375
# new 0.375
# lower -0.25
# significant 0.375
# smart 0.5
# integrated 0.0
# standard 0.0
# smaller -0.125
# cheaper -0.25
# smart 0.5
# new 0.375
# long 0.0
# low -0.25
# cheaper -0.25
# indoor 0.125
# improved 0.375
# responsible 0.625
# last -0.25
# false -0.75
# potential -0.25
# private -0.125
# private -0.125
# first 0.0
# available 0.375
# clean 0.125
# next 0.0
# true 0.125
#
# ********************************************
# Total Sentiment:  5.5
# Word Count In Article:  44
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# great 0.0
# wireless 0.0
# best 0.75
# long 0.0
# true 0.125
# good 0.75
# common 0.0
# woeful -0.75
# free 0.375
# wireless 0.0
# difficult -0.75
# separate -0.5
# true 0.125
# last -0.25
# available 0.375
# new 0.375
# right 0.0
# sound 0.75
# difficult -0.75
# wireless 0.0
# third 0.0
# small -0.375
# comfortable -0.75
# traditional 0.0
# small -0.375
# small -0.375
# soft -0.25
# fine 0.375
# double 0.25
# triple 0.0
# ambient 0.375
# assistant 0.0
# right 0.0
# ambient 0.375
# good 0.75
# reasonable 0.5
# treble 0.0
# good 0.75
# capable 0.125
# uncomfortable -0.75
# limited 0.0
# available 0.375
# good 0.75
# solid 0.875
# hot 0.0
# right 0.0
# capable 0.125
# proprietary 0.0
# scalable 0.5
# high -0.125
# noticeable 0.625
# good 0.75
# little -0.375
# distant 0.0
# similar 0.125
# good 0.75
# open -0.375
# small -0.375
# fit 0.5
# full 0.0
# mean 0.0
# last -0.25
# continuous 0.0
# additional 0.0
# mean 0.0
# compatible 0.5
# easy 0.375
# quick 0.0
# various -0.25
# useful 0.0
# sound 0.75
# mean 0.0
# least 0.0
# sure -0.25
# best 0.75
# simple -0.25
# wireless 0.0
# live 0.0
# effective 0.125
# great 0.0
# excellent 1.0
# sound 0.75
# true 0.125
# effective 0.125
# free 0.375
# comfortable -0.75
# full 0.0
# strong 0.5
# attractive 0.875
# black -0.375
# massive 0.0
# fit 0.5
# right 0.0
# good 0.75
# lasting -0.625
# active -0.125
# large 0.125
# difficult -0.75
# great 0.0
# sound 0.75
# excellent 1.0
# solid 0.875
# solid 0.875
# attractive 0.875
# best 0.75
# true 0.125
# best 0.75
# great 0.0
# smaller -0.125
# second 0.0
# little -0.375
# white -0.25
# sound 0.75
# able 0.125
# loud 0.25
# maximum 0.25
# good 0.75
# reasonable 0.5
# recent 0.0
# double 0.25
# second 0.0
# little -0.375
# slow 0.0
# poor -0.75
# odd 0.125
# public -0.125
# good 0.75
# best 0.75
# last -0.25
# available 0.375
# new 0.375
# extra -0.5
# compatible 0.5
# sound 0.75
# good 0.75
# excellent 1.0
# decent 0.875
# alternative 0.125
# sound 0.75
# smallest -0.375
# available 0.375
# tiny 0.0
# flat 0.125
# sensitive 0.0
# visible 0.125
# Available 0.375
# black -0.375
# white -0.25
# easy 0.375
# flat 0.125
# good 0.75
# treble 0.0
# crisp 0.25
# sparkling 0.125
# good 0.75
# good 0.75
# great 0.0
# old 0.375
# fine 0.375
# left 0.0
# right 0.0
# stable 0.0
# magnetic 0.0
# free 0.375
# good 0.75
# little -0.375
# quiet -0.5
# difficult -0.75
# loud 0.25
# last -0.25
# good 0.75
# constant 0.375
# cylindrical 0.0
# open -0.375
# small -0.375
# possible 0.5
# good 0.75
# great 0.0
# good 0.75
# smallest -0.375
# wireless 0.0
# smaller -0.125
# better 0.875
# great 0.0
# solid 0.875
# excellent 1.0
# proper 0.75
# flexible 0.375
# free 0.375
# resistant -0.125
# fine 0.375
# hard -0.75
# energetic 0.375
# good 0.75
# enormous 0.0
# worst -0.5
# robust -0.375
# able 0.125
# fit 0.5
# basic 0.0
# good 0.75
# excellent 1.0
# real 0.0
# solid 0.875
# smaller -0.125
# cheaper -0.25
# known 0.5
# best 0.75
# true 0.125
# available 0.375
# expensive 0.5
# comfortable -0.75
# hard -0.75
# fleshy 0.0
# traditional 0.0
# extra -0.5
# good 0.75
# best 0.75
# last -0.25
# double 0.25
# average 0.0
# true 0.125
# big 0.125
# pocketable 0.0
# full 0.0
# good 0.75
# good 0.75
# least 0.0
# good 0.75
# best 0.75
# stiff -0.5
# right 0.0
# left 0.0
# right 0.0
# good 0.75
# little -0.375
# audible 0.375
# fine 0.375
# similar 0.125
# poor -0.75
# sound 0.75
# solid 0.875
# OK 0.375
# excellent 1.0
# true 0.125
# great 0.0
# wireless 0.0
# small -0.375
# worth 0.25
# top 0.0
# fit 0.5
# true 0.125
# second 0.0
# best 0.75
# great 0.0
# sound 0.75
# solid 0.875
# comfortable -0.75
# basic 0.0
# excellent 1.0
# smaller -0.125
# easier 0.375
# extra -0.5
# smaller -0.125
# true 0.125
# excellent 1.0
# larger 0.125
# cheaper -0.25
# worth 0.25
# good 0.75
# second 0.0
# solid 0.875
# small -0.375
# last -0.25
# full 0.0
# reasonable 0.5
# biggest 0.125
# massive 0.0
# stable 0.0
# good 0.75
# flexible 0.375
# good 0.75
# good 0.75
# last -0.25
# large 0.125
# full 0.0
# biggest 0.125
# huge -0.125
# least 0.0
# solid 0.875
# good 0.75
# good 0.75
# available 0.375
# pocketable 0.0
# huge -0.125
# large 0.125
# classic 0.375
# big 0.125
# uncomfortable -0.75
# minute 0.0
# real 0.0
# good 0.75
# alternative 0.125
# solid 0.875
# noticeable 0.625
# good 0.75
# full 0.0
# right 0.0
# sound 0.75
# good 0.75
# clear 0.5
# little -0.375
# pretty 0.75
# compact 0.0
# large 0.125
# uncomfortable -0.75
# longer 0.0
# smaller -0.125
# best 0.75
# true 0.125
# available 0.375
# general 0.0
# attractive 0.875
# great 0.0
# effective 0.125
# tiny 0.0
# fit 0.5
# shy 0.0
# great 0.0
# sound 0.75
# worth 0.25
# good 0.75
# pronounced 0.5
# high -0.125
# short 0.0
# slight -0.375
# solid 0.875
# large 0.125
# uncomfortable -0.75
# good 0.75
# heavy 0.0
# great 0.0
# black -0.375
# traditional 0.0
# good 0.75
# strong 0.5
# solid 0.875
# poor -0.75
# good 0.75
# occasional 0.0
# minimal 0.0
# last -0.25
# full 0.0
# attractive 0.875
# accessible 0.625
# multiple 0.0
# mushy 0.0
# best 0.75
# true 0.125
# great 0.0
# large 0.125
# comfortable -0.75
# solid 0.875
# last -0.25
# better 0.875
# pocketable 0.0
# best 0.75
# new 0.375
# Low -0.25
# good 0.75
# distant 0.0
# best 0.75
# sound 0.75
# rich 0.0
# warm 0.375
# high -0.125
# deep 0.125
# great 0.0
# solid 0.875
# true 0.125
# good 0.75
# weak -0.375
# small -0.375
# newer 0.375
# constant 0.375
# small -0.375
# serious 0.125
# ok 0.375
# stuck 0.0
# cheap -0.25
# questionable 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  73.375
# Word Count In Article:  396
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# young 0.0
# available 0.375
# mobile 0.0
# documentary 0.0
# unfinished -0.625
# largest 0.125
# second 0.0
# documented 0.0
# old 0.375
# many 0.0
# broad 0.125
# unspecific -0.125
# unfathomable -0.625
# formative 0.5
# much 0.0
# journalistic 0.0
# valid 0.125
# side 0.0
# soft -0.25
# nostalgic -0.75
# logistical 0.0
# u 0.0
# u 0.0
# u 0.0
# older 0.5
# younger -0.375
# Serbian 0.0
# filthy -0.875
# vile -0.5
# long 0.0
# hard -0.75
# pivotal 0.5
# characteristic 0.0
# dramatic 0.5
# small -0.375
# European 0.0
# unheralded -0.5
# aesthetic 0.0
# mobile 0.0
# small -0.375
# external 0.0
# audible 0.375
# extensive 0.0
# sound 0.75
# unclean -0.75
# aware 0.5
# mobile 0.0
# enough 0.125
# bigger 0.125
# constant 0.375
# Turkish 0.0
# central 0.0
# mobile 0.0
# many 0.0
# barbed 0.375
# Hungarian 0.0
# painful -0.625
# vulnerable 0.125
# biggest 0.125
# pivotal 0.5
# masterful 0.75
# dramatic 0.5
# scary -0.75
# peaceful 0.25
# potential -0.25
# best 0.75
# much 0.0
# inextricable -0.625
# living -0.125
# simultaneous 0.0
# strange 0.25
# familiar 0.125
# many 0.0
# candid 0.125
# fraught -0.75
# unresolved 0.0
#
# ********************************************
# Total Sentiment:  -0.75
# Word Count In Article:  76
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# u 0.0
# great 0.0
# sound 0.75
# Danish 0.0
# true 0.125
# familiar 0.125
# vast -0.125
# different 0.625
# metallic 0.0
# white -0.25
# good 0.75
# simple -0.25
# attractive 0.875
# subtle 0.25
# unnoticed -0.125
# different 0.625
# attractive 0.875
# black -0.375
# fit 0.5
# comfortable -0.75
# small -0.375
# fit 0.5
# small -0.375
# light -0.25
# different 0.625
# comfortable -0.75
# best 0.75
# small -0.375
# fit 0.5
# wireless 0.0
# pocketable 0.0
# handy 0.0
# shy 0.0
# active -0.125
# little -0.375
# flimsy -0.375
# little -0.375
# standard 0.0
# high -0.125
# highest -0.125
# higher 0.375
# noticeable 0.625
# minimal 0.0
# major 0.625
# minor -0.375
# noticeable 0.625
# solid 0.875
# momentary 0.125
# underground 0.0
# weak -0.375
# double 0.25
# best 0.75
# good 0.75
# true 0.125
# big 0.125
# best 0.75
# aggressive 0.5
# good 0.75
# basic 0.0
# neutral 0.125
# extra -0.5
# treble 0.0
# best 0.75
# left 0.0
# neutral 0.125
# good 0.75
# effective 0.125
# new 0.375
# top 0.0
# full 0.0
# maximum 0.25
# worth 0.25
# active -0.125
# ambient 0.375
# excellent 1.0
# natural 0.25
# easy 0.375
# good 0.75
# clear 0.5
# little -0.375
# loud 0.25
# audible 0.375
# fine 0.375
# larger 0.125
# open -0.375
# right 0.0
# automatic 0.0
# many 0.0
# white -0.25
# black -0.375
# best 0.75
# true 0.125
# available 0.375
# attractive 0.875
# small -0.375
# light -0.25
# best 0.75
# pocketable 0.0
# good 0.75
# shy 0.0
# best 0.75
# true 0.125
# available 0.375
# pretty 0.75
# effective 0.125
# curious -0.25
# small -0.375
# cheap -0.25
# good 0.75
# great 0.0
# great 0.0
# true 0.125
# last -0.25
# long 0.0
# pocketable 0.0
# cherry 0.0
# top 0.0
# true 0.125
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  18.75
# Word Count In Article:  123
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# latest 0.125
# ongoing 0.0
# new 0.375
# high -0.125
# latest 0.125
# western 0.0
# open -0.375
# mobile 0.0
# temporary 0.375
# new 0.375
# alternative 0.125
# Chinese 0.0
# essential 0.125
# western 0.0
# possible 0.5
# able 0.125
# many 0.0
# strong 0.5
# new 0.375
# good 0.75
# multiple 0.0
# great 0.0
# chief 0.375
# huge -0.125
# new 0.375
# largest 0.125
# second 0.0
# hard -0.75
# biggest 0.125
# present -0.125
# serious 0.125
# main 0.375
# strong 0.5
# new 0.375
# new 0.375
# complete 0.0
# many 0.0
# new 0.375
# top 0.0
# flexible 0.375
# right 0.0
# physical 0.0
# virtual 0.5
# second 0.0
# circular 0.25
# main 0.375
# ultra 0.0
# wide 0.125
# optical 0.0
# capable 0.125
# professional 0.0
# second 0.0
# super 0.625
# slow 0.0
# new 0.375
# dual 0.0
# large 0.125
# longer 0.0
# new 0.375
# various -0.25
# new 0.375
#
# ********************************************
# Total Sentiment:  8.875
# Word Count In Article:  61
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# Dutch 0.0
# last -0.25
# possible 0.5
# latest 0.125
# many 0.0
# many 0.0
# possible 0.5
# human 0.0
# third 0.0
# responsible 0.625
# dated -0.375
# top 0.0
# reminiscent 0.0
# small -0.375
# reasonable 0.5
# good 0.75
# bright 0.125
# enough 0.125
# latest 0.125
# least 0.0
# utilitarian 0.0
# thick 0.0
# chunky 0.0
# big 0.125
# thick 0.0
# larger 0.125
# small -0.375
# closer 0.0
# similar 0.125
# translucent 0.0
# black -0.375
# able 0.125
# hidden -0.375
# little -0.375
# impressive 0.125
# side 0.0
# left 0.0
# likely 0.5
# little -0.375
# self 0.0
# rare 0.25
# high -0.125
# reachable 0.375
# little -0.375
# last -0.25
# significant 0.375
# middle 0.0
# last -0.25
# primary 0.375
# total 0.0
# standard 0.0
# second 0.0
# standard 0.0
# free 0.375
# minor -0.375
# new 0.375
# last -0.25
# familiar 0.125
# clear 0.5
# better 0.875
# likely 0.5
# avoidable 0.625
# standard 0.0
# magic -0.25
# good 0.75
# reasonable 0.5
# solid 0.875
# low -0.25
# light -0.25
# overhead 0.0
# dark 0.0
# indistinct -0.5
# similar 0.125
# fine 0.375
# sunny 0.5
# poor -0.75
# Other -0.625
# top 0.0
# exciting 0.375
# modular -0.5
# wrong -0.625
# removable 0.625
# standard 0.0
# correct 0.625
# big 0.125
# individual 0.0
# cheap -0.25
# fair 0.625
# top 0.0
# open -0.375
# strong 0.5
# poor -0.75
# solid 0.875
# direct -0.25
# available 0.375
# mid 0.0
# available 0.375
# full 0.0
# massive 0.0
# interesting 0.375
# translucent 0.0
# good 0.75
# big 0.125
# larger 0.125
# welcome 0.5
# odd 0.125
# easy 0.375
# clean 0.125
# free 0.375
# good 0.75
# new 0.375
# great 0.0
# poor -0.75
# great 0.0
# modern -0.25
# similar 0.125
# different 0.625
# fit 0.5
# modular -0.5
# new 0.375
# second 0.0
# sustainable 0.625
# material 0.125
# ethical 0.0
# possible 0.5
# serviceable 0.0
# new 0.375
# possible 0.5
# real 0.0
# ethical 0.0
# prepared 0.625
# extra -0.5
# worthy 0.875
# new 0.375
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  14.375
# Word Count In Article:  139
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# early 0.0
# new 0.375
# old 0.375
# new 0.375
# early 0.0
# expensive 0.5
# happy 0.875
# full 0.0
# possible 0.5
# great 0.0
# great 0.0
# great 0.0
# ancient 0.0
# entire 0.0
# happy 0.875
# sharp 0.25
# mobile 0.0
# decent 0.875
# ample 0.0
# realistic 0.0
# mean 0.0
# compatible 0.5
# content 0.0
# real 0.0
# much 0.0
# much 0.0
# dark 0.0
# available 0.375
# slow 0.0
# front 0.0
# happy 0.875
# artful -0.875
# little -0.375
# slow 0.0
# hard -0.75
# large 0.125
# slow 0.0
# new 0.375
# dual 0.0
# wide 0.125
# Last -0.25
# single 0.0
# enough 0.125
# better 0.875
# last -0.25
# pet 0.25
# indifferent 0.0
# usual 0.125
# good 0.75
# last -0.25
# top 0.0
# standard 0.0
# colour 0.625
# new 0.375
# big 0.125
# dull 0.125
# black -0.375
# large 0.125
# red 0.0
# black -0.375
# white -0.25
# yellow 0.0
# green -0.125
# first 0.0
# equivalent 0.125
# millennial 0.0
# stylish 0.375
# new 0.375
# hidden -0.375
# lower -0.25
# enough 0.125
# hard -0.75
# modern -0.25
# able 0.125
# higher 0.375
# different 0.625
# worth 0.25
# wrong -0.625
# newest 0.375
# nice 0.875
# speedier 0.5
# improved 0.375
# new 0.375
# lower -0.25
# enough 0.125
# immediate 0.0
# latest 0.125
# big 0.125
# last -0.25
# X 0.0
# current 0.0
# old 0.375
# significant 0.375
# excellent 1.0
# higher 0.375
# new 0.375
# main 0.375
# cheaper -0.25
# complimentary 0.5
# enough 0.125
# single 0.0
# enough 0.125
# excellent 1.0
# small -0.375
# meaningful 0.125
# last -0.25
# new 0.375
# side 0.0
# truer 0.125
# facial 0.0
# apparent 0.625
# small -0.375
# impressive 0.125
# smaller -0.125
# expensive 0.5
# likely 0.5
# high -0.125
# main 0.375
# larger 0.125
# extra -0.5
# professional 0.0
# best 0.75
# separate -0.5
# difficult -0.75
# real 0.0
# new 0.375
# able 0.125
# single 0.0
# much 0.0
# improved 0.375
# cinematic 0.0
# little -0.375
# impressive 0.125
# best 0.75
# important 0.875
# magical -0.25
# true 0.125
# best 0.75
# professional 0.0
# best 0.75
# accurate 0.5
# glassy 0.25
# harsh -0.625
# excellent 1.0
# leading 0.125
# expensive 0.5
# better 0.875
# floral 0.125
# dark 0.0
# easy 0.375
# colour 0.625
# true 0.125
#
# ********************************************
# Total Sentiment:  22.0
# Word Count In Article:  152
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# new 0.375
# top 0.0
# new 0.375
# standard 0.0
# new 0.375
# new 0.375
# new 0.375
# modern -0.25
# fashionable 0.0
# segmented 0.0
# outside 0.0
# harsh -0.625
# soft -0.25
# longer 0.0
# easier 0.375
# fit 0.5
# mean 0.0
# small -0.375
# heavier 0.0
# comfortable -0.75
# extended 0.0
# snug 0.125
# relaxed -0.625
# new 0.375
# best 0.75
# inclement -0.75
# full 0.0
# minimum 0.0
# maximum 0.25
# continual 0.0
# fine 0.375
# highest -0.125
# advanced -0.25
# good 0.75
# major 0.625
# problematic 0.0
# little -0.375
# similar 0.125
# great 0.0
# mobile 0.0
# hot 0.0
# original 0.0
# next 0.0
# best 0.75
# maximum 0.25
# effective 0.125
# difficult -0.75
# sudden -0.5
# mid 0.0
# greater 0.25
# maximum 0.25
# open -0.375
# ambient 0.375
# mean 0.0
# natural 0.25
# open -0.375
# similar 0.125
# favourite 0.125
# big 0.125
# small -0.375
# whole 0.125
# luxurious 0.625
# sound 0.75
# divisive -0.5
# different 0.625
# original 0.0
# balanced 0.125
# low -0.25
# high -0.125
# clinical 0.0
# individual 0.0
# easy 0.375
# open -0.375
# spacious 0.0
# consistent 0.25
# best 0.75
# right 0.0
# new 0.375
# assistant 0.0
# new 0.375
# similar 0.125
# smart 0.5
# clear 0.5
# loud 0.25
# noisiest 0.0
# last -0.25
# shy 0.0
# maximum 0.25
# longer 0.0
# last -0.25
# last -0.25
# transatlantic 0.0
# slow 0.0
# quick 0.0
# handy 0.0
# double 0.25
# loud 0.25
# quiet -0.5
# several -0.5
# wired 0.0
# small -0.375
# available 0.375
# black -0.375
# cheaper -0.25
# expensive 0.5
# sound 0.75
# best 0.75
# consistent 0.25
# sound 0.75
# top 0.0
# adaptable 0.0
# available 0.375
# best 0.75
# flat 0.125
# fit 0.5
# general 0.0
# spacious 0.0
# comfortable -0.75
# comfortable -0.75
# extended 0.0
# key 0.0
# better 0.875
# handy 0.0
# mobile 0.0
# higher 0.375
# low -0.25
# solid 0.875
# shy 0.0
# best 0.75
# original 0.0
# best 0.75
# true 0.125
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  11.375
# Word Count In Article:  137
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# South 0.0
# Korean 0.0
# long 0.0
# big 0.125
# longer 0.0
# biggest 0.125
# bad -0.625
# good 0.75
# mean 0.0
# longer 0.0
# best 0.75
# clear 0.5
# slight -0.375
# striking 0.25
# enormous 0.0
# bigger 0.125
# gorgeous 0.75
# great 0.0
# top 0.0
# smaller -0.125
# impressive 0.125
# good 0.75
# thin 0.0
# thin 0.0
# top 0.0
# squared 0.125
# giant 0.375
# old 0.375
# accidental -0.125
# regular 0.0
# difficult -0.75
# total 0.0
# big 0.125
# newer 0.375
# used 0.0
# powerful 0.25
# snappy -0.25
# good 0.75
# heavy 0.0
# excess -0.5
# ...
# top 0.0
# similar 0.125
# best 0.75
# capable 0.125
# maximum 0.25
# noticeable 0.625
# standard 0.0
# good 0.75
# large 0.125
# cheap -0.25
# disappointing -0.75
# large 0.125
# smaller -0.125
# maximum 0.25
# average 0.0
# primary 0.375
# active -0.125
# comic 0.5
# last -0.25
# full 0.0
# similar 0.125
# possible 0.5
# North 0.0
# American 0.0
# latest 0.125
# unexpected -0.25
# useful 0.0
# large 0.125
# present -0.125
# whole 0.125
# best 0.75
# smoother 0.25
# snappy -0.25
# dual 0.0
# wide 0.125
# dual 0.0
# fine 0.375
# subject -0.125
# alert 0.5
# many 0.0
# rich 0.0
# excellent 1.0
# new 0.375
# full 0.0
# second 0.0
# Other -0.625
# usual 0.125
# next 0.0
# useful 0.0
# great 0.0
# resistant -0.125
# good 0.75
# big 0.125
# viable 0.375
# better 0.875
# big 0.125
# loud 0.25
# good 0.75
# able 0.125
# massive 0.0
# biggest 0.125
# difficult -0.75
# much 0.0
# smaller -0.125
# great 0.0
# useful 0.0
# myriad 0.0
# maximum 0.25
# workable 0.375
# light -0.25
# good 0.75
# better 0.875
# new 0.375
# last -0.25
# much 0.0
# different 0.625
# huge -0.125
# older 0.5
# happy 0.875
# best 0.75
# big 0.125
# best 0.75
# big 0.125
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  15.25
# Word Count In Article:  122
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# American 0.0
# ethical 0.0
# live 0.0
# top 0.0
# important 0.875
# big 0.125
# substantial 0.0
# red 0.0
# Taiwanese 0.0
# several -0.5
# main 0.375
# British 0.0
# hard -0.75
# least 0.0
# South 0.0
# African 0.0
# private -0.125
# little -0.375
# original 0.0
# alternative 0.125
# free 0.375
# excellent 1.0
# Chinese 0.0
# many 0.0
# alternative 0.125
# open -0.375
# great 0.0
# easy 0.375
# alternative 0.125
# Japanese 0.0
# South 0.0
# Korean 0.0
# long 0.0
# Russian 0.0
# giant 0.375
# national 0.0
# many 0.0
# first 0.0
# European 0.0
# popular 0.125
# real 0.0
# past -0.25
# unlikely -0.625
# social 0.0
# improved 0.375
# American 0.0
# equivalent 0.125
# combined 0.0
# second 0.0
# largest 0.125
# social 0.0
# many 0.0
# virtual 0.5
# equivalent 0.125
# huge -0.125
# international -0.5
# many 0.0
# giant 0.375
# equivalent 0.125
# social 0.0
# digital 0.125
# biggest 0.125
# international -0.5
# recent 0.0
# small -0.375
# independent 0.125
# commercial 0.0
# third 0.0
# More 0.0
#
# ********************************************
# Total Sentiment:  1.625
# Word Count In Article:  69
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# recent 0.0
# electronic 0.0
# stronger 0.5
# political 0.0
# Turkish 0.0
# diplomatic 0.0
# American 0.0
# evangelical 0.0
# decisive 0.0
# current 0.0
# low -0.25
# Indian 0.0
# central 0.0
# new 0.375
# low -0.25
# slow 0.0
# last -0.25
# wider 0.125
#
# ********************************************
# Total Sentiment:  0.25
# Word Count In Article:  18
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# right 0.0
# Spanish 0.0
# top 0.0
# Indian 0.0
# latest 0.125
# exclusive -0.75
# new 0.375
# free 0.375
# much 0.0
# right 0.0
# last -0.25
# right 0.0
# popular 0.125
# satellite 0.0
# worldwide 0.0
# next 0.0
# right 0.0
# live 0.0
# global -0.375
# live 0.0
# big 0.125
# latest 0.125
# first 0.0
# successful 0.625
# possible 0.5
# south 0.0
# Asian 0.0
# crucial 0.25
# untapped -0.625
# social 0.0
# largest 0.125
# single 0.0
# first 0.0
# affordable 0.0
# mobile 0.0
# chief 0.375
# next 0.0
# local 0.0
# free 0.375
# select 0.625
# net 0.0
# original 0.0
# local 0.0
# plus 0.0
# main 0.375
# social 0.0
# Last -0.25
# right 0.0
# Indian 0.0
# suitable 0.125
# alternative 0.125
#
# ********************************************
# Total Sentiment:  2.5
# Word Count In Article:  51
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# wealthier -0.25
# cosmetic 0.375
# many 0.0
# extra -0.5
# free 0.375
# maximum 0.25
# weekly 0.0
# new 0.375
# many 0.0
# manual 0.0
# irregular -0.5
# national 0.0
# new 0.375
# early 0.0
# happy 0.875
# free 0.375
# old 0.375
# new 0.375
# powerful 0.25
# wealthy -0.25
# due 0.0
# second 0.0
# unofficial -0.75
# average 0.0
# due 0.0
# third 0.0
# irregular -0.5
# 53 0.0
# largest 0.125
# national 0.0
# massive 0.0
# significant 0.375
# political 0.0
# South 0.0
# Korean 0.0
# longest 0.0
# Last -0.25
# average 0.0
# low -0.25
# additional 0.0
# similar 0.125
# average 0.0
# additional 0.0
# strong 0.5
# little -0.375
# different 0.625
# new 0.375
# long 0.0
# extra -0.5
# normal -0.5
# many 0.0
# private -0.125
# opening 0.0
# aggressive 0.5
# hefty 0.125
# difficult -0.75
# possible 0.5
# new 0.375
# second 0.0
# third 0.0
# new 0.375
# new 0.375
# new 0.375
# largest 0.125
# legal 0.0
# stable 0.0
# high -0.125
# civil 0.125
# corporate 0.0
# second 0.0
# last -0.25
#
# ********************************************
# Total Sentiment:  3.125
# Word Count In Article:  71
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# popular 0.125
# available 0.375
# available 0.375
# unusual -0.5
# main 0.375
# good 0.75
# outside 0.0
# poor -0.75
# susceptible 0.5
# greatest 0.875
# malicious -0.375
# outside 0.0
# vulnerable 0.125
# malicious -0.375
# wrong -0.625
# hypothetical 0.125
# malicious -0.375
# naive 0.5
# additional 0.0
# young 0.0
# immune 0.0
# free 0.375
# best 0.75
# immediate 0.0
# general 0.0
# popular 0.125
# vulnerable 0.125
# unknown -0.25
# malicious -0.375
# long 0.0
# mixed -0.125
# effective 0.125
# fine 0.375
#
# ********************************************
# Total Sentiment:  2.25
# Word Count In Article:  33
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# latest 0.125
# larger 0.125
# lasting -0.625
# last -0.25
# replete 0.25
# bigger 0.125
# last -0.25
# heavier 0.0
# larger 0.125
# heaviest 0.0
# premium 0.75
# busy 0.375
# first 0.0
# able 0.125
# popular 0.125
# exclusive -0.75
# limited 0.0
# available 0.375
# traditional 0.0
# available 0.375
# available 0.375
# new 0.375
# similar 0.125
# bottom 0.0
# dual 0.0
# variable 0.375
# optical 0.0
# shot 0.0
# lower -0.25
# easier 0.375
# mobile 0.0
# loyal 0.5
# new 0.375
# wary 0.625
# previous 0.0
# enough 0.125
# loyal 0.5
# able 0.125
# recent 0.0
# top 0.0
# colour 0.625
# black -0.375
# available 0.375
# new 0.375
# new 0.375
# current 0.0
# available 0.375
# new 0.375
# new 0.375
# greatest 0.875
# best 0.75
# big 0.125
#
# ********************************************
# Total Sentiment:  8.875
# Word Count In Article:  52
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# next 0.0
# new 0.375
# new 0.375
# biggest 0.125
# colourful 0.125
# new 0.375
# least 0.0
# Right 0.0
# recent 0.0
# last -0.25
# much 0.0
# free 0.375
# eligible 0.5
# biggest 0.125
# traditional 0.0
# new 0.375
# traditional 0.0
# right 0.0
# last -0.25
# similar 0.125
# double 0.25
# back 0.0
# needed 0.125
# mean 0.0
# small -0.375
# useful 0.0
# little -0.375
# perfect 0.5
# top 0.0
# dramatic 0.5
# able 0.125
# least 0.0
# biggest 0.125
# individual 0.0
# predictable 0.0
# manual 0.0
# several -0.5
# accessible 0.625
# easy 0.375
# particular 0.0
# right 0.0
# magnified -0.5
# fine 0.375
# easier 0.375
# tiny 0.0
# able 0.125
# idle -0.625
# mean 0.0
# recent 0.0
# big 0.125
# new 0.375
# similar 0.125
# live 0.0
# select 0.625
# much 0.0
# certain -0.375
# visual 0.0
# audible 0.375
#
# ********************************************
# Total Sentiment:  4.75
# Word Count In Article:  58
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# available 0.375
# available 0.375
# official 0.0
# available 0.375
# possible 0.5
# physical 0.0
# mobile 0.0
# fastest 0.0
# active -0.125
# official 0.0
# last -0.25
# outside 0.0
# direct -0.25
# major 0.625
# mobile 0.0
# able 0.125
# smooth 0.25
# trusted 0.5
# high -0.125
# enormous 0.0
# broad 0.125
# open -0.375
# fake -0.75
# malicious -0.375
# open -0.375
# various -0.25
# third 0.0
# available 0.375
# third 0.0
# mobile 0.0
# main 0.375
# tougher -0.75
# lucrative 0.75
# new 0.375
# mobile 0.0
# Chinese 0.0
# successful 0.625
# large 0.125
# exclusive -0.75
# small -0.375
# key 0.0
# cross 0.0
# mobile 0.0
# free 0.375
# sign 0.0
# last -0.25
#
# ********************************************
# Total Sentiment:  1.25
# Word Count In Article:  46
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# new 0.375
# mid 0.0
# hot 0.0
# legendary 0.875
# free 0.375
# last -0.25
# pink 0.0
# chicken -0.5
# worst -0.5
# dead -0.75
# problematic 0.0
# memorable 0.125
# good 0.75
# bad -0.625
# bad -0.625
# viral 0.0
# expensive 0.5
# last -0.25
# limited 0.0
# chicken -0.5
# special 0.0
# last -0.25
# unlikely -0.625
# chicken -0.5
# u 0.0
# chicken -0.5
# u 0.0
# vocational 0.0
# chicken -0.5
# best 0.75
# difficult -0.75
# successful 0.625
# willing 0.5
# difficult -0.75
# different 0.625
# total 0.0
# creative 0.0
# better 0.875
# nervous 0.125
# u 0.0
# best 0.75
# final 0.0
# recent 0.0
# inescapable -0.5
# chicken -0.5
# worth 0.25
# regular 0.0
# little -0.375
# whole 0.125
# essential 0.125
# dry -0.25
# big 0.125
# pretty 0.75
# decent 0.875
# substantial 0.0
# defensive 0.0
# weird -0.75
# mum 0.0
# certain -0.375
# big 0.125
# young 0.0
# forgettable 0.5
# steady -0.5
# dead -0.75
# mean 0.0
# normal -0.5
# viral 0.0
# full 0.0
# demographic 0.0
# certain -0.375
# young 0.0
# black -0.375
# successful 0.625
# good 0.75
# next 0.0
# demographic 0.0
# much 0.0
# new 0.375
# international -0.5
#
# ********************************************
# Total Sentiment:  -1.75
# Word Count In Article:  79
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# larger 0.125
# hard -0.75
# replaceable 0.5
# obvious 0.5
# cool 0.125
# sleek 0.375
# physical 0.0
# successful 0.625
# white -0.25
# fundamental 0.0
#
# ********************************************
# Total Sentiment:  1.25
# Word Count In Article:  10
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# latest 0.125
# lowest -0.125
# domestic 0.0
# new 0.375
# lowest -0.125
# high -0.125
# global -0.375
# recent 0.0
# unlikely -0.625
# easier 0.375
# recent 0.0
# biggest 0.125
# huge -0.125
# suspect -0.5
# next 0.0
# low -0.25
# late 0.0
# latest 0.125
# positive 0.625
# low -0.25
# unlikely -0.625
# small -0.375
# recent 0.0
# much 0.0
# larger 0.125
# weak -0.375
# first 0.0
# key 0.0
# next 0.0
# ideal 0.75
# much 0.0
#
# ********************************************
# Total Sentiment:  -1.25
# Word Count In Article:  31
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# second 0.0
# largest 0.125
# second 0.0
# first 0.0
# split 0.0
# top 0.0
# Multiple 0.0
# largest 0.125
# recent 0.0
# weak -0.375
# second 0.0
# significant 0.375
# first 0.0
# top 0.0
# second 0.0
# due 0.0
# willing 0.5
# numerous -0.125
# previous 0.0
# worst -0.5
# big 0.125
# second 0.0
# impressive 0.125
# least 0.0
# unknown -0.25
# competitive 0.0
# top 0.0
# popular 0.125
# top 0.0
# Chinese 0.0
# key 0.0
# Chinese 0.0
# private -0.125
# Chinese 0.0
# subject -0.125
# good 0.75
# significant 0.375
# major 0.625
# higher 0.375
# steady -0.5
# third 0.0
# total 0.0
# last -0.25
# half 0.0
#
# ********************************************
# Total Sentiment:  1.375
# Word Count In Article:  44
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# last -0.25
# fourth 0.0
# American 0.0
# much 0.0
# much 0.0
# insolent -0.25
# long 0.0
# vague -0.125
# sour -0.375
# proverbial 0.0
# whole 0.125
# many 0.0
# famous 0.375
# third 0.0
# executive 0.0
# real 0.0
# actual -0.375
# last -0.25
# better 0.875
# recent 0.0
# biggest 0.125
# social 0.0
# next 0.0
# perfect 0.5
# classic 0.375
# content 0.0
# particular 0.0
# top 0.0
# proper 0.75
# responsible 0.625
# controversial 0.5
# biological 0.0
# outside 0.0
# trashy -0.875
# repulsive -0.75
# able 0.125
# biggest 0.125
# eternal 0.25
# next 0.0
# unscripted -0.625
# least 0.0
#
# ********************************************
# Total Sentiment:  0.875
# Word Count In Article:  41
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# indelible -0.125
# good 0.75
#
# ********************************************
# Total Sentiment:  0.625
# Word Count In Article:  2
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# best 0.75
# different 0.625
# monthly 0.0
# old 0.375
# mobile 0.0
# many 0.0
# recent 0.0
# little -0.375
# latest 0.125
# Chinese 0.0
# mobile 0.0
# able 0.125
# domestic 0.0
# old 0.375
# usual 0.125
# teen 0.125
# social 0.0
# good 0.75
# pricey 0.5
# online 0.0
# best 0.75
# free 0.375
# previous 0.0
# next 0.0
# great 0.0
# great 0.0
# old 0.375
# old 0.375
# big 0.125
# happy 0.875
# u 0.0
# prepared 0.625
# latest 0.125
# free 0.375
# expensive 0.5
# better 0.875
# cheaper -0.25
# good 0.75
# absolute 0.5
# competitive 0.0
# best 0.75
# free 0.375
# better 0.875
# unlocked -0.5
# local 0.0
# best 0.75
# best 0.75
# great 0.0
# much 0.0
#
# ********************************************
# Total Sentiment:  12.875
# Word Count In Article:  49
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# red 0.0
# normal -0.5
# top 0.0
# old 0.375
# brilliant 0.875
# young 0.0
# human 0.0
# huge -0.125
# outside 0.0
# early 0.0
# disappointed -0.5
# next 0.0
# urgent 0.0
# different 0.625
# old 0.375
# local 0.0
# several -0.5
# wound 0.0
# like -0.25
# complete 0.0
# upset -0.875
# unexpected -0.25
# many 0.0
# representative 0.0
# u 0.0
# major 0.625
# rare 0.25
# little -0.375
# new 0.375
# homespun -0.25
# first 0.0
# important 0.875
# experiential 0.0
# influential 0.125
# next 0.0
# competitive 0.0
# amorphous -0.5
# real 0.0
# good 0.75
# easier 0.375
# last -0.25
# great 0.0
# economic 0.0
# industrial 0.0
# outer 0.0
# small -0.375
# manipulative 0.25
# right 0.0
# unique 0.375
# future -0.125
# local 0.0
# special 0.0
# clever 0.5
# valuable 0.0
# global -0.375
# tangible 0.5
# incredible 0.0
# intangible -0.625
# intangible -0.625
# magical -0.25
# old 0.375
# accessory 0.375
# huge -0.125
# reasonable 0.5
# capable 0.125
# hard -0.75
# actual -0.375
# overpriced 0.125
# good 0.75
# important 0.875
# last -0.25
# helpful 0.25
# special 0.0
# second 0.0
# unchanged -0.625
# soft -0.25
# simple -0.25
# much 0.0
# popular 0.125
# nice 0.875
# animal 0.125
# human 0.0
# universal 0.0
# easy 0.375
# human 0.0
# human 0.0
# animal 0.125
# perfect 0.5
# universal 0.0
# new 0.375
# unique 0.375
# young 0.0
# virtual 0.5
# online 0.0
# valuable 0.0
# senior 0.375
# particular 0.0
# old 0.375
# old 0.375
# additional 0.0
# accessory 0.375
# digital 0.125
# experiential 0.0
# close 0.0
# directional 0.0
# interactive 0.0
# specific 0.0
# directional 0.0
# specific 0.0
# sound 0.75
# similar 0.125
# memorable 0.125
# directional 0.0
# interactive 0.0
# burdensome -0.25
# physical 0.0
# personal 0.0
# traditional 0.0
# easy 0.375
# annual 0.0
# total 0.0
# last -0.25
# little -0.375
# half 0.0
# main 0.375
# net 0.0
# previous 0.0
# short 0.0
# big 0.125
# new 0.375
# open -0.375
# new 0.375
# good 0.75
# negative -0.875
# avoidable 0.625
# whole 0.125
# mean 0.0
# steady -0.5
# last -0.25
# factual 0.5
# due 0.0
# able 0.125
# full 0.0
# last -0.25
# north 0.0
# inside 0.0
# willing 0.5
# panicked 0.0
# broken -0.125
#
# ********************************************
# Total Sentiment:  8.25
# Word Count In Article:  149
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# new 0.375
# likely 0.5
# bigger 0.125
# front 0.0
# shattered -0.5
# new 0.375
# compressed 0.0
# probabilistic 0.0
# average 0.0
# multiple 0.0
# new 0.375
# average 0.0
# rough -0.375
# previous 0.0
# resistant -0.125
# multiple 0.0
# higher 0.375
# multiple 0.0
# general 0.0
# similar 0.125
# older 0.5
# current 0.0
# older 0.5
# next 0.0
# several -0.5
# top 0.0
# second 0.0
# multiple 0.0
# new 0.375
# next 0.0
#
# ********************************************
# Total Sentiment:  2.125
# Word Count In Article:  30
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# old 0.375
# west 0.0
# last -0.25
# tiny 0.0
# last -0.25
# old 0.375
# overwhelming 0.0
# senior 0.375
# north 0.0
# west 0.0
# different 0.625
# general 0.0
# clear 0.5
# royal 0.0
# potential -0.25
# minimum 0.0
# martial 0.125
# military 0.0
# successful 0.625
# many 0.0
# successful 0.625
# online 0.0
# new 0.375
# busy 0.375
# great 0.0
# hard -0.75
# strong 0.5
# unable -0.75
# different 0.625
# vast -0.125
# elderly 0.5
# former -0.125
# online 0.0
# real 0.0
# former -0.125
# desperate -0.5
# torn -0.75
# glossy 0.0
# similar 0.125
#
# ********************************************
# Total Sentiment:  2.25
# Word Count In Article:  39
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************
# strange 0.25
# sign 0.0
# unaware -0.25
# Last -0.25
# entire 0.0
# enough 0.125
# last -0.25
# similar 0.125
# low -0.25
# maximum 0.25
# routine 0.125
# Good 0.75
# clear 0.5
# random 0.125
# long 0.0
# awaited 0.25
# aware 0.5
# technical 0.125
#
# ********************************************
# Total Sentiment:  2.125
# Word Count In Article:  18
# ********************************************
#
# **********************
#  NEXT ARTICLE
# **********************

# %%
print(article_senti)
df['Sentiment'] = article_senti
# Out:
# [11.375, 3.875, 0.25, 18.0, 1.5, 4.5, 8.75, 29.375, 2.875, 20.25, 2.5, 2.875, 10.5, 6.75, 3.5809999999999995, 13.875, -4.875, 10.5, 15.125, 7.5, 5.5, 73.375, -0.75, 18.75, 8.875, 14.375, 22.0, 11.375, 16.5, 8.375, -5.125, 1.0, 9.25, 0.625, 0.875, 22.125, 9.5, -2.625, -0.375, 18.375, 17.5, 2.25, 3.875, -0.25, 0.625, 2.5, 8.625, -3.931, 13.875, 62.125, 8.125, 12.875, 19.625, 14.625, 10.375, 5.0, 5.5, 6.25, 1.875, 5.25, -1.625, 8.5, 0.25, 7.25, 16.0, 0.5, 8.0, 18.625, 6.125, 1.375, 4.375, 10.5, 1.25, 3.25, 18.375, 1.375, 21.375, 3.5, 5.125, -0.625, 0.0, 0.875, 3.25, -1.25, 1.625, 19.125, -0.875, 1.125, -2.125, -1.5, 1.375, 1.5, -2.375, 1.625, -0.125, -0.625, -0.5, -3.5, 13.625, 6.625, 19.125, 2.625, 4.375, 17.5, 4.75, 1.0, 6.0, 3.75, -1.375, 1.5, 22.375, -2.25, -3.0, 15.0, 12.25, 10.375, 0.125, -1.0, 3.0, 1.75, 7.125, 5.75, 6.625, 6.5, 4.5, 2.875, 0.25, 0.625, 5.625, 3.875, 2.2279999999999998, 3.819, -1.125, -2.625, -0.25, 2.25, -1.5, 1.875, 11.75, 11.25, 22.75, -2.875, 7.5, 2.75, 10.25, 3.75, 5.375, -1.875, 0.125, 17.0, 15.125, 15.75, 4.375, 15.375, 3.6029999999999998, 3.125, 14.5, 9.0, 3.125, 9.5, 15.5, 6.625, 8.25, 3.5, 0.25, 7.875, 3.625, 1.25, 6.75, -3.375, 6.25, 12.375, 30.625, 12.0, 1.125, 4.375, 10.75, 1.5, -1.125, 15.5, 8.375, 15.25, 1.625, 0.25, 2.5, 3.125, 2.25, 8.875, 4.75, 1.25, -1.75, 1.25, -1.25, 1.375, 0.875, 0.625, 12.875, 8.25, 2.125, 2.25, 2.125]

# %%
df.to_csv("Formatted_Data_Sentiment.csv")

# %%
pos_art = 0
neg_art = 0

for senti in article_senti:
    if senti > 0:
        pos_art += 1
    elif senti < 0:
        neg_art += 1
    else:
        pass
print("Out Of {} Articles, {} Are Positive , {} Are Negative And {} Is/Are Neutral"
      .format(len(article_senti), pos_art, neg_art, (len(article_senti) - pos_art - neg_art)))
