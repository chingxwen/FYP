# %%
import pandas as pd
import numpy as np
import re
import nltk
from pprint import pprint
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk import FreqDist
from textblob import TextBlob

# %%
#Reading of .csv file
df = pd.read_csv("TheGuardianDataFinal.csv")
content = df['Text']
assert content.isnull().count() == len(content)

# %%
df = pd.read_csv("TheGuardianDataFinal.csv")
content = df['Text']

# %%
#Before stop word removal count
count = [len(content[i]) for i in range(len(content))]
# data['Count Before'] = count
print(count)
# Out:
# [8625, 9258, 2648, 13182, 1899, 7842, 11971, 8772, 5565, 9165, 3198, 2426, 8657, 9182, 12405, 11333, 25352, 7375, 12506, 12845, 3788, 23099, 7351, 7728, 4338, 10207, 11862, 10192, 10773, 5184, 13471, 1028, 6678, 3873, 4470, 10071, 7516, 2964, 3423, 6897, 7321, 6019, 2920, 1614, 1004, 3680, 8942, 6232, 8002, 16608, 7648, 7448, 8712, 8582, 7375, 4079, 8308, 2319, 1882, 7517, 5742, 6646, 638, 7839, 7870, 624, 20102, 10232, 5633, 4097, 3218, 7325, 6543, 3348, 7306, 4280, 9235, 9615, 3016, 1582, 1119, 4117, 6499, 4670, 3604, 10180, 3544, 5768, 9769, 6767, 3352, 828, 5165, 4172, 1195, 1460, 3413, 2723, 7797, 9302, 12164, 5348, 5273, 7782, 3729, 3376, 3347, 4418, 7799, 1798, 6489, 2310, 3982, 9678, 7603, 11839, 720, 5915, 3332, 7701, 5279, 9187, 13448, 5879, 5599, 8929, 2212, 1950, 26567, 3209, 21282, 5188, 4600, 8239, 1318, 4899, 4707, 4045, 7950, 6905, 5694, 4248, 6604, 13625, 5775, 6385, 6005, 7459, 9072, 16628, 8515, 7515, 2805, 11277, 4662, 3423, 9310, 6415, 9101, 7395, 10163, 3749, 6962, 6004, 2551, 7063, 3189, 7154, 9514, 3657, 8356, 9881, 12059, 7653, 2324, 5158, 7010, 8721, 6863, 7818, 31668, 8641, 8062, 1877, 3927, 5917, 3298, 4480, 6634, 4576, 10661, 1337, 2040, 3964, 5096, 270, 4200, 14125, 1955, 5755, 2008]

# %%
#Tokenization
from nltk.tokenize import RegexpTokenizer


data = []
tokenizer = RegexpTokenizer(r'\w+')

content = content.apply(lambda x: tokenizer.tokenize(x))
content.head(20)
# Out:
# 0     [Brilliant, camera, slick, features, and, smal...
# 1     [On, a, dark, dark, night, in, a, dark, dark, ...
# 2     [Labour, has, written, to, the, competition, r...
# 3     [Google, s, latest, Pixel, 4, XL, smartphone, ...
# 4     [Apple, has, launched, a, new, set, of, its, p...
# 5     [I, use, a, 9, 7in, Samsung, Galaxy, Tab, S2, ...
# 6     [Always, on, screen, completes, the, package, ...
# 7     [Still, an, absolute, beast, in, every, way, e...
# 8     [First, it, was, books, then, it, was, the, Ki...
# 9     [The, OnePlus, 7T, takes, the, best, bits, of,...
# 10    [In, a, country, where, the, biggest, companie...
# 11    [I, think, you, should, at, least, make, an, e...
# 12    [Plastic, packaging, has, many, amazing, quali...
# 13    [A, great, camera, screen, and, performance, c...
# 14    [After, a, period, of, stagnation, the, A, Lea...
# 15    [Apple, s, iPhone, has, gone, pro, for, its, 1...
# 16    [Gordon, s, wine, bar, is, reached, through, a...
# 17    [Microsoft, has, launched, the, Surface, Pro, ...
# 18    [Apple, s, lower, cost, model, has, latest, ch...
# 19    [In, the, autumn, of, 1997, I, was, a, fresher...
# Name: Text, dtype: object

# %%
#Removal of Stop Words
from nltk.corpus import stopwords
set(stopwords.words('english'))

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

content = content.apply(lambda x: remove_stopwords(x))

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = [lemmatizer.lemmatize(i, pos="a") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="s") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="v") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="r") for i in text]
    lem_text = [lemmatizer.lemmatize(i, pos="n") for i in text]
    return lem_text

content = content.apply(lambda x: word_lemmatizer(x))
print(content[0])
content_freq = content
# Out:
# ['Brilliant', 'camera', 'slick', 'feature', 'small', 'size', 'mean', 'nothing', 'phone', 'even', 'last', 'day', 'Google', 'one', 'handful', 'smartphone', 'manufacturer', 'still', 'making', 'flagship', 'phone', 'ginormous', 'beast', 'new', 'Pixel', '4', 'cheapest', 'significantly', 'undercut', 'competition', 'Priced', '669', 'Pixel', '4', '70', 'cheaper', 'last', 'year', 'Pixel', '3', '60', 'cheaper', 'Apple', 'iPhone', '11', 'It', 'also', 'cheaper', 'bigger', 'sibling', '829', 'Pixel', '4', 'XL', 'The', 'concern', 'corner', 'cut', 'matter', 'The', '5', '7in', 'FHD', 'OLED', 'display', '90Hz', 'refresh', 'rate', 'larger', '6', '3in', 'version', 'Pixel', '4', 'XL', 'It', 'look', 'similar', 'good', 'viewing', 'angle', 'inky', 'black', 'bold', 'colour', 'smooth', 'experience', 'thanks', 'high', 'refresh', 'rate', 'But', 'brightest', 'screen', 'available', 'make', 'fine', 'thing', 'quite', 'bright', 'I', 'would', 'like', 'direct', 'sunlight', 'There', 'large', 'forehead', 'containing', 'sensor', 'Google', 'new', 'Face', 'Unlock', 'Motion', 'Sense', 'system', 'The', 'side', 'aluminium', 'black', 'textured', 'coating', 'glass', 'back', 'frosted', 'texture', 'similar', 'super', 'smooth', 'skin', 'Buy', 'white', 'orange', 'version', 'contrasting', 'colour', 'make', 'Pixel', '4', 'stand', 'Combined', 'slender', 'proportion', '68', '8mm', 'wide', '162g', 'Pixel', '4', 'one', 'smallest', 'lightest', 'easiest', 'top', 'end', 'smartphones', 'hold', 'use', 'It', 'joy', 'able', 'easily', 'use', 'smartphone', 'one', 'handed', 'For', 'comparison', 'Apple', '1', '049', 'iPhone', '11', 'Pro', 'currently', 'best', 'smaller', 'phone', 'available', '71', '4mm', 'wide', '188g', '799', 'Samsung', 'Galaxy', 'S10', '70', '4mm', 'wide', '157g', 'The', 'Pixel', '4', '6GB', 'RAM', '64GB', 'storage', 'one', 'Qualcomm', 'Snapdragon', '855', 'Pixel', '4', 'XL', 'performs', 'identically', 'fast', 'fluid', 'quite', 'speedy', 'OnePlus', '7T', 'Battery', 'life', 'really', 'poor', 'The', 'Pixel', '4', 'last', '14', 'hour', 'charge', 'Remove', 'charger', '7am', 'dead', '9pm', 'Turning', 'bell', 'whistle', 'ambient', 'display', 'added', '40', 'minute', 'battery', 'life', 'Anything', '24', 'hour', 'simply', 'good', 'enough', 'particularly', 'given', 'I', 'play', 'game', 'anything', 'particularly', 'battery', 'draining', 'That', 'using', 'primary', 'device', '200', 'email', 'message', 'push', 'notification', 'two', 'hour', 'browsing', 'Chrome', 'four', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', '40', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', 'three', 'photo', 'For', 'comparison', 'similarly', 'sized', 'iPhone', '11', 'Pro', 'last', '32', 'hour', 'Pixel', '4', 'XL', 'last', '26', 'hour', 'similar', 'condition', 'majority', 'smartphones', '2019', 'last', 'least', '24', 'hour', 'heavy', 'usage', 'The', 'Pixel', '4', 'fast', 'charge', '18W', 'via', 'USB', 'C', 'Power', 'Delivery', 'charger', 'one', 'included', 'box', 'wirelessly', 'charge', '11W', 'A', 'full', 'charge', 'via', 'cable', 'took', '105', 'minute', 'hitting', '70', '45', 'minute', 'The', 'Pixel', '4', 'one', 'first', 'smartphones', 'ship', 'latest', 'version', 'Android', '10', 'complete', 'system', 'wide', 'dark', 'mode', 'full', 'theming', 'support', 'changing', 'colour', 'icon', 'shape', 'typeface', 'vastly', 'improved', 'gesture', 'navigation', 'At', 'least', 'three', 'year', 'software', 'update', 'phone', 'release', 'included', 'get', 'Android', 'version', 'update', 'device', 'The', 'Pixel', '4', 'also', 'new', 'device', 'natural', 'language', 'processing', 'impressive', 'larger', 'Pixel', '4', 'XL', 'Google', 'Assistant', 'much', 'faster', 'work', 'without', 'internet', 'connection', 'many', 'task', 'Google', 'voice', 'transcription', 'app', 'equally', 'excellent', 'Live', 'Caption', 'feature', 'The', 'new', 'Assistant', 'still', 'work', 'Google', 'commercial', 'G', 'Suite', 'account', 'though', 'bit', 'blunder', 'Google', 'say', 'still', 'working', 'fix', 'Motion', 'Sense', 'us', ...

# %%
joinedText = []
for articles in content:
    joinedText.append(" ".join(articles))
print(joinedText)
# Out:
# 201

# %%
sentiment = []
for articles in joinedText:
    testimonial = TextBlob(articles)
    sentiment.append(testimonial.sentiment.polarity)
print(sentiment)
# Out:
# 201

# %%
for articles in content:
    print(articles)
# Out:
# ['Brilliant', 'camera', 'slick', 'feature', 'small', 'size', 'mean', 'nothing', 'phone', 'even', 'last', 'day', 'Google', 'one', 'handful', 'smartphone', 'manufacturer', 'still', 'making', 'flagship', 'phone', 'ginormous', 'beast', 'new', 'Pixel', '4', 'cheapest', 'significantly', 'undercut', 'competition', 'Priced', '669', 'Pixel', '4', '70', 'cheaper', 'last', 'year', 'Pixel', '3', '60', 'cheaper', 'Apple', 'iPhone', '11', 'It', 'also', 'cheaper', 'bigger', 'sibling', '829', 'Pixel', '4', 'XL', 'The', 'concern', 'corner', 'cut', 'matter', 'The', '5', '7in', 'FHD', 'OLED', 'display', '90Hz', 'refresh', 'rate', 'larger', '6', '3in', 'version', 'Pixel', '4', 'XL', 'It', 'look', 'similar', 'good', 'viewing', 'angle', 'inky', 'black', 'bold', 'colour', 'smooth', 'experience', 'thanks', 'high', 'refresh', 'rate', 'But', 'brightest', 'screen', 'available', 'make', 'fine', 'thing', 'quite', 'bright', 'I', 'would', 'like', 'direct', 'sunlight', 'There', 'large', 'forehead', 'containing', 'sensor', 'Google', 'new', 'Face', 'Unlock', 'Motion', 'Sense', 'system', 'The', 'side', 'aluminium', 'black', 'textured', 'coating', 'glass', 'back', 'frosted', 'texture', 'similar', 'super', 'smooth', 'skin', 'Buy', 'white', 'orange', 'version', 'contrasting', 'colour', 'make', 'Pixel', '4', 'stand', 'Combined', 'slender', 'proportion', '68', '8mm', 'wide', '162g', 'Pixel', '4', 'one', 'smallest', 'lightest', 'easiest', 'top', 'end', 'smartphones', 'hold', 'use', 'It', 'joy', 'able', 'easily', 'use', 'smartphone', 'one', 'handed', 'For', 'comparison', 'Apple', '1', '049', 'iPhone', '11', 'Pro', 'currently', 'best', 'smaller', 'phone', 'available', '71', '4mm', 'wide', '188g', '799', 'Samsung', 'Galaxy', 'S10', '70', '4mm', 'wide', '157g', 'The', 'Pixel', '4', '6GB', 'RAM', '64GB', 'storage', 'one', 'Qualcomm', 'Snapdragon', '855', 'Pixel', '4', 'XL', 'performs', 'identically', 'fast', 'fluid', 'quite', 'speedy', 'OnePlus', '7T', 'Battery', 'life', 'really', 'poor', 'The', 'Pixel', '4', 'last', '14', 'hour', 'charge', 'Remove', 'charger', '7am', 'dead', '9pm', 'Turning', 'bell', 'whistle', 'ambient', 'display', 'added', '40', 'minute', 'battery', 'life', 'Anything', '24', 'hour', 'simply', 'good', 'enough', 'particularly', 'given', 'I', 'play', 'game', 'anything', 'particularly', 'battery', 'draining', 'That', 'using', 'primary', 'device', '200', 'email', 'message', 'push', 'notification', 'two', 'hour', 'browsing', 'Chrome', 'four', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', '40', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', 'three', 'photo', 'For', 'comparison', 'similarly', 'sized', 'iPhone', '11', 'Pro', 'last', '32', 'hour', 'Pixel', '4', 'XL', 'last', '26', 'hour', 'similar', 'condition', 'majority', 'smartphones', '2019', 'last', 'least', '24', 'hour', 'heavy', 'usage', 'The', 'Pixel', '4', 'fast', 'charge', '18W', 'via', 'USB', 'C', 'Power', 'Delivery', 'charger', 'one', 'included', 'box', 'wirelessly', 'charge', '11W', 'A', 'full', 'charge', 'via', 'cable', 'took', '105', 'minute', 'hitting', '70', '45', 'minute', 'The', 'Pixel', '4', 'one', 'first', 'smartphones', 'ship', 'latest', 'version', 'Android', '10', 'complete', 'system', 'wide', 'dark', 'mode', 'full', 'theming', 'support', 'changing', 'colour', 'icon', 'shape', 'typeface', 'vastly', 'improved', 'gesture', 'navigation', 'At', 'least', 'three', 'year', 'software', 'update', 'phone', 'release', 'included', 'get', 'Android', 'version', 'update', 'device', 'The', 'Pixel', '4', 'also', 'new', 'device', 'natural', 'language', 'processing', 'impressive', 'larger', 'Pixel', '4', 'XL', 'Google', 'Assistant', 'much', 'faster', 'work', 'without', 'internet', 'connection', 'many', 'task', 'Google', 'voice', 'transcription', 'app', 'equally', 'excellent', 'Live', 'Caption', 'feature', 'The', 'new', 'Assistant', 'still', 'work', 'Google', 'commercial', 'G', 'Suite', 'account', 'though', 'bit', 'blunder', 'Google', 'say', 'still', 'working', 'fix', 'Motion', 'Sense', 'us', ...
# ['On', 'dark', 'dark', 'night', 'dark', 'dark', 'town', 'dark', 'dark', 'street', 'skeleton', 'witch', 'zombie', 'gather', 'There', 'even', 'odd', 'devil', 'two', 'The', 'legion', 'dead', 'come', 'together', 'annual', 'Halloween', 'night', 'parade', 'watched', 'thousand', 'costumed', 'reveller', 'But', 'US', 'country', 'people', 'consider', 'Halloween', 'mothership', 'Derry', 'Northern', 'Ireland', 'The', 'Derry', 'Halloween', 'festival', 'started', 'small', 'mid', '80', 'fancy', 'dress', 'disco', 'pub', 'Now', 'snowballed', 'massive', 'four', 'day', 'event', '120', '000', 'people', 'attending', '2018', 'double', 'number', '2016', 'On', 'Halloween', 'night', '45', '000', 'people', 'watching', 'parade', 'firework', 'The', 'sheer', 'size', 'extravaganza', 'gone', 'unnoticed', 'across', 'pond', 'either', 'USA', 'Today', 'crowning', 'world', 'best', 'Halloween', 'destination', '2015', 'So', 'safe', 'say', 'Derry', 'capital', 'Halloween', 'Or', 'city', 'go', 'even', 'While', '23', 'reveller', 'attending', 'Derry', 'festival', 'travelling', 'outside', 'Northern', 'Ireland', 'organiser', 'claim', 'growth', 'popularity', 'local', 'enthusiasm', 'clever', 'marketing', 'Aeidin', 'McCarter', 'head', 'culture', 'Derry', 'City', 'Strabane', 'district', 'council', 'call', 'festival', 'people', 'It', 'attracts', 'people', 'age', 'everybody', 'dress', 'You', 'look', 'strange', 'say', 'In', 'organised', 'festival', 'bringing', 'something', 'people', 'people', 'bringing', 'something', 'world', 'McCarter', 'say', 'Halloween', 'Derry', 'carnival', 'Rio', 'new', 'year', 'Edinburgh', 'Instead', 'Christmas', 'stuff', 'supermarket', 'aisle', 'full', 'Halloween', 'merchandise', 'There', 'pop', 'shop', 'open', 'last', 'three', 'week', 'selling', 'purely', 'Halloween', 'thing', 'People', 'plan', 'costume', 'least', 'year', 'advance', 'Even', 'local', 'people', 'left', 'city', 'come', 'back', 'In', 'way', 'people', 'come', 'back', 'Christmas', 'people', 'Derry', 'come', 'back', 'Halloween', 'None', 'Revellers', 'Halloween', 'parade', 'Greenwich', 'Village', 'New', 'York', 'City', 'Ireland', 'connection', 'All', 'Hallows', 'Eve', 'date', 'back', 'millennium', 'Celtic', 'festival', 'Samhain', 'spirit', 'believed', 'walk', 'Earth', 'new', 'year', 'began', '1', 'November', 'It', 'thought', 'ancient', 'tradition', 'first', 'introduced', 'US', 'Irish', 'immigrant', 'fleeing', 'potato', 'famine', 'mid', '19th', 'century', 'Undoubtedly', 'Americans', 'turned', 'religious', 'rite', 'secular', 'spectacular', 'A', 'terrifying', '68', 'people', 'celebrate', 'Halloween', 'average', 'household', 'US', 'spending', '86', '27', '67', 'festival', 'adding', 'whopping', 'nationwide', 'total', 'spend', '8', '8bn', 'That', 'lot', 'treat', 'Speaking', 'estimated', '41', 'million', 'child', 'aged', 'five', '14', 'go', 'trick', 'treating', '2019', '2', '1bn', 'spent', 'buying', 'sweet', 'give', 'away', 'night', 'Halloween', 'lucrative', 'country', 'Halloween', 'Costume', 'Association', 'petitioning', 'government', 'extend', 'celebration', 'include', 'additional', 'day', 'freakish', 'fun', 'weekend', '31', 'October', 'So', 'city', 'Halloween', 'mad', 'nation', 'deserves', 'title', 'pumpkin', 'king', 'After', 'taking', 'account', 'factor', 'trick', 'treat', 'friendliness', 'general', 'fun', 'even', 'average', 'weather', 'forecast', 'website', 'WalletHub', 'math', 'ranked', 'New', 'York', 'City', 'number', 'one', 'Los', 'Angeles', 'close', 'second', 'spook', 'tacular', 'place', 'enjoy', 'annual', 'frightfest', 'None', 'Halloween', 'parade', 'take', 'place', 'Los', 'Angeles', 'New', 'York', 'City', 'One', 'popular', 'activity', 'Halloween', 'attend', 'party', 'parade', 'top', 'city', 'boast', 'biggest', 'shindig', 'around', 'The', 'largest', 'event', 'New', 'York', 'City', 'Village', 'Halloween', 'Parade', 'evening', '31', 'October', 'About', '60', '000', 'reveller', 'join', 'costumed', 'march', '6th', 'Avenue', '16th', 'Street', 'estimated', '2', 'million', 'people', 'watch', 'It',  ...
# ['Labour', 'written', 'competition', 'regulator', 'calling', 'Google', 'reported', 'acquisition', 'Fitbit', 'halted', 'least', 'wider', 'inquiry', 'anticompetitive', 'practice', 'technology', 'sector', 'completed', 'Google', 'made', 'offer', 'purchase', 'fitness', 'tracking', 'company', 'Monday', 'undisclosed', 'price', 'according', 'Reuters', 'Tom', 'Watson', 'shadow', 'digital', 'culture', 'medium', 'sport', 'secretary', 'written', 'Competition', 'Markets', 'Authority', 'CMA', 'request', 'halt', 'acquisition', 'pending', 'full', 'investigation', 'effect', 'competitive', 'landscape', 'I', 'long', 'concerned', 'data', 'monopoly', 'dominate', 'tech', 'market', 'including', 'Google', 'Watson', 'writes', 'These', 'company', 'hold', 'gather', 'unprecedented', 'amount', 'data', 'user', 'monetised', 'micro', 'targeting', 'advertising', 'amass', 'huge', 'profit', 'power', 'Meanwhile', 'digital', 'giant', 'remain', 'unaccountable', 'unregulated', 'see', 'law', 'They', 'run', 'ring', 'around', 'regulation', 'far', 'long', 'This', 'business', 'deal', 'data', 'grab', 'worry', 'u', 'Any', 'proposal', 'must', 'subjected', 'rigorous', 'possible', 'scrutiny', 'must', 'fully', 'investigated', 'CMA', 'Watson', 'specifically', 'single', 'fact', 'Fitbit', 'store', 'physical', 'health', 'data', 'user', 'track', 'activity', 'exercise', 'company', 'range', 'connected', 'wearable', 'device', 'cause', 'concern', 'If', 'acquisition', 'proceed', 'Google', 'could', 'information', 'sleep', 'move', 'eat', 'breathing', 'heartbeat', 'This', 'data', 'could', 'hardly', 'sensitive', 'Google', 'business', 'model', 'information', 'could', 'used', 'micro', 'targeting', 'advertising', 'behaviour', 'modification', 'The', 'risk', 'consumer', 'significant', 'Watson', 'writes', 'The', 'CMA', 'already', 'announced', 'one', 'market', 'study', 'whether', 'Facebook', 'Google', 'dominate', 'online', 'platform', 'digital', 'advertising', 'Watson', 'argues', 'minimum', 'acquisition', 'Fitbit', 'paused', 'CMA', 'market', 'study', 'concluded', 'recommendation', 'implemented', 'Watson', 'also', 'written', 'Information', 'Commissioner', 'Office', 'expressing', 'concern', 'data', 'aspect', 'merger', 'calling', 'Elizabeth', 'Denham', 'information', 'commissioner', 'ass', 'whether', 'raise', 'privacy', 'concern', 'feed', 'back', 'CMA', 'Google', 'provided', 'fitness', 'tracking', 'service', 'Google', 'Fit', 'since', '2014', 'company', 'never', 'offered', 'hardware', 'go', 'along', 'instead', 'relying', 'third', 'party', 'Samsung', 'produce', 'Android', 'Wear', 'smartwatches']
# ['Google', 'latest', 'Pixel', '4', 'XL', 'smartphone', 'bravest', 'yet', 'throwing', 'convention', 'old', 'integrating', 'cutting', 'edge', 'technology', 'attempting', 'round', 'special', 'mix', 'software', 'direct', 'Android', 'maker', 'By', 'probably', 'know', 'drill', 'The', 'Pixel', '4', 'XL', 'metal', 'glass', 'sandwich', 'like', 'practically', 'every', 'phone', 'Unlike', 'though', 'aluminium', 'side', 'black', 'textured', 'coating', 'aid', 'grip', 'back', 'feel', 'almost', 'like', 'super', 'smooth', 'skin', 'silk', 'rather', 'glass', 'It', 'also', 'bold', 'contrasting', 'colour', 'choose', 'white', 'orange', 'variant', 'make', 'stand', 'well', 'competition', 'The', '6', '3in', 'QHD', 'OLED', 'screen', 'big', 'massive', 'today', '6', '5in', 'plus', 'standard', 'It', '90Hz', 'refresh', 'rate', 'certain', 'lighting', 'condition', 'Google', 'say', 'working', 'fix', 'increase', 'Generally', 'make', 'experience', 'using', 'smoother', 'fluid', 'It', 'crisp', 'colourful', 'good', 'viewing', 'angle', 'reach', 'super', 'bright', 'height', 'rival', '90Hz', 'display', 'OnePlus', '7T', 'Pro', 'far', 'wow', 'factor', 'A', 'chunky', 'top', 'bezel', 'hide', 'new', 'Face', 'Unlock', 'system', 'Google', 'new', 'party', 'trick', 'Soli', 'radar', 'system', 'The', 'Pixel', '4', 'XL', 'large', 'phone', 'feel', 'big', 'hand', 'The', 'textured', 'side', 'frosted', 'glass', 'back', 'help', 'grip', 'I', 'never', 'felt', 'I', 'would', 'drop', 'At', '8', '2mm', 'thick', '75', '1mm', 'wide', 'compare', 'favourably', 'Apple', 'iPhone', '11', 'Pro', 'Max', 'OnePlus', '7T', 'Pro', 'undercutting', 'much', '29g', 'It', 'feel', 'like', 'phone', 'meant', 'use', 'without', 'case', 'rather', 'something', 'need', 'protecting', 'although', 'dropping', 'run', 'risk', 'smashing', 'like', 'phone', 'whether', 'people', 'use', 'without', 'case', 'another', 'matter', 'The', 'bottom', 'USB', 'C', 'port', 'back', 'support', 'wireless', 'charging', 'accent', 'colour', 'power', 'button', 'still', 'squeeze', 'side', 'bottom', 'half', 'phone', 'activate', 'Google', 'Assistant', 'Speed', 'long', 'The', 'Pixel', '4', 'XL', '6GB', 'RAM', 'least', '64GB', 'storage', 'one', 'Qualcomm', 'top', 'processor', 'Snapdragon', '855', 'recently', 'replaced', 'slightly', 'faster', '855', 'used', 'OnePlus', '7T', '7T', 'Pro', 'In', 'day', 'day', 'task', 'Pixel', '4', 'XL', 'felt', 'fast', 'fluid', 'significantly', 'faster', 'Samsung', 'Galaxy', 'S10', 'quite', 'super', 'slick', 'OnePlus', '7T', 'Most', 'happy', 'Pixel', '4', 'XL', 'likely', 'continue', 'feeling', 'fast', 'responsive', 'couple', 'year', 'line', 'previous', 'generation', 'Pixels', 'anything', 'go', 'What', 'great', 'battery', 'life', 'The', 'Pixel', '4', 'XL', 'last', '26', 'hour', 'charge', 'medium', 'usage', 'mean', '7am', 'day', 'one', '9am', 'day', 'two', 'working', 'week', 'That', 'really', 'long', 'enough', 'guarantee', 'Pixel', '4', 'XL', 'alive', 'kicking', 'end', 'night', 'see', 'home', 'That', 'using', 'primary', 'device', '200', 'email', 'message', 'push', 'notification', 'couple', 'hour', 'browsing', 'Chrome', 'five', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', '50', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', 'taking', '15', 'photo', 'For', 'comparison', 'OnePlus', '7T', 'last', '34', 'hour', 'similarly', 'sized', 'iPhone', '11', 'Pro', 'Max', 'last', 'shy', '48', 'hour', 'similar', 'condition', 'Turning', 'ambient', 'display', 'feature', 'added', 'two', 'hour', 'battery', 'life', 'The', 'Pixel', '4', 'XL', 'fast', 'charge', '18W', 'via', 'USB', 'C', 'Power', 'Delivery', 'charger', 'one', 'included', 'box', 'wirelessly', 'charge', '11W', 'A', 'full', 'charge', 'via', 'cable', 'took', 'two', 'hour', 'hitting', '70', '50', 'minute', 'The', 'Pixel', '4', 'XL', 'one', 'first', 'smartphones', 'ship', 'latest', 'version', 'Android', '10', 'level', 'polish', 'OnePlus', 'rival', 'bunch', 'Pixel', 'exclusive', 'feature', 'make', 'third', 'party', 'smartphones', 'point', 'Android', '10', 'introduce ...
# ['Apple', 'launched', 'new', 'set', 'popular', 'true', 'wireless', 'earbuds', 'traditional', 'silicone', 'tip', 'noise', 'cancelling', 'software', 'The', 'AirPods', 'Pro', 'similar', 'design', 'current', 'non', 'isolating', 'AirPods', 'complete', 'white', 'stalk', 'ultra', 'compact', 'case', 'But', 'instead', 'plastic', 'duct', 'rest', 'ear', 'allowing', 'sound', 'outside', 'world', 'heard', 'music', 'AirPods', 'Pro', 'aim', 'block', 'Earlier', 'AirPods', 'Apple', 'wired', 'EarPods', 'practically', 'impossible', 'hear', 'noisy', 'public', 'transport', 'That', 'mean', 'user', 'often', 'crank', 'volume', 'potentially', 'hearing', 'damaging', 'level', 'risking', 'annoying', 'around', 'sound', 'bleeding', 'ear', 'due', 'lack', 'isolation', 'Apple', 'hope', 'AirPods', 'Pro', 'solve', 'problem', 'Like', 'noise', 'cancelling', 'headphone', 'new', 'earbuds', 'pair', 'microphone', 'unit', 'detect', 'unwanted', 'noise', 'use', 'speaker', 'cancel', 'inverse', 'soundwave', 'hit', 'wearer', 'eardrum', 'That', 'let', 'user', 'hear', 'music', 'significantly', 'lower', 'volume', 'noisy', 'environment', 'A', 'transparency', 'mode', 'allows', 'wearer', 'pipe', 'sound', 'outside', 'world', 'ear', 'vent', 'equalise', 'pressure', 'avoid', 'plugged', 'feeling', 'The', 'AirPods', 'Pro', 'also', 'adaptive', 'equaliser', 'technology', 'tune', 'sound', 'shape', 'individual', 'ear', 'The', 'earbuds', 'five', 'hour', 'continuous', 'playback', 'time', '4', '5', 'hour', 'noise', 'cancelling', 'active', 'case', 'provide', 'additional', '18', 'hour', 'charging', 'They', 'also', 'support', 'hand', 'free', 'Hey', 'Siri', 'activation', 'Apple', 'voice', 'assistant', 'announce', 'message', 'arrive', 'iPhone', 'The', 'earbuds', 'also', 'sweat', 'resistant', 'The', 'AirPods', 'Pro', 'cost', '249', 'UK', '249', 'US', 'ship', '30', 'October', 'None', 'Best', 'true', 'wireless', 'earbuds', '2019', 'AirPods', 'Samsung', 'Jabra', 'Beats', 'Anker', 'compared', 'ranked']
# ['I', 'use', '9', '7in', 'Samsung', 'Galaxy', 'Tab', 'S2', 'tablet', 'general', 'browsing', 'email', 'reading', 'digital', 'magazine', 'basic', 'photo', 'editing', 'It', '32GB', 'storage', 'apps', 'installed', '128GB', 'SD', 'card', 'However', 'battery', 'longer', 'Samsung', 'updated', 'version', 'Android', 'still', 'running', 'Android', '7', 'I', 'thinking', 'getting', 'new', 'iPad', 'Apple', 'seems', 'support', 'machine', 'longer', 'apps', 'seem', 'better', 'suited', 'need', 'anecdotally', 'appear', 'secure', 'On', 'budget', 'I', 'decide', 'iPad', 'Air', '256GB', 'iPad', 'Pro', '11', '64GB', 'Both', 'fit', 'camera', 'bag', 'Is', 'better', 'opt', 'tablet', 'built', 'storage', 'one', 'better', 'processor', 'Len', 'The', 'challenge', 'anyone', 'designing', 'computing', 'device', 'whether', 'desktop', 'laptop', 'tablet', 'smartphone', 'create', 'machine', 'properly', 'balanced', 'meet', 'user', 'need', 'price', 'charged', 'This', 'exact', 'science', 'It', 'depends', 'cost', 'major', 'component', 'processor', 'memory', 'screen', 'graphic', 'storage', 'module', 'operating', 'system', 'But', 'trust', 'saddle', 'low', 'end', 'device', 'cost', 'high', 'end', 'processor', 'compromise', 'high', 'end', 'device', 'providing', 'little', 'memory', 'storage', 'space', 'This', 'problem', 'iPad', 'Pro', '11', '12', '9', 'stuck', 'choice', 'face', 'It', 'hard', 'read', 'trend', 'technology', 'market', 'two', 'obvious', 'one', 'apply', 'First', 'people', 'need', 'storage', 'handle', 'apps', 'digital', 'content', 'cheap', 'free', 'thanks', 'higher', 'broadband', 'speed', 'easy', 'download', 'We', 'longer', 'listening', '64kbps', 'MP3', 'file', 'watching', '640', 'x', '480', 'pixel', 'movie', 'file', 'size', 'much', 'bigger', 'used', 'So', 'web', 'page', 'Second', 'cost', 'Flash', 'memory', 'chip', 'falling', 'rapid', 'rate', 'even', 'growing', 'size', 'I', 'remember', 'chuffed', 'buying', 'storage', 'card', '1', 'per', 'megabyte', 'Today', 'I', 'buy', '128GB', 'card', 'le', '20', '64', 'megabyte', 'per', 'penny', 'Under', 'circumstance', '64GB', 'fit', 'smartphones', 'Chromebooks', 'netbook', 'type', 'Windows', 'laptop', 'Shipping', 'high', 'end', '769', 'tablet', 'iPad', 'Pro', '64GB', 'insane', 'It', '128GB', 'would', 'rational', 'fit', 'companion', 'model', '256GB', '919', '512GB', '1', '119', '1TB', '1', '319', 'Then', 'step', 'would', 'double', 'storage', 'There', 'another', 'way', 'look', 'If', 'buy', '64GB', 'iPad', 'Pro', '11', 'paying', '12', 'per', 'gigabyte', 'storage', 'If', 'buy', '256GB', 'version', 'price', 'drop', '3', '59', 'per', 'gigabyte', '1TB', '1', '29', 'Putting', '128GB', 'entry', 'level', 'model', '6', 'per', 'gigabyte', 'make', 'bargain', 'would', 'line', 'rest', 'range', 'And', 'extra', 'cost', 'fitting', '128GB', 'would', 'peanut', 'retail', 'price', 'without', 'even', 'considering', 'massive', 'discount', 'Apple', 'must', 'get', 'buying', 'million', 'In', 'short', 'I', 'think', 'anyone', 'buy', '64GB', 'iPad', 'Pro', 'Either', 'bust', 'budget', 'buy', 'iPad', 'Pro', '11', '256GB', 'storage', 'space', 'get', 'Air', 'amount', 'Alternatively', 'wait', 'Apple', 'release', 'new', 'version', 'iPad', 'Pro', 'start', '128GB', 'This', 'could', 'happen', 'November', 'current', 'model', 'released', 'November', 'last', 'year', 'perhaps', 'March', '2020', 'later', 'Your', 'Tab', 'S2', 'dead', 'yet', 'You', 'already', 'experienced', 'tablet', 'user', '160GB', 'storage', 'good', 'idea', 'much', 'space', 'need', 'My', 'rule', 'thumb', 'try', 'double', 'everything', 'new', 'device', 'always', 'need', 'everything', 'future', 'le', 'doubling', 'rarely', 'feel', 'like', 'real', 'advance', 'Unfortunately', 'tablet', 'smartphones', 'ultra', 'thin', 'laptop', 'let', 'upgrade', 'processor', 'You', 'stuck', 'next', 'five', 'year', 'It', 'good', 'idea', 'aim', 'high', 'With', 'storage', 'space', 'however', 'flexibility', 'Lots', 'device', 'SD', 'card', 'slot', 'know', 'cheap', 'convenient', 'way', 'alleviate', 'problem', 'machine', 'enough', ...
# ['Always', 'screen', 'completes', 'package', 'kicking', 'competitor', 'curb', 'becoming', 'top', 'reason', 'buy', 'iPhone', 'When', 'Apple', 'launched', 'smartwatch', '2015', 'lukewarm', 'reception', 'critic', 'claimed', 'would', 'never', 'take', 'like', 'iPod', 'iPhone', 'But', 'sale', 'Apple', 'Watch', 'quickly', 'eclipsed', 'every', 'smartwatch', 'wearable', 'technology', 'sale', 'soaring', 'expected', 'year', 'outsell', 'Swiss', 'watchmaker', 'combined', 'The', 'latest', 'Apple', 'Watch', 'Series', '5', 'iteration', 'though', 'still', 'pricey', '399', 'look', 'likely', 'continue', 'firm', 'domination', 'smartwatch', 'market', 'deservedly', 'If', 'unfamiliar', 'Apple', 'smartwatches', 'work', 'also', 'Apple', 'iPhone', '6S', 'newer', 'connecting', 'smartphone', 'via', 'Bluetooth', 'It', 'genius', 'link', 'tie', 'buyer', 'Apple', 'ecosphere', 'adding', 'important', 'alternative', 'revenue', 'stream', 'people', 'hold', 'onto', 'phone', 'But', 'take', 'away', 'extraordinary', 'quality', 'watch', 'The', 'Series', '5', 'build', 'last', 'year', 'larger', 'screen', 'redesign', 'Apple', 'Watch', 'making', 'one', 'small', 'important', 'change', 'screen', 'stay', 'time', 'It', 'feature', 'every', 'smartwatch', 'year', 'important', 'actually', 'telling', 'time', 'absolutely', 'essential', 'something', 'permanent', 'place', 'wrist', 'Until', 'Apple', 'Watch', 'owner', 'either', 'tap', 'face', 'elaborate', 'wrist', 'rotation', 'gesture', 'get', 'screen', 'light', 'never', 'worked', 'I', 'really', 'needed', 'running', 'train', 'Now', 'see', 'time', 'glance', 'time', 'angle', 'The', 'rest', 'Apple', 'Watch', 'always', 'top', 'notch', 'Equipped', 'right', 'strap', 'tried', 'Sport', 'Loop', 'one', 'many', 'clone', 'absolutely', 'must', 'Apple', 'Watch', 'comfortable', 'timepiece', 'I', 'pleasure', 'strapping', 'wrist', 'beating', 'best', 'Swiss', 'watchmaker', 'offer', 'It', 'neither', 'heavy', 'light', 'hide', 'heart', 'rate', 'sensor', 'curved', 'lump', 'belly', 'comfortably', 'sitting', 'atop', 'wrist', 'It', 'fit', 'easily', 'shirt', 'cuff', 'larger', 'smartwatches', 'It', 'water', 'resistant', 'depth', '50m', 'mean', 'likely', 'never', 'worry', 'take', 'dip', 'pool', 'The', 'screen', 'bright', 'crisp', 'clearly', 'visible', 'circumstance', 'I', 'never', 'massive', 'fan', 'rectangular', 'shape', 'preferring', 'watch', 'circular', 'variety', 'Series', '5', 'round', 'last', 'month', 'Apple', 'still', 'lead', 'way', 'haptics', 'little', 'vibration', 'tap', 'watch', 'make', 'let', 'know', 'something', 'happened', 'I', 'loved', 'original', '2015', 'still', 'mile', 'better', 'anything', 'else', 'market', 'five', 'generation', 'later', 'Victim', 'success', 'One', 'thing', 'might', 'appreciate', 'strap', 'one', 'wrist', 'many', 'wild', 'looking', 'I', 'one', 'conform', 'particular', 'fashion', 'club', 'I', 'often', 'get', 'twinge', 'embarrassment', 'feel', 'walk', 'room', 'spot', 'someone', 'wearing', 'shirt', 'dress', 'It', 'made', 'little', 'better', 'Series', '5', 'screen', 'time', 'pick', 'slightly', 'different', 'face', 'putting', 'one', 'instantly', 'become', 'one', 'Apple', 'Watch', 'people', 'Apple', 'provides', 'load', 'watch', 'face', 'infinitely', 'tweakable', 'colour', 'many', 'dial', 'customisation', 'Then', 'sizeable', 'collection', 'widget', 'thing', 'like', 'timer', 'weather', 'activity', 'others', 'called', 'complication', 'But', 'I', 'found', 'always', 'something', 'quite', 'perfect', 'face', 'I', 'change', 'I', 'love', 'new', 'Numerals', 'Duo', 'face', 'I', 'wish', 'could', 'date', 'I', 'really', 'like', 'Meridian', 'analogue', 'face', 'wish', 'option', 'numeral', 'tick', 'I', 'also', 'find', 'round', 'analogue', 'face', 'hard', 'read', 'glance', 'even', '44mm', 'Series', '5', 'bit', 'small', 'I', 'picky', 'thing', 'something', 'wear', 'quite', 'want', 'going', 'notice', 'annoyed', 'Of', 'course', 'Apple', 'Watch', 'tell', 'time', 'Notifications', 'high', 'point', 'A', 'little', 'tap', 'wrist', 'know', 'something', 'happened' ...
# ['Still', 'absolute', 'beast', 'every', 'way', 'even', 'minor', 'update', 'already', 'cracking', 'smartphone', 'The', 'OnePlus', '7T', 'Pro', 'update', 'best', 'phone', 'first', 'half', '2019', 'good', 'news', 'messed', 'tweak', 'make', 'good', 'better', 'model', 'replaces', 'The', 'bad', 'news', 'updated', 'phone', 'start', '50', 'predecessor', '699', 'although', 'also', 'come', 'storage', 'RAM', 'effect', 'match', 'cost', 'earlier', 'mid', 'range', '7', 'Pro', 'version', 'It', 'also', 'gain', 'faster', 'processor', 'improved', 'camera', 'slightly', 'tweaked', 'paint', 'job', 'The', 'star', 'show', '6', '67in', '90Hz', 'QHD', 'AMOLED', 'screen', 'stunning', 'five', 'month', 'ago', 'Once', 'get', 'used', 'smoothness', '90Hz', 'display', 'difficult', 'go', 'back', 'The', 'popup', 'selfie', 'camera', 'remove', 'notch', 'top', 'bezel', 'still', 'thin', 'round', 'curved', 'side', 'reaching', 'slim', 'metal', 'band', 'side', 'curved', 'glass', 'back', 'It', 'attractive', 'incredibly', 'modern', 'looking', 'design', 'excellent', 'build', 'quality', 'The', '7T', 'Pro', 'big', 'heavy', 'predecessor', '206g', '162', '6mm', 'tall', '75', '9mm', 'wide', '8', '8mm', 'thick', 'While', 'much', 'manageable', 'Apple', 'iPhone', '11', 'Pro', 'Max', '77', '8mm', 'wide', '226g', '7T', 'Pro', 'still', 'beast', 'right', 'limit', 'usability', 'smaller', 'hand', 'struggle', 'The', '7T', 'may', 'little', 'bit', 'smaller', '6', '55in', 'screen', '74', '4mm', 'wide', '190g', 'difference', 'palpable', 'Flip', 'phone', 'treated', 'slightly', 'lighter', 'equally', 'gorgeous', 'shade', 'blue', 'glass', 'back', 'There', 'also', 'new', 'laser', 'focus', 'patch', 'left', 'vertical', 'camera', 'lump', 'The', 'USB', 'C', 'socket', 'bottom', 'input', 'charging', 'connecting', 'wired', 'headphone', 'The', 'OnePlus', '7T', 'Pro', 'faster', 'paper', 'predecessor', 'Qualcomm', 'slightly', 'newer', 'Snapdragon', '855', 'chip', '15', 'faster', 'graphic', 'slightly', 'faster', 'processor', 'Whether', 'anyone', 'able', 'tell', 'remains', 'seen', 'The', 'OnePlus', '7', 'Pro', 'already', 'fastest', 'feeling', 'phone', 'available', '7T', 'Pro', 'different', 'powering', 'thing', 'immediacy', 'unrivalled', 'anything', 'else', 'market', 'There', 'two', 'version', 'available', 'The', 'standard', 'widely', 'available', '7T', 'Pro', 'come', '8GB', 'RAM', '256GB', 'storage', 'A', 'McLaren', 'Edition', '12GB', 'RAM', '256GB', 'storage', 'well', 'new', 'black', 'orange', 'paint', 'job', 'also', 'available', 'limited', 'quantity', 'All', 'speed', 'backed', 'solid', 'battery', 'life', '32', 'hour', 'charge', 'four', 'hour', 'longer', 'OnePlus', '7', 'Pro', 'enough', 'last', '7am', 'day', 'one', '3pm', 'day', 'two', 'That', 'primary', 'device', 'usual', 'deluge', 'email', 'message', 'push', 'notification', 'lot', 'browsing', 'five', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', 'watching', '50', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', 'shooting', '10', 'photo', 'day', 'Despite', 'glass', 'back', 'still', 'wireless', 'charging', 'Instead', 'OnePlus', 'reduced', 'internal', 'resistance', 'battery', 'make', 'charge', 'even', 'faster', 'hitting', '70', '34', 'minute', 'full', '70', 'minute', 'The', '7T', 'Pro', 'ship', 'box', 'OxygenOS', '10', 'based', 'latest', 'version', 'Android', '10', 'making', 'one', 'first', 'phone', 'like', '7T', 'OxygenOS', 'continues', 'set', 'standard', 'custom', 'version', 'Android', 'third', 'party', 'manufacturer', 'focused', 'refinement', 'speed', 'Full', 'theming', 'support', 'changing', 'colour', 'shape', 'screen', 'icon', 'box', 'including', 'full', 'dark', 'mode', 'new', 'version', 'But', 'Google', 'new', 'swiping', 'navigation', 'gesture', 'replacing', 'custom', 'one', 'used', 'OnePlus', 'previous', 'phone', 'biggest', 'improvement', 'Swipe', 'bar', 'bottom', 'screen', 'go', 'home', 'hold', 'recently', 'used', 'apps', 'left', 'right', 'jump', 'previously', 'used', 'app', 'A', 'swipe', 'left', 'right', 'side', 'lower', 'two', 'th ...
# ['First', 'book', 'Kindle', 'It', 'DVD', 'box', 'set', 'making', 'show', 'It', 'CDs', 'streaming', 'music', 'festival', 'The', 'next', 'step', 'Amazon', 'iterative', 'takeover', 'western', 'culture', 'announced', 'December', 'Las', 'Vegas', 'Intersect', 'two', 'day', 'festival', 'featuring', 'act', 'including', 'Foo', 'Fighters', 'Beck', 'Kacey', 'Musgraves', 'Anderson', 'Paak', 'It', 'also', 'promise', 'postapocalyptic', 'dodgeball', 'stadium', 'mega', 'sized', 'ball', 'pit', '200', '000', 'ball', 'visual', 'art', 'installation', 'game', 'including', 'one', 'try', 'mash', 'button', 'high', 'speed', 'The', 'latter', 'perfect', 'symbol', 'enterprise', 'one', 'value', 'immediate', 'sensory', 'thrill', 'deep', 'cultural', 'engagement', 'try', 'press', 'every', 'pop', 'cultural', 'button', 'hard', 'fast', 'attempt', 'succeed', 'The', 'lineup', 'face', 'firmly', 'towards', 'millennials', 'Gen', 'Z', 'hipster', 'Amazon', 'need', 'ensure', 'ongoing', 'relevance', 'leftfield', 'black', 'talent', 'Flying', 'Lotus', 'HER', 'Thundercat', 'Jpegmafia', 'new', 'indie', 'star', 'like', 'Japanese', 'Breakfast', 'Snail', 'Mail', 'Miya', 'Folick', 'dance', 'track', 'Jamie', 'xx', 'Max', 'Cooper', 'Gesaffelstein', 'The', 'Black', 'Madonna', 'another', 'DJs', 'booked', 'play', 'reacted', 'horror', 'festival', 'announcement', 'saying', 'Amazon', 'name', 'mentioned', 'paperwork', 'signed', 'Musgraves', 'meanwhile', 'set', 'perform', 'alongside', '500', 'Intel', 'drone', 'programmed', 'flown', 'female', 'led', 'team', 'tribute', 'woman', 'contribution', 'advancement', 'technology', 'Given', 'gender', 'pay', 'gap', '11', '6', 'among', 'computer', 'programmer', 'US', 'way', 'national', 'average', '4', '9', 'wretchedly', 'offensive', 'banal', 'initiative', 'With', 'excellent', 'studiously', 'diverse', 'music', 'lineup', 'Intersect', 'merely', 'attempt', 'gild', 'Amazon', 'wokeness', 'credibility', 'This', 'nothing', 'new', 'Music', 'cheap', 'easily', 'available', 'cultural', 'form', 'accessible', 'via', 'streaming', 'radio', 'YouTube', 'elsewhere', 'Compared', 'film', 'TV', 'literature', 'anything', 'stage', 'also', 'cheapest', 'easiest', 'make', 'grassroots', 'scene', 'blue', 'UK', 'drill', 'attest', 'So', 'music', 'immediacy', 'authenticity', 'absolute', 'catnip', 'brand', 'long', 'quality', 'advertising', 'simplest', 'way', 'access', 'simply', 'shackle', 'music', 'Red', 'Bull', 'master', 'craft', 'nurturing', 'musician', 'Red', 'Bull', 'Music', 'Academy', 'publishing', 'music', 'journalism', 'switched', 'tack', 'festival', 'held', 'London', 'last', 'month', 'headlined', 'Aphex', 'Twin', 'Savvier', 'still', 'Boiler', 'Room', 'live', 'streaming', 'brand', 'supported', 'dance', 'music', 'site', 'started', 'music', 'festival', 'also', 'advertising', 'agency', 'leveraging', 'cool', 'data', 'led', 'audience', 'insight', 'earned', 'last', 'decade', 'sell', 'back', 'brand', 'The', 'two', 'big', 'name', 'streaming', 'Spotify', 'Apple', 'music', 'event', 'former', 'Who', 'We', 'Be', 'festival', 'return', 'third', 'year', 'November', 'latter', 'replaced', 'Apple', 'Music', 'festival', 'Up', 'Next', 'Live', 'concert', 'series', 'Other', 'music', 'festival', 'may', 'run', 'brand', 'advertising', 'agency', 'feel', 'way', 'Over', 'last', 'two', 'year', 'strange', 'ghastly', 'experience', 'walking', 'London', 'All', 'Points', 'East', 'festival', 'whose', 'branding', 'aesthetic', 'echoed', 'Amazon', 'Intersect', 'brilliance', 'artist', 'Björk', 'Nick', 'Cave', 'etc', 'dulled', 'vast', 'walk', 'advertising', 'experience', 'Jägermeister', 'Samsung', 'Tinder', 'others', 'This', 'co', 'opting', 'musical', 'space', 'branding', 'become', 'normalised', 'head', 'one', 'hip', 'independent', 'London', 'music', 'company', 'told', 'audience', 'see', 'le', 'legitimate', 'brand', 'partnership', 'A', 'PR', 'Red', 'Bull', 'recently', 'assured', 'regarding', 'coverage', 'one', 'event', 'sponsored', 'branded', 'event', 'event', 'produced', 'owned', 'Red', 'Bull', 'Medici', 'style', ' ...
# ['The', 'OnePlus', '7T', 'take', 'best', 'bit', 'brilliant', 'OnePlus', '7', 'Pro', 'condenses', 'smaller', 'cheaper', 'package', 'Released', 'le', 'four', 'month', 'last', 'version', 'hit', 'shelf', 'new', '500', '7T', 'mess', 'much', 'winning', 'formula', 'simply', 'adding', 'better', 'camera', 'market', 'leading', '90Hz', 'screen', 'technology', 'OnePlus', 'launch', 'new', 'phone', 'every', 'six', 'month', 'typically', 'improved', 'specification', 'small', 'tweak', 'design', 'While', '6T', '7', 'transition', 'particularly', 'big', 'step', 'new', 'processor', 'faster', 'fingerprint', 'scanner', '7T', 'brings', '90Hz', 'screen', '7', 'Pro', 'smaller', 'cheaper', 'device', 'Although', 'probably', 'tell', 'unless', 'put', 'side', 'side', 'predecessor', '7T', '4mm', 'longer', 'screen', 'slightly', 'taller', 'smaller', 'widow', 'peak', 'notch', 'selfie', 'camera', 'Some', '18', 'month', 'design', 'still', 'feel', 'fresh', 'particularly', 'compared', 'phone', 'massive', 'notch', 'The', '90Hz', '6', '55in', 'Fluid', 'AMOLED', 'screen', 'star', 'show', 'It', 'bright', 'smooth', 'pleasure', 'use', 'At', 'Full', 'HD', 'le', 'pixel', 'dense', 'QHD', 'screen', '7', 'Pro', 'hard', 'pressed', 'tell', 'screen', 'flat', 'curved', 'edge', 'le', 'visually', 'arresting', 'though', 'might', 'prefer', 'use', 'The', 'front', 'glass', 'meet', 'polished', 'metal', 'band', 'side', 'curved', 'glass', 'back', 'narrow', '74', '4mm', 'width', 'make', 'OnePlus', '7T', 'one', 'easiest', 'large', 'screen', 'smartphones', 'hold', 'particularly', 'compared', '6', '5in', 'iPhone', '11', 'Pro', 'The', 'back', 'also', 'new', 'large', 'circular', 'lump', 'containing', 'new', 'triple', 'camera', 'system', 'look', 'fairly', 'attractive', 'though', 'feel', 'finger', 'normal', 'use', 'New', '7T', 'bump', 'Qualcomm', 'Snapdragon', '855', 'chip', '15', 'faster', 'graphic', 'slightly', 'faster', 'CPU', 'otherwise', 'Snapdragon', '855', '7', 'many', 'smartphones', 'year', 'In', 'UK', 'rest', 'specification', 'reduced', 'one', 'option', '8GB', 'RAM', '128GB', 'UFS3', '0', 'storage', '256GB', 'version', 'available', 'elsewhere', 'effectively', 'eliminating', 'cheapest', '6GB', 'RAM', 'configuration', 'predecessor', 'The', 'phone', 'absolutely', 'fly', 'Every', 'action', 'sense', 'immediacy', 'unrivalled', 'smartphone', 'industry', 'Now', '90Hz', 'display', 'everything', 'even', 'smoother', 'enjoyable', 'even', 'mundane', 'thing', 'scrolling', 'web', 'page', 'social', 'medium', 'post', 'pleasurable', 'Battery', 'life', '7T', 'slightly', 'worse', '34', 'hour', '7', 'The', 'new', '7T', 'last', '31', 'hour', 'charge', 'medium', 'heavy', 'usage', '200', 'email', 'message', 'push', 'notification', 'couple', 'hour', 'browsing', 'Chrome', 'five', 'hour', 'Spotify', 'via', 'Bluetooth', 'headphone', '90', 'minute', 'Into', 'Badlands', 'Amazon', 'Prime', 'Video', '15', 'photo', 'That', 'mean', '7T', 'reliably', 'make', '7am', 'day', 'one', '2pm', 'day', 'two', 'There', 'wireless', 'charging', 'improved', 'Warp', 'Charge', '30T', 'technology', 'see', '7T', 'hit', 'full', 'charge', '60', 'minute', 'flat', 'half', 'hour', 'le', 'previous', 'version', 'one', 'fastest', 'available', 'The', 'OnePlus', '7T', 'ship', 'Oxygen', 'OS10', 'based', 'latest', 'Android', '10', 'making', 'one', 'first', 'smartphones', 'sale', 'use', 'OxygenOS', 'continues', 'one', 'best', 'implementation', 'Android', 'focusing', 'speed', 'customisation', 'New', 'version', '10', 'complete', 'theming', 'engine', 'addition', 'usual', 'wallpaper', 'change', 'allows', 'customise', 'colour', 'button', 'background', 'shape', 'icon', 'dialogue', 'box', 'font', 'ambient', 'clock', 'display', 'even', 'fingerprint', 'scanner', 'animation', 'Also', 'new', 'integration', 'Google', 'new', 'Android', '10', 'gesture', 'navigation', 'eschews', 'traditional', 'three', 'button', 'two', 'button', 'navigation', 'system', 'new', 'gesture', 'bar', 'Swipe', 'bar', 'go', 'home', 'hold', 'recently', 'used', 'apps', 'left', 'right', 'jump',  ...
# ['In', 'country', 'biggest', 'company', 'still', 'king', 'Seoul', 'burgeoning', 'startup', 'sector', 'finding', 'foot', 'Out', 'west', 'South', 'Korean', 'capital', 'nine', 'storey', 'building', 'dressed', 'bright', 'colour', 'giant', 'red', 'bull', 'outside', 'home', '100', 'startup', 'From', 'one', 'person', 'operation', 'running', 'locker', 'laptop', 'ground', 'floor', 'fully', 'fledged', 'office', 'upper', 'level', 'Seoul', 'startup', 'hub', 'supported', '1', '282', 'operation', 'various', 'stage', 'growth', 'past', 'two', 'year', 'It', 'bell', 'whistle', 'come', 'associate', 'startup', 'hub', 'across', 'world', 'shared', 'dining', 'working', 'space', 'rest', 'area', 'beanbag', 'egg', 'shaped', 'couch', 'fully', 'decked', 'kitchen', 'food', 'tech', 'company', 'broadcast', 'studio', 'library', 'slide', 'two', 'floor', 'even', '7', 'Eleven', 'powering', 'night', 'There', '467', 'accelerator', 'venture', 'capital', 'fund', 'government', 'organisation', 'supporting', 'startup', 'Seoul', 'surrounding', 'province', '2018', 'backed', 'bigger', 'company', 'Samsung', 'Naver', 'There', '85', 'accelerator', 'Seoul', 'amount', 'angel', 'investment', 'increased', 'US', '170m', '250m', '2015', 'US', '250m', '2017', 'Since', '2015', 'South', 'Korean', 'government', 'provided', '4bn', 'startup', 'Forbes', 'reported', 'biggest', 'government', 'backing', 'startup', 'per', 'caput', 'world', 'In', 'April', 'Seoul', 'mayor', 'Park', 'Won', 'soon', 'said', 'aim', 'make', 'Seoul', 'global', 'top', 'five', 'startup', 'city', '2022', 'Korea', 'particularly', 'attractive', 'startup', 'high', 'speed', 'internet', 'fast', 'rollout', '5G', 'network', 'high', 'uptake', 'technology', 'The', 'push', 'towards', 'startup', 'driven', 'slow', 'growth', 'traditional', 'larger', 'company', 'according', 'Seoul', 'Startup', 'Hub', 'co', 'founder', 'Matt', 'Kang', 'We', 'lost', 'momentum', 'large', 'company', 'startup', 'emerged', 'new', 'momentum', 'Korea', 'said', 'One', 'startup', 'moved', 'hub', 'month', 'ago', 'Amuse', 'Travel', 'social', 'enterprise', 'provides', 'tour', 'people', 'living', 'disability', 'popular', 'destination', 'around', 'South', 'Korea', 'well', 'giving', 'people', 'living', 'disability', 'confidence', 'travel', 'The', 'company', 'develops', 'map', 'tourist', 'destination', 'based', 'data', 'collected', 'tour', 'highlighting', 'area', 'positive', 'negative', 'aspect', 'steep', 'incline', 'stair', 'barrier', 'access', 'The', 'company', 'founder', 'Seo', 'yeon', 'Oh', 'said', 'previously', 'difficulty', 'raising', 'enough', 'investment', 'needed', 'time', 'prove', 'viability', 'company', 'He', 'said', 'Naver', 'expressed', 'interest', 'business', 'Moving', 'startup', 'hub', 'meant', 'Oh', 'staff', 'able', 'network', 'variety', 'business', 'various', 'stage', 'life', 'The', 'strength', 'hub', 'wide', 'spectrum', 'startup', 'company', 'fintech', 'senior', 'citizen', 'also', 'startup', 'company', 'experienced', 'failure', 'past', 'said', 'Koreans', 'seem', 'shy', 'seem', 'work', 'alone', 'independently', 'also', 'co', 'work', 'work', 'together', 'Josh', 'Taylor', 'visited', 'Korea', 'part', 'Walkley', 'Foundation', 'Australia', 'Korea', 'exchange', 'program', 'partnership', 'Korea', 'Press', 'Foundation']
# ['I', 'think', 'least', 'make', 'effort', 'describe', 'It', 'like', 'smiley', 'face', 'yawning', 'Happy', 'And', 'new', 'Honestly', 'big', 'deal', 'I', 'like', 'know', 'come', 'It', 'really', 'boring', 'story', 'Still', 'Fine', 'like', 'emojis', 'yawning', 'emoji', 'born', 'two', 'year', 'process', 'start', 'proposal', 'Unicode', 'Consortium', 'international', 'nonprofit', 'organisation', 'set', 'standard', 'representation', 'character', 'across', 'various', 'programme', 'platform', 'You', 'kidding', 'I', 'wish', 'In', 'recent', 'annual', 'update', 'Unicode', 'announced', 'introduction', 'Yawning', 'Face', 'AKA', 'U', '1F971', 'along', 'dozen', 'emojis', 'But', 'proposes', 'new', 'emojis', 'first', 'place', 'Anyone', 'submit', 'proposal', 'successful', 'emojis', 'must', 'meet', 'criterion', 'Which', 'criterion', 'Emojis', 'must', 'graphically', 'legible', 'small', 'useful', 'What', 'possible', 'communicative', 'us', 'could', 'yawning', 'emoji', 'Actually', 'I', 'think', 'occasion', 'I', 'use', 'Because', 'tired', 'time', 'Tired', 'bored', 'supremely', 'unconcerned', 'merely', 'underwhelmed', 'peremptorily', 'dismissive', 'enthusiasm', 'shown', 'others', 'I', 'see', 'mean', 'What', 'ever', 'without', 'yawning', 'emoji', 'I', 'remember', 'I', 'think', 'used', 'type', 'word', 'yawn', 'Every', 'time', 'How', 'tiresome', 'Exactly', 'Yawn', 'Where', 'though', 'I', 'find', 'yawning', 'face', 'among', 'sea', 'little', 'round', 'emoting', 'head', 'phone', 'menu', 'That', 'probably', 'got', 'iPhone', 'Each', 'vendor', 'responsible', 'adding', 'new', 'batch', 'emojis', 'Apple', 'done', 'yet', 'Yawning', 'Face', 'included', 'iOS', '13', '2', 'update', 'due', 'imminently', 'rolled', 'Twitter', 'Facebook', 'well', 'Microsoft', 'Samsung', 'Google', 'device', 'So', 'fun', 'useful', 'emojis', 'expect', 'autumn', 'There', 'new', 'hearing', 'aid', 'wheelchair', 'symbol', 'Holding', 'Hands', 'emoji', 'available', '75', 'permutation', 'gender', 'skin', 'tone', 'Also', 'garlic', 'plate', 'falafel', 'five', 'string', 'banjo', 'Huh', 'What', 'I', 'wanted', 'specifically', 'reference', 'four', 'string', 'banjo', 'There', 'still', 'time', 'get', 'proposal', 'next', 'year', 'Do', 'say', 'I', 'care', 'le', 'new', 'Yawning', 'Face', 'emoji', 'Yawning', 'Face', 'emoji', 'Don', 'say', 'Man', 'I', 'stayed', 'late', 'last', 'night', 'U', '1F971', 'U', '1F971', 'U', '1F971']
# ['Plastic', 'packaging', 'many', 'amazing', 'quality', 'It', 'keep', 'food', 'fresh', 'hold', 'liquid', 'without', 'going', 'soggy', 'It', 'also', 'moulded', 'variety', 'shape', 'unlike', 'glass', 'shatter', 'drop', 'But', 'one', 'quality', 'make', 'useful', 'durability', 'also', 'mean', 'take', 'approximately', '450', 'year', 'biodegrade', 'It', 'therefore', 'imperative', 'reuse', 'redesign', 'recycle', 'plastic', 'packaging', 'end', 'buried', 'landfill', 'clogging', 'ocean', 'century', 'come', 'But', 'given', '14', 'plastic', 'packaging', 'get', 'recycled', 'today', 'clearly', 'lot', 'work', 'still', 'especially', 'come', 'creating', 'packaging', 'design', 'easier', 'recycle', 'use', 'le', 'material', 'contain', 'recycled', 'plastic', 'One', 'biggest', 'barrier', 'better', 'design', 'higher', 'cost', 'constrained', 'supply', 'recycled', 'plastic', 'compared', 'virgin', 'type', 'So', 'April', '2022', 'UK', 'government', 'plan', 'introduce', 'new', 'tax', 'plastic', 'packaging', 'contain', 'minimum', '30', 'recycled', 'content', 'It', 'hope', 'transform', 'economics', 'sustainable', 'packaging', 'driving', 'demand', 'recycled', 'material', 'discouraging', 'production', 'single', 'use', 'packaging', 'recycled', 'content', 'The', 'EU', 'also', 'want', 'make', 'plastic', 'packaging', 'across', 'Europe', 'recyclable', 'reusable', '2030', 'allocating', 'additional', '100m', 'top', 'current', 'spending', 'research', 'better', 'design', 'durability', 'recyclability', 'Initiatives', 'Alliance', 'End', 'Plastic', 'Waste', 'New', 'Plastics', 'Economy', 'aim', 'build', 'momentum', 'towards', 'plastic', 'system', 'based', 'circular', 'economy', 'principle', 'also', 'brought', 'together', 'stakeholder', 'across', 'plastic', 'value', 'chain', 'rethink', 'way', 'plastic', 'designed', 'produced', 'used', 'recycled', 'reprocessed', 'Black', 'plastic', 'often', 'used', 'package', 'ready', 'meal', 'high', 'list', 'packaging', 'need', 'redesigning', 'The', 'near', 'infrared', 'technology', 'found', 'plastic', 'sorting', 'facility', 'us', 'light', 'reflection', 'identify', 'different', 'type', 'plastic', 'sort', 'appropriately', 'But', 'due', 'presence', 'carbon', 'black', 'ready', 'meal', 'tray', 'type', 'black', 'plastic', 'simply', 'absorb', 'light', 'rather', 'reflecting', 'back', 'machine', 'effectively', 'rendering', 'unrecyclable', 'Henkel', 'global', 'chemical', 'consumer', 'good', 'company', 'behind', 'well', 'known', 'brand', 'Loctite', 'Pritt', 'Sellotape', 'Schwarzkopf', 'Dylon', 'Colour', 'Catcher', 'decided', 'tackle', 'black', 'plastic', 'problem', 'partnership', 'colouring', 'supplier', 'Ampacet', 'Together', 'developed', 'black', 'plastic', 'us', 'alternative', 'carbon', 'free', 'black', 'colour', 'detected', 'sorting', 'machine', 'We', 'already', 'begun', 'integrating', 'product', 'portfolio', 'starting', 'bottle', 'toilet', 'cleaning', 'product', 'say', 'Dr', 'Thorsten', 'Leopold', 'head', 'international', 'packaging', 'development', 'home', 'care', 'product', 'Henkel', 'In', 'time', 'carbon', 'free', 'colour', 'rolled', 'across', 'company', 'black', 'plastic', 'packaging', 'ensure', 'formerly', 'unrecyclable', 'plastic', 'become', 'waste', 'The', 'project', 'part', 'Henkel', 'goal', 'making', '100', 'consumer', 'packaging', 'recyclable', 'reusable', 'compostable', '2025', 'also', 'increasing', 'share', 'recycled', 'plastic', 'European', 'consumer', 'good', 'product', '35', 'In', 'order', 'meet', 'target', 'Henkel', 'packaging', 'developer', 'follow', 'three', 'main', 'principle', 'prevent', 'reduce', 'reuse', 'This', 'mean', 'producing', 'le', 'packaging', 'waste', 'developing', 'better', 'packaging', 'enabling', 'circular', 'economy', 'For', 'example', 'company', 'Laundry', 'Home', 'Care', 'Beauty', 'Care', 'business', 'recently', 'launched', 'packaging', 'made', 'solely', 'recycled', 'plastic', 'half', 'also', 'classed', 'Social', 'Plastic', 'This', 'Social', 'Plastic', 'come', 'Henkel', 'partnership', 'Plastic', 'Bank', 'soc ...
# ...
# ['Thursday', '12', 'July', 'red', 'letter', 'day', 'thousand', 'upon', 'thousand', 'kid', 'favourite', 'shop', 'Build', 'A', 'Bear', 'Workshop', 'The', 'company', 'announced', 'pay', 'age', 'promotion', 'customer', 'UK', 'US', 'Canada', 'could', 'come', 'make', 'teddy', 'pay', 'fraction', 'normal', 'cost', 'instead', '52', 'top', 'range', 'bear', 'six', 'year', 'old', 'would', 'pay', '6', 'It', 'sounded', 'brilliant', 'What', 'Build', 'A', 'Bear', 'factored', 'devotion', 'young', 'customer', 'unending', 'human', 'appetite', 'getting', 'something', 'cheap', 'Its', 'shop', 'overwhelmed', 'huge', 'queue', 'wanting', 'take', 'advantage', 'Police', 'called', 'help', 'control', 'crowd', 'outside', 'Leeds', 'branch', 'Scores', 'shop', 'close', 'early', 'thousand', 'people', 'left', 'without', 'getting', 'Even', 'left', 'wildly', 'disappointed', 'one', 'parent', 'told', 'BBC', 'child', 'queued', 'three', 'half', 'hour', 'get', 'Derby', 'branch', 'spent', 'another', 'two', 'hour', 'waiting', 'get', 'bear', 'stuffed', 'When', 'I', 'look', 'back', 'I', 'probably', 'think', 'What', 'I', 'done', 'especially', 'I', 'end', 'paying', 'parking', 'said', 'The', 'next', 'day', 'headline', 'contained', 'word', 'executive', 'want', 'see', 'describing', 'business', 'chaos', 'carnage', 'fiasco', 'You', 'might', 'thought', 'Build', 'A', 'Bear', 'would', 'take', 'urgent', 'action', 'ensure', 'different', 'outcome', 'US', 'store', 'opened', 'hour', 'later', 'Ben', 'Bigalke', 'three', 'half', 'year', 'old', 'daughter', 'Astrid', 'arrived', 'local', 'Build', 'A', 'Bear', 'Workshop', 'Minnesota', 'Mall', 'America', '9', '30am', '3', '30pm', 'UK', 'time', 'several', 'hour', 'day', 'disaster', 'The', 'area', 'around', 'store', 'completely', 'packed', 'ensconced', 'almost', 'camped', 'customer', 'tell', 'email', 'The', 'line', 'zigzagged', 'mall', 'first', 'floor', 'wound', 'way', 'entirely', 'theme', 'park', 'centre', 'mall', 'side', 'mall', 'It', 'seemed', 'like', 'quarter', 'mile', 'long', 'line', 'least', 'We', 'learned', 'later', 'people', 'began', 'camping', '6am', 'probably', '500', 'people', 'maybe', '1', '000', 'line', 'store', 'even', 'opened', 'We', 'nowhere', 'near', 'store', 'In', 'Minnesota', 'despite', 'already', 'happened', 'UK', 'event', 'came', 'complete', 'surprise', 'concerned', 'The', 'Build', 'A', 'Bear', 'store', 'staff', 'tell', 'customer', 'long', 'might', 'waiting', 'happening', 'I', 'asked', 'security', 'guard', 'expect', 'said', 'upset', 'situation', 'saying', 'unexpected', 'prepared', 'even', 'forewarned', 'something', 'like', 'could', 'happen', 'Bigalke', 'say', 'They', 'information', 'many', 'hour', 'could', 'expected', 'stay', 'line', 'I', 'feel', 'like', 'known', 'There', 'also', 'representative', 'store', 'telling', 'u', 'happening', 'expect', 'Pay', 'age', 'first', 'major', 'disaster', 'Build', 'A', 'Bear', '21', 'year', 'history', 'time', 'company', 'usually', 'ahead', 'game', 'retailer', 'mythmaker', 'It', 'rare', 'shopping', 'chain', 'origin', 'story', 'US', 'founder', 'Maxine', 'Clark', 'shopping', 'friend', 'child', 'little', 'girl', 'commented', 'make', 'bear', 'absence', 'anything', 'new', 'shop', 'A', 'lightbulb', 'went', 'Clark', 'head', 'Of', 'course', 'quite', 'homespun', 'Clark', 'experienced', 'retail', 'executive', 'worked', 'May', 'Co', 'department', 'store', 'company', 'president', 'Payless', 'ShoeSource', 'She', 'knew', 'The', 'first', 'part', 'Clark', 'genius', 'genius', 'anticipate', 'prove', 'important', 'shopping', 'development', 'internet', 'age', 'de', 'rigueur', 'experiential', 'retailing', 'In', 'summer', '1998', 'year', 'Clark', 'set', 'first', 'Build', 'A', 'Bear', 'Workshop', 'St', 'Louis', 'Missouri', 'Harvard', 'Business', 'Review', 'published', 'Welcome', 'Experience', 'Economy', 'influential', 'essay', 'set', 'path', 'ahead', 'From', 'leading', 'edge', 'company', 'whether', 'sell', 'consumer', 'business', 'find', 'next', 'competitive', 'battleground', 'lie', 'staging', 'experience', 'wrote',  ...
# ['Glass', 'maker', 'Corning', 'unveiled', 'new', 'version', 'Gorilla', 'Glass', 'used', 'majority', 'smartphone', 'display', 'say', 'twice', 'likely', 'survive', 'dropped', 'As', 'phone', 'get', 'bigger', 'come', 'glass', 'back', 'well', 'front', 'potential', 'smashed', 'device', 'increased', 'While', 'case', 'helped', 'even', 'heavily', 'protected', 'phone', 'screen', 'still', 'end', 'shattered', 'impact', 'stress', 'bent', 'squeezed', 'bumped', 'pocket', 'bag', 'Gorilla', 'Glass', '6', 'new', 'chemically', 'strengthened', 'highly', 'compressed', 'glass', 'Corning', 'say', 'twice', 'drop', 'protection', 'Gorilla', 'Glass', '5', 'With', 'break', 'drop', 'probabilistic', 'event', 'added', 'compression', 'help', 'increase', 'average', 'likelihood', 'survival', 'multiple', 'drop', 'event', 'said', 'Dr', 'Jaymin', 'Amin', 'vice', 'president', 'technology', 'product', 'development', 'Corning', 'The', 'new', 'glass', 'survived', 'average', '15', 'drop', '1m', 'rough', 'surface', 'lab', 'test', 'compared', '11', 'previous', 'version', 'meaning', 'resistant', 'multiple', 'drop', 'Gorilla', 'Glass', '6', 'improves', 'upon', 'Gorilla', 'Glass', '5', 'surviving', 'drop', 'higher', 'height', 'importantly', 'engineered', 'survive', 'multiple', 'drop', 'said', 'John', 'Bayne', 'vice', 'president', 'general', 'manager', 'Corning', 'Gorilla', 'Glass', 'Corning', 'said', 'Gorilla', 'Glass', '6', 'similar', 'scratch', 'resistance', 'property', 'older', 'glass', 'Apple', 'current', 'iPhones', 'Samsung', 'Galaxy', '9', 'majority', 'premium', 'smartphones', 'sold', 'UK', 'use', 'older', 'Gorilla', 'Glass', '5', 'Corning', 'said', 'Gorilla', 'Glass', '6', 'market', 'next', 'several', 'month', 'mean', 'top', 'end', 'smartphones', 'launched', 'second', 'half', 'year', 'ship', 'With', 'multiple', 'iPhones', 'expected', 'September', 'along', 'new', 'Google', 'Pixel', 'smartphones', 'October', 'replacement', 'Galaxy', 'S9', 'first', 'quarter', '2019', 'next', 'smartphone', 'might', 'break', 'drop']
# ['An', 'Islamic', 'State', 'supporter', 'called', 'attack', 'Prince', 'George', 'jailed', 'life', 'minimum', '25', 'year', 'string', 'terrorism', 'offence', 'Husnain', 'Rashid', 'Nelson', 'Lancashire', 'called', 'four', 'year', 'old', 'targeted', 'shortly', 'prince', 'joined', 'Thomas', 'school', 'Battersea', 'south', 'west', 'London', 'last', 'year', 'On', '13', 'October', 'posted', 'photograph', 'school', 'superimposed', 'silhouette', 'two', 'masked', 'jihadist', 'fighter', 'He', 'sent', 'follow', 'message', 'listed', 'address', 'writing', 'Even', 'royal', 'family', 'left', 'alone', 'School', 'start', 'early', 'The', 'post', 'Prince', 'George', 'tiny', 'fraction', 'Rashid', 'output', '13', 'month', 'arrest', '22', 'November', 'last', 'year', 'He', 'also', 'suggested', 'injecting', 'cyanide', 'fruit', 'vegetable', 'grocery', 'store', 'poisoning', 'ice', 'cream', 'supermarket', 'attacking', 'fan', 'football', 'World', 'Cup', 'Russia', 'The', '32', 'year', 'old', 'initially', 'denied', 'charge', 'mid', 'trial', 'changed', 'plea', 'four', 'seven', 'count', 'admitting', 'three', 'count', 'engaging', 'conduct', 'preparation', 'terrorist', 'act', 'one', 'count', 'encouraging', 'terrorism', 'The', 'Crown', 'Prosecution', 'Service', 'said', 'done', 'faced', 'overwhelming', 'weight', 'evidence', 'DCI', 'Andy', 'Meeks', 'case', 'senior', 'investigating', 'officer', 'north', 'west', 'counter', 'terrorism', 'unit', 'said', 'Rashid', 'posted', '360', '000', 'message', '150', 'different', 'forum', 'Telegram', 'online', 'messaging', 'service', 'November', '2016', 'arrest', 'year', 'later', 'Judge', 'Andrew', 'Lees', 'said', 'message', 'included', 'exhortation', 'attack', 'UK', 'football', 'stadium', '2017', 'general', 'election', 'Wimbledon', 'Trafford', 'Centre', 'Manchester', 'BBC', 'Proms', 'Park', 'may', 'viewed', 'million', 'people', 'Sentencing', 'Rashid', 'Woolwich', 'crown', 'court', 'Friday', 'Lees', 'said', 'The', 'message', 'clear', 'providing', 'name', 'address', 'Prince', 'George', 'school', 'image', 'Prince', 'George', 'school', 'instruction', 'threat', 'Prince', 'George', 'member', 'royal', 'family', 'viewed', 'potential', 'target', 'Rashid', 'given', 'life', 'sentence', 'count', 'engaging', 'conduct', 'preparation', 'terrorist', 'act', 'minimum', 'term', '25', 'year', 'He', 'sentenced', 'four', 'half', 'year', 'imprisonment', 'offence', 'encouraging', 'terrorism', 'run', 'concurrently', 'Rashid', 'worked', 'teacher', 'Muhammadi', 'mosque', 'Nelson', 'encouraged', 'follower', 'deploy', 'variety', 'weapon', 'including', 'knife', 'homemade', 'bomb', 'poison', 'chemical', 'vehicle', 'krav', 'maga', 'martial', 'art', 'employed', 'Israeli', 'military', 'force', 'He', 'praised', 'successful', 'terrorist', 'attack', 'country', 'writing', 'Look', 'around', 'many', 'infidel', 'reach', 'kill', 'car', 'knife', 'even', 'stone', 'poisoning', 'Go', 'take', 'revenge', 'What', 'waiting', 'We', 'ask', 'Allah', 'bless', 'make', 'successful', 'One', 'Christmas', 'posted', 'message', 'online', 'wishing', 'people', 'terror', 'filled', 'new', 'year', 'The', 'prosecutor', 'Annabel', 'Darlow', 'QC', 'said', 'overarching', 'aim', 'Rashid', 'activity', 'provide', 'e', 'toolkit', 'terrorism', 'He', 'suggested', 'dropping', 'smoke', 'grenade', 'cause', 'panic', 'adding', 'You', 'enjoying', 'taking', 'one', 'terrorizethekuffar', 'He', 'also', 'posted', 'No', 'need', 'board', 'train', 'Just', 'get', 'train', 'station', 'Then', 'name', 'Allah', 'get', 'busy', 'These', 'word', 'followed', 'emojis', 'bomb', 'knife', 'dripping', 'blood', 'There', 'evidence', 'anyone', 'acted', 'post', 'Rashid', 'went', 'great', 'length', 'hide', 'online', 'extremism', 'authority', 'The', 'encryption', 'laptop', 'two', 'terabyte', 'hard', 'drive', 'strong', 'intelligence', 'agency', 'unable', 'crack', 'He', 'used', 'encrypted', 'Telegram', 'app', 'three', 'different', 'sim', 'card', 'hacked', 'neighbour', 'internet', 'connection', 'publish', 'material', 'online', 'The', 'vast' ...
# ['Samsung', 'investigating', 'report', 'default', 'text', 'messaging', 'app', 'Galaxy', 'S8', 'S9', 'smartphones', 'sending', 'photo', 'random', 'contact', 'without', 'permission', 'Users', 'posted', 'complaint', 'Reddit', 'Samsung', 'support', 'forum', 'strange', 'issue', 'appears', 'silently', 'sending', 'photo', 'random', 'contact', 'The', 'Samsung', 'Messages', 'app', 'show', 'sign', 'sending', 'photo', 'meaning', 'user', 'completely', 'unaware', 'picture', 'messaging', 'Last', 'night', 'around', '2', '30am', 'phone', 'sent', 'entire', 'photo', 'gallery', 'text', 'record', 'message', 'app', 'However', 'record', 'Tmobile', 'log', 'Why', 'would', 'happen', 'asked', 'one', 'Reddit', 'user', 'Oddly', 'enough', 'wife', 'phone', 'last', 'night', 'mine', 'night', 'said', 'Reddit', 'user', 'Sfkn123', 'I', 'think', 'something', 'Samsung', 'SMS', 'app', 'updated', 'Galaxy', 'Store', 'When', 'phone', 'texted', 'gallery', 'show', 'end', 'vice', 'versa', 'Reddit', 'user', 'Moosan', 'said', 'something', 'similar', 'happened', 'My', 'phone', 'battery', 'super', 'low', 'overnight', 'maximum', 'power', 'saving', 'kicked', 'routine', 'I', 'set', 'Good', 'Lock', 'two', 'three', 'people', 'sent', 'photo', 'one', 'photo', 'I', 'sent', 'past', 'While', 'clear', 'causing', 'random', 'picture', 'messaging', 'affected', 'user', 'reported', 'receiving', 'update', 'default', 'text', 'messaging', 'app', 'Samsung', 'smartphones', 'enables', 'Rich', 'Communication', 'Services', 'RCS', 'This', 'long', 'awaited', 'replacement', 'SMS', 'add', 'modernisation', 'feature', 'picture', 'messaging', 'typing', 'indicator', 'read', 'receipt', 'Samsung', 'said', 'We', 'aware', 'report', 'regarding', 'matter', 'technical', 'team', 'looking', 'Affected', 'user', 'encouraged', 'contact', 'Samsung', 'directly', 'fix', 'issued', 'In', 'meantime', 'user', 'switch', 'another', 'text', 'messaging', 'app', 'Google', 'Android', 'Messages', 'disable', 'access', 'phone', 'storage', 'Samsung', 'Messages', 'app']

# %%
df["Senti"] = sentiment

# %%
daterange = df["Date"]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
#Graph to show the relationship between the said date and the sentiments of the articles in the range 

plt.plot(daterange, sentiment, 'rD-')
# plt.ylim(-10,80)

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

plt.title("Sentiments vs Date")

plt.xlabel('Date')
plt.ylabel('Sentiments In Each Article')


plt.show()

# %%
df.to_csv("TextblobSentiment.csv")

# %%
#Count after removal of stop words
countaft = [len(content[i]) for i in range(len(content))]
print(countaft)
# Out:
# [435, 944, 951, 241, 1399, 202, 834, 1237, 973, 558, 1007, 331, 255, 853, 1047, 1320, 1240, 2484, 802, 1348, 1366, 406, 2427, 710, 820, 468, 1057, 1288, 1063, 1156, 616, 1389, 112, 664, 383, 476, 1096, 754, 301, 317, 793, 766, 563, 320, 169, 96, 368, 861, 569, 876, 1827, 846, 809, 970, 879, 811, 393, 870, 253, 206, 801, 548, 709, 70, 835, 851, 67, 1956, 1132, 596, 424, 378, 824, 732, 367, 796, 455, 935, 995, 328, 171, 107, 432, 604, 441, 349, 1140, 345, 581, 1004, 723, 347, 78, 545, 449, 131, 148, 365, 298, 885, 919, 1288, 548, 556, 853, 407, 343, 345, 479, 792, 173, 686, 224, 394, 1034, 789, 1170, 82, 637, 341, 797, 579, 913, 1437, 580, 558, 892, 240, 205, 2776, 307, 1985, 545, 483, 807, 137, 494, 480, 426, 818, 731, 616, 428, 705, 1570, 591, 649, 628, 724, 904, 1585, 888, 806, 309, 1235, 550, 329, 1030, 705, 921, 799, 1094, 429, 762, 559, 260, 765, 329, 779, 1047, 343, 862, 960, 1240, 815, 230, 531, 779, 827, 664, 876, 3000, 937, 836, 199, 428, 641, 329, 486, 671, 458, 1089, 136, 220, 416, 502, 29, 443, 1447, 204]

# %%
#Tagging
content_tag = [nltk.pos_tag(i) for i in content]
print(content_tag)
# Out:
# [[('Google', 'NNP'), ('snapped', 'VBD'), ('Fitbit', 'NNP'), ('activity', 'NN'), ('tracker', 'NN'), ('business', 'NN'), ('2', 'CD'), ('1bn', 'CD'), ('1', 'CD'), ('6bn', 'CD'), ('deal', 'NN'), ('enable', 'JJ'), ('search', 'NN'), ('giant', 'NN'), ('go', 'VBP'), ('toe', 'JJ'), ('toe', 'NN'), ('Apple', 'NNP'), ('fast', 'RB'), ('growing', 'VBG'), ('smartwatch', 'RBR'), ('wearable', 'JJ'), ('business', 'NN'), ('Google', 'NNP'), ('paying', 'VBG'), ('cash', 'NN'), ('San', 'NNP'), ('Francisco', 'NNP'), ('based', 'VBN'), ('Fitbit', 'NNP'), ('set', 'JJ'), ('2007', 'CD'), ('It', 'PRP'), ('paying', 'VBG'), ('7', 'CD'), ('35', 'CD'), ('per', 'IN'), ('share', 'NN'), ('premium', 'NN'), ('70', 'CD'), ('Fitbit', 'NNP'), ('share', 'NN'), ('price', 'NN'), ('share', 'NN'), ('suspended', 'VBN'), ('earlier', 'RBR'), ('week', 'NN'), ('amid', 'IN'), ('takeover', 'NN'), ('speculation', 'NN'), ('The', 'DT'), ('price', 'NN'), ('however', 'RB'), ('fraction', 'NN'), ('company', 'NN'), ('value', 'NN'), ('floated', 'VBD'), ('2015', 'CD'), ('The', 'DT'), ('share', 'NN'), ('initially', 'RB'), ('priced', 'VBN'), ('20', 'CD'), ('soared', 'VBD'), ('50', 'CD'), ('week', 'NN'), ('following', 'VBG'), ('initial', 'JJ'), ('public', 'JJ'), ('offer', 'NN'), ('But', 'CC'), ('suffered', 'VBD'), ('recent', 'JJ'), ('year', 'NN'), ('competition', 'NN'), ('bigger', 'JJR'), ('rival', 'NN'), ('Apple', 'NNP'), ('Samsung', 'NNP'), ('China', 'NNP'), ('Xiaomi', 'NNP'), ('In', 'IN'), ('August', 'NNP'), ('group', 'NN'), ('share', 'NN'), ('hit', 'VBD'), ('low', 'JJ'), ('2', 'CD'), ('85', 'CD'), ('The', 'DT'), ('deal', 'NN'), ('Google', 'NNP'), ('biggest', 'JJS'), ('consumer', 'NN'), ('purchase', 'NN'), ('since', 'IN'), ('bought', 'VBD'), ('home', 'NN'), ('tech', 'NN'), ('business', 'NN'), ('Nest', 'NNP'), ('five', 'CD'), ('year', 'NN'), ('ago', 'RB'), ('3bn', 'CD'), ('approved', 'VBD'), ('shareholder', 'NN'), ('regulator', 'NN'), ('especially', 'RB'), ('handle', 'JJ'), ('Fitbit', 'NNP'), ('user', 'NN'), ('data', 'VBD'), ('The', 'DT'), ('firm', 'NN'), ('claim', 'NN'), ('28m', 'CD'), ('active', 'JJ'), ('user', 'NN'), ('worldwide', 'NN'), ('fitness', 'NN'), ('tracker', 'NN'), ('store', 'NN'), ('location', 'NN'), ('physical', 'JJ'), ('health', 'NN'), ('data', 'NNS'), ('user', 'RB'), ('monitor', 'VBP'), ('activity', 'NN'), ('sleep', 'NN'), ('exercise', 'NN'), ('using', 'VBG'), ('range', 'NN'), ('wearable', 'JJ'), ('device', 'NN'), ('Fitbit', 'NNP'), ('said', 'VBD'), ('would', 'MD'), ('sell', 'VB'), ('customer', 'NN'), ('personal', 'JJ'), ('data', 'NNS'), ('pledged', 'VBD'), ('wellness', 'NN'), ('data', 'NNS'), ('would', 'MD'), ('used', 'VBN'), ('Google', 'NNP'), ('ad', 'NN'), ('Google', 'NNP'), ('offered', 'VBD'), ('fitness', 'JJ'), ('tracking', 'NN'), ('service', 'NN'), ('called', 'VBN'), ('Google', 'NNP'), ('Fit', 'NNP'), ('since', 'IN'), ('2014', 'CD'), ('relied', 'VBD'), ('third', 'JJ'), ('party', 'NN'), ('Fossil', 'NNP'), ('Tag', 'NNP'), ('Heuer', 'NNP'), ('produce', 'VBP'), ('Android', 'NNP'), ('compatible', 'JJ'), ('smartwatches', 'NNS'), ('In', 'IN'), ('blogpost', 'NN'), ('announcing', 'NN'), ('deal', 'NN'), ('Rick', 'NNP'), ('Osterloh', 'NNP'), ('Google', 'NNP'), ('senior', 'JJ'), ('vice', 'NN'), ('president', 'NN'), ('charge', 'NN'), ('device', 'NN'), ('service', 'NN'), ('said', 'VBD'), ('Fitbit', 'NNP'), ('pioneer', 'NN'), ('Google', 'NNP'), ('could', 'MD'), ('help', 'VB'), ('spur', 'VB'), ('innovation', 'NN'), ('wearable', 'JJ'), ('build', 'JJ'), ('product', 'NN'), ('benefit', 'VB'), ('even', 'JJ'), ('people', 'NNS'), ('around', 'IN'), ('world', 'NN'), ('The', 'DT'), ('market', 'NN'), ('wearable', 'JJ'), ('growing', 'VBG'), ('rapidly', 'RB'), ('Last', 'JJ'), ('week', 'NN'), ('latest', 'JJS'), ('quarterly', 'JJ'), ('financial', 'JJ'), ('result', 'NN'), ('Apple', 'NNP'), ('reported', 'VBD'), ('annual', 'JJ'), ('sale', 'NN'), ('growth', 'NN'), ('50', 'CD'), ('wearable', 'JJ'), ('division', 'NN'), ('includes', 'VBZ'), ('watch', 'VBP'), ('The', 'DT'), ('iPhone', 'NN'), ('maker', 'NN' ...

# %%
#Difference for the count before and after stop word removal
count_diff = []
for i in range(len(count)):
    count_diff.append(round(((count[i] - countaft[i])/count[i])*100, 1))
print(count_diff)
# Out:
# [89.6, 89.1, 89.7, 90.9, 89.4, 89.4, 89.4, 89.7, 88.9, 90.0, 89.0, 89.6, 89.5, 90.1, 88.6, 89.4, 89.1, 90.2, 89.1, 89.2, 89.4, 89.3, 89.5, 90.3, 89.4, 89.2, 89.6, 89.1, 89.6, 89.3, 88.1, 89.7, 89.1, 90.1, 90.1, 89.4, 89.1, 90.0, 89.8, 90.7, 88.5, 89.5, 90.6, 89.0, 89.5, 90.4, 90.0, 90.4, 90.9, 89.1, 89.0, 88.9, 89.1, 88.9, 89.8, 89.0, 90.4, 89.5, 89.1, 89.1, 89.3, 90.5, 89.3, 89.0, 89.3, 89.2, 89.3, 90.3, 88.9, 89.4, 89.7, 88.3, 88.8, 88.8, 89.0, 89.1, 89.4, 89.9, 89.7, 89.1, 89.2, 90.4, 89.5, 90.7, 90.6, 90.3, 88.8, 90.3, 89.9, 89.7, 89.3, 89.6, 90.6, 89.4, 89.2, 89.0, 89.9, 89.3, 89.1, 88.6, 90.1, 89.4, 89.8, 89.5, 89.0, 89.1, 89.8, 89.7, 89.2, 89.8, 90.4, 89.4, 90.3, 90.1, 89.3, 89.6, 90.1, 88.6, 89.2, 89.8, 89.7, 89.0, 90.1, 89.3, 90.1, 90.0, 90.0, 89.2, 89.5, 89.6, 90.4, 90.7, 89.5, 89.5, 90.2, 89.6, 89.9, 89.8, 89.5, 89.7, 89.4, 89.2, 89.9, 89.3, 88.5, 89.8, 89.8, 89.5, 90.3, 90.0, 90.5, 89.6, 89.3, 89.0, 89.0, 88.2, 90.4, 88.9, 89.0, 89.9, 89.2, 89.2, 88.6, 89.1, 90.7, 89.8, 89.2, 89.7, 89.1, 89.0, 90.6, 89.7, 90.3, 89.7, 89.4, 90.1, 89.7, 88.9, 90.5, 90.3, 88.8, 90.5, 89.2, 89.6, 89.4, 89.1, 89.2, 90.0, 89.2, 89.9, 90.0, 89.8, 89.8, 89.2, 89.5, 90.1, 89.3, 89.5, 89.8, 89.6]

# %%
Freq = [FreqDist(content_freq[i]).most_common(5) for i in range(len(content_freq))]

# %%
# df['Content with Tag'] = content_tag
df['Amount Cleansed (%)'] = count_diff
# df['Frequency'] = Freq

df.to_csv('Output.csv')

# %%
# Sentiment Analysis

# %%
feeling_words = []
word_total_count = 0
for articles in content_tag:
    word_total_count += len(articles)
    for words in articles:
        if words[1].startswith('JJ'):
            feeling_words.append((words))

print(feeling_words)

# %%
feeling_words_1 = []
word_total_count = 0
# for articles in content_tag:
#     word_total_count += len(articles)
#     for words in articles:
#         if words[1].startswith('JJ'):
#             feeling_words.append((words))
for words1 in content_tag[0]:
#     print(words1)
    if words1[1].startswith('JJ'):
        feeling_words_1.append((words1))

print(feeling_words_1)
print(len(feeling_words_1))

# %%
# feeling_words = []
# word_total_count = 0
# for articles in content_tag:
#     word_total_count += len(articles)
#     for words in articles:
#         if words[1].startswith('JJ'):
#             feeling_words.append((words[0]))

# Feeling_Freq = FreqDist(feeling_words).most_common(500)
# # print(Feeling_Freq)
# adj_list = []
# for word in Feeling_Freq:
#     adj_list.append(word[0])
    
# print(adj_list)

# # word_features = list(Feeling_Freq.keys())[:500]
# # pprint(word_features)

# %%
# adj_list_tag = [nltk.pos_tag(i) for i in adj_list]

# for word in adj_list:
#     nltk.pos_tag(word)

# # print(adj_list)

# %%
# print(adj_list_tag)

# %%
from nltk.corpus import wordnet as wn

def penn_to_wn(tag):
    """
    Convert between the PennTreebank tags to simple Wordnet tags
    """
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

for articles in feeling_words:
#     for words in articles:
    penn_to_wn(articles[1])

# %%
from nltk.corpus import sentiwordnet as swn

breakdown = swn.senti_synset('breakdown.n.04')
print(breakdown)

# %%
def get_sentiment(word,tag):
    """ returns list of pos neg and objective score. But returns empty list if not present in senti wordnet. """

    wn_tag = penn_to_wn(tag)
    if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV):
        return []

    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    if not lemma:
        return []

    synsets = wn.synsets(word, pos=wn_tag)
    if not synsets:
        return []

    # Take the first sense, the most common
    synset = synsets[0]
    swn_synset = swn.senti_synset(synset.name())
    

    return [swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score()]

# %%
get_sentiment("toe", wn.NOUN)

# %%
pos_list = []
neg_list = []

for articles in feeling_words:
    senti = get_sentiment(articles[0], articles[1])
    if len(senti) >0:
        if senti[0]>senti[1]:
            print("pos: " + articles[0] + str(senti))
            pos_list.append([articles[0], senti])
        elif senti[1]>senti[0]:
            print("neg: " + articles[0] + str(senti))
            neg_list.append([articles[0], senti])

# %%
print(pos_list)

# %%
print(neg_list)

# %%
#Useless

# import pandas

# df_pos_list = pandas.DataFrame(pos_list)
# # print(df_pos_list)
# top_pos_list = FreqDist(df_pos_list[0]).most_common(200)
# print(top_pos_list)
# words_only = []
# for words in pos_list:
#     words_only.append(words[0])

# for asd in words_only:
#     print(FreqDist(asd).most_common(200))

# %%
unique_pos = [] 

for eachlist in pos_list: 
    if eachlist not in unique_pos:
        unique_pos.append(eachlist) 

print(unique_pos)

# %%
unique_neg = [] 

for eachlist in neg_list: 
    if eachlist not in unique_neg:
        unique_neg.append(eachlist) 

print(unique_neg)

# %%
for posword in unique_pos:
    posvalue = posword[1][0]
    negvalue = posword[1][1]
    senti_value = str(posvalue - negvalue)
    posword.append(posword[1][0] - posword[1][1])
print(unique_pos)

# %%
for negword in unique_neg:
    posvalue = posword[1][0]
    negvalue = posword[1][1]
    senti_value = str(posvalue - negvalue)
    negword.append(negword[1][0] - negword[1][1])
print(unique_neg)

# %%
from pprint import pprint

sentiwordlist = unique_pos + unique_neg

pprint(sentiwordlist)

# %%
#doesnt work:(

articlesenti = []

for article in content:
    totalsenti = []
    for word in article:
        for i in range(len(sentiwordlist)):
            if sentiwordlist[i][0] in word:
                totalsenti.append(sentiwordlist[i][2])
    articlesenti.append(sum(totalsenti))

# %%
print(articlesenti)
print(len(articlesenti))

# %%
articlesenti = []

for article in df['Text']:
    totalsenti = []
    print("\n***NEW ARTICLE***")
    for i in range(len(sentiwordlist)):
        if sentiwordlist[i][0] in article:
            print(sentiwordlist[i][0], sentiwordlist[i][2])
            totalsenti.append(sentiwordlist[i][2])
    articlesenti.append(sum(totalsenti))
    print("sum = {}, sentiwords = {}".format(sum(totalsenti), len(totalsenti)))

# %%
print(len(feeling_words))
print(len(sentiwordlist))

# %%
articlesenti = []

for article in df['Text']:
    totalsenti = []
    print("\n***NEW ARTICLE***")
    for i in range(len(sentiwordlist)):
        if sentiwordlist[i][0] in article:
            print(sentiwordlist[i][0], sentiwordlist[i][2])
            totalsenti.append(sentiwordlist[i][2])
    articlesenti.append(sum(totalsenti))
    print("sum = {}, sentiwords = {}".format(sum(totalsenti), len(totalsenti)))

# %%
for i in range(len(articlesenti)):
    print(articlesenti[i], i)
print(len(articlesenti))

# %%
articlepossenti = []

for article in df['Text']:
    totalpossenti = []
    for i in range(len(unique_pos)):
        if unique_pos[i][0] in article:
            totalpossenti.append(unique_pos[i][2])
    articlepossenti.append(sum(totalpossenti))
print(articlepossenti)

# %%
articlenegsenti = []

for article in df['Text']:
    totalnegsenti = []
    for i in range(len(unique_neg)):
        if unique_neg[i][0] in article:
            totalnegsenti.append(unique_neg[i][2])
    articlenegsenti.append(sum(totalnegsenti))
print(articlenegsenti)

# %%
articlenetsenti = [articlepossenti[i] + articlenegsenti[i] for i in range(len(articlepossenti))]
print(articlenetsenti)

# %%
poscount = 0
negcount = 0
neucount = 0
for value in articlenetsenti:
    if value > 0:
        poscount += 1
    elif value < 0:
        negcount += 1
    elif value == 0:
        neucount += 1
        
print("Pos: {}, Neg: {}, Neu: {}".format(poscount, negcount, neucount))

# %%
print(len(sentiwordlist))
