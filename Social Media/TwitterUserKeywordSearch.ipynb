# %%
import pandas as pd

# %%
def keywordsearch():

    #Samsung Dictionary
    samsunglist = ["samsung","galaxy", "samsung galaxy", "samsung group", 
        "samsung technologies","galaxy s10", "galaxy note10", "galaxy fold", 
        "galaxy s10+", "galaxy s10e", "galaxy buds", "galaxy watch", "watch active 2",
        "galaxy tab", "tab S6", "galaxy book S", "samsung electronics", "samsung x IFA 2019", 
        "the wall luxury", "Q series soundbar", "seoul sisters conference", 
        " Samsung Semiconductor Institute of Technology", "galaxy A30", "galaxy S11", 
        "a70 waterproof", "a70 wireless charging", "s10 plus", "s7 edge", "galaxy m30", "galaxy j7", 
       "galaxy j2", "galaxy a10", "space zoom", "samsung support", "the serif", "#dowhatyoucant", "spacemax", 
       "galaxy A", "galaxy note", "QLED", "quickdrive", "s series", "galaxyAs", "samsung mobile", "SamsungMobileSA",
       "#DontFumbleTheBag", "galaxy a30s", "#FillUpRoyalBafokeng", "#SDC19", "galaxy buds", "samsungUS", "samsungsupport",
       "chromebook", "samsung J4", "samsung J4 core", "galaxy J4", "galaxy J2", "galaxy J4 core", "galaxy tab",
       "samsung health", "SamsungKids", "SamsungKidsUS", "samsung galacy", "TeamGalaxy", "#TeamGalaxy", "withgalaxy",
       "galaxy FIT E", "samsung T5", "galaxy T5", "Samsung Catalyst Fund", "samsungcatalyst", "SamsungCEOSummit",
       "Samsung 5G Exynos 980", "SamMobile"]


    datafile = input('Which data set do you want to cleanse?')
    df = pd.read_csv('C:/Users/User/Desktop/FYP/FYP/Social Media/CSV/Cleanse/' + datafile + 'Cleanse.csv', names = ['User','Date','Tweets'])
    
    count = 0
    usercontent = df['User']
    userdate = df['Date']
    content = df["Tweets"]

    print(len(content))

    #for loop to run through every row in datafile
    #inside the for loop is a if else loop to check for relvent data rows using the samsung dictionary
    #Append relevent rows into a new list then convert into a dataframe 

    relevantuser = []
    relevantdate = []
    relevanttext = []
    for words in samsunglist:
        for i in range(len(content)):
            if (words in content.iloc[i].lower()) == True:
                print(words)
                count += 1 
                print(content.iloc[i])

                relevantuser.append(usercontent.iloc[i])
                relevantdate.append(userdate.iloc[i])
                relevanttext.append(content.iloc[i])

    print(relevantuser)
    print(relevantdate)
    print(relevanttext)

    dfUser = pd.DataFrame(relevantuser, columns = ['User'])
    dfDate = pd.DataFrame(relevantdate, columns = ['Date'])
    dfTweets = pd.DataFrame(relevanttext, columns = ['Tweets'])


    final = pd.concat([dfUser,dfDate,dfTweets], axis = 1)

    # remove duplicate rows
    final.drop_duplicates(subset = 'Tweets' ,keep = 'first', inplace = True)

    # Convert DataFrame to csv
    pd.DataFrame.from_dict(data = final , orient = 'columns').to_csv('C:/Users/User/Desktop/FYP/FYP/Social Media/CSV/Relevant/' + datafile + 'Relevant.csv')

# %%
keywordsearch()
# Out:
# Which data set do you want to cleanse?BBCTech
# 3136
# samsung
# RBS pulls Samsung Galaxy S10 app over security flaw
# samsung
# Any fingerprint unlocks Galaxy S10 Samsung warns
# samsung
# Samsung Galaxy Fold UK launch date revealed
# samsung
# Galaxy Note 10 Samsung hopes to strike the right Note
# samsung
# RT  Samsung says the Galaxy Fold will go on sale in September after faulty screens delayed the launch
# samsung
# Samsung sued over waterresistant phone claims
# samsung
# Samsung TVs should be regularly viruschecked the company says
# samsung
# Samsung unveils TV that can switch to vertical mode
# samsung
# Samsung Galaxy Fold launch events delayed in China
# samsung
# Samsungs folding phone breaks for reviewers
# samsung
# RT  Heres my first handson with the Samsung Galaxy Fold GalaxyFold
# samsung
# RT  Our folding phone is bigger and better than Samsungs says Huawei
# samsung
# Samsung on whether you can end calls on the GalaxyFold by snapping it shut like the old flip phones
# samsung
# RT  Important can I answer calls with the phone unfolded and then hang up by snapping it shut   Samsung
# samsung
# Samsung Galaxy Fold The internet reacts
# samsung
# Samsung reveals Galaxy Fold and S10 5G
# samsung
# CES 2019 Samsung adds rival Apples iTunes to smart TVs
# samsung
# RT  Samsung has revealed a 75in 190cm television made of modular panels you can rearrange  CES2019
# samsung
# Huawei Honor View20 and Samsung A8s have holepunch cameras
# samsung
# Samsung Nigeria tweets update using Apple iPhone
# samsung
# Samsung apologises to sick factory workers
# samsung
# RT  After 5 years of talking about folding devices Samsung unveiled theirs at SDC18
# samsung
# Samsung agrees to payouts after worker deaths
# samsung
# Apple and Samsung fined by Italian authorities over slow phones
# samsung
# Samsung Time for folding smartphones
# samsung
# Samsung Galaxy Note 9 warns of wonky photos
# samsung
# Why is Samsungs Galaxy S9 flagship struggling
# samsung
# Samsung wont be forced to update old phones
# samsung
# Apple awarded 539m in US patent case against Samsung
# samsung
# AppleSamsung patent battle revived in California court
# samsung
# Samsung Galaxy S9 gets super slowmo and AR emojis
# samsung
# Samsung Galaxy S9 focuses on the camera
# samsung
# Samsung Galaxy S9 smartphone images leaked by MWC app
# galaxy
# RBS pulls Samsung Galaxy S10 app over security flaw
# galaxy
# Any fingerprint unlocks Galaxy S10 Samsung warns
# galaxy
# Samsung Galaxy Fold UK launch date revealed
# galaxy
# Galaxy Note 10 Samsung hopes to strike the right Note
# galaxy
# RT  Samsung says the Galaxy Fold will go on sale in September after faulty screens delayed the launch
# galaxy
# Samsung Galaxy Fold launch events delayed in China
# galaxy
# RT  Heres my first handson with the Samsung Galaxy Fold GalaxyFold
# galaxy
# Samsung on whether you can end calls on the GalaxyFold by snapping it shut like the old flip phones
# galaxy
# Samsung Galaxy Fold The internet reacts
# galaxy
# Samsung reveals Galaxy Fold and S10 5G
# galaxy
# Samsung Galaxy Note 9 warns of wonky photos
# galaxy
# Why is Samsungs Galaxy S9 flagship struggling
# galaxy
# Samsung Galaxy S9 gets super slowmo and AR emojis
# galaxy
# Samsung Galaxy S9 focuses on the camera
# galaxy
# Samsung Galaxy S9 smartphone images leaked by MWC app
# galaxy
# Guardians of the Galaxy Vol 2 Visual effects revealed
# samsung galaxy
# RBS pulls Samsung Galaxy S10 app over security flaw
# samsung galaxy
# Samsung Galaxy Fold UK launch date revealed
# samsung galaxy
# Samsung Galaxy Fold launch events delayed in China
# samsung galaxy
# RT  Heres my first handson with the Samsung Galaxy Fold GalaxyFold
# samsung galaxy
# Samsung Galaxy Fold The internet reacts
# samsung galaxy
# Samsung Galaxy Note 9 warns of wonky photos
# samsung galaxy
# Samsung Galaxy S9 gets super slowmo and AR emojis
# samsung galaxy
# Samsung Galaxy S9 focuses on the camera
# samsung galaxy
# Samsung Galaxy S9 smartphone images leaked by MWC app
# galaxy s10
# RBS pulls Samsung Galaxy S10 app over security flaw
# galaxy s10
# Any fingerprint unlocks Galaxy S10 Samsung warns
# galaxy fold
# Samsung Galaxy Fold UK launch date revealed
# galaxy fold
# RT  Samsung says the Galaxy Fold will go on sale in September after faulty screens delayed the launch
# galaxy fold
# Samsung Galaxy Fold launch events delayed in China
# galaxy fold
# RT  Heres my first handson with the Samsung Galaxy Fold GalaxyFold
# galaxy fold
# Samsung Galaxy Fold The internet reacts
# galaxy fold
# Samsung reveals Galaxy Fold and S10 5G
# galaxy note
# Galaxy Note 10 Samsung hopes to strike the right Note
# galaxy note
# Samsung Galaxy Note 9 warns of wonky photos
# ['BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech', 'BBCTech']
# ['2019-10-24', '2019-10-17', '2019-09-05', '2019-08-07', '2019-07-25', '2019-07-04', '2019-06-17', '2019-04-30', '2019-04-22', '2019-04-17', '2019-04-16', '2019-02-24', '2019-02-21', '2019-02-21', '2019-02-20', '2019-02-20', '2019-01-08', '2019-01-07', '2018-12-10', '2018-12-03', '2018-11-23', '2018-11-07', '2018-11-01', '2018-10-24', '2018-09-05', '2018-08-09', '2018-07-31', '2018-05-31', '2018-05-25', '2018-05-14', '2018-02-25', '2018-02-25', '2018-02-21', '2019-10-24', '2019-10-17', '2019-09-05', '2019-08-07', '2019-07-25', '2019-04-22', '2019-04-16', '2019-02-21', '2019-02-20', '2019-02-20', '2018-08-09', '2018-07-31', '2018-02-25', '2018-02-25', '2018-02-21', '2018-02-21', '2019-10-24', '2019-09-05', '2019-04-22', '2019-04-16', '2019-02-20', '2018-08-09', '2018-02-25', '2018-02-25', '2018-02-21', '2019-10-24', '2019-10-17', '2019-09-05', '2019-07-25', '2019-04-22', '2019-04-16', '2019-02-20', '2019-02-20', '2019-08-07', '2018-08-09']
# ['RBS pulls Samsung Galaxy S10 app over security flaw ', 'Any fingerprint unlocks Galaxy S10 Samsung warns ', 'Samsung Galaxy Fold UK launch date revealed ', 'Galaxy Note 10 Samsung hopes to strike the right Note ', 'RT  Samsung says the Galaxy Fold will go on sale in September after faulty screens delayed the launch ', 'Samsung sued over waterresistant phone claims ', 'Samsung TVs should be regularly viruschecked the company says ', 'Samsung unveils TV that can switch to vertical mode ', 'Samsung Galaxy Fold launch events delayed in China ', 'Samsungs folding phone breaks for reviewers ', 'RT  Heres my first handson with the Samsung Galaxy Fold GalaxyFold ', 'RT  Our folding phone is bigger and better than Samsungs says Huawei ', 'Samsung on whether you can end calls on the GalaxyFold by snapping