# %%
import os
import glob
import pandas as pd
import numpy as np

# %%
# directory folder 

os.chdir(r"C:\Users\User\Desktop\FYP\FYP\Social Media\reddit\MLReady\SelfText")

# %%
#include all files in the folder into the list

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

all_filenames
# Out:
# ['April2019SentimentAll.csv',
#  'August2018SentimentAll.csv',
#  'August2019SentimentAll.csv',
#  'December2018SentimentAll.csv',
#  'Feburary2019SentimentAll.csv',
#  'January2019SentimentAll.csv',
#  'July2018SentimentAll.csv',
#  'July2019SentimentAll.csv',
#  'June2019SentimentAll.csv',
#  'March2019SentimentAll.csv',
#  'May2019SentimentAll.csv',
#  'November2018SentimentAll.csv',
#  'October2018SentimentAll.csv',
#  'October2019SentimentAll.csv',
#  'September2018SentimentAll.csv',
#  'September2019SentimentAll.csv']

# %%
#combine all files in the list

combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

df = combined_csv.sort_values(by='timestamp', ascending=True)

df
# Out:
#      Unnamed: 0            timestamp  \
# 0             0  2018-06-30 19:15:49
# 1             1  2018-07-01 00:12:16
# 2             2  2018-07-01 13:45:03
# 3             3  2018-07-01 18:30:28
# 4             4  2018-07-01 20:20:27
# ..          ...                  ...
# 122         122  2019-10-14 10:57:46
# 123         123  2019-10-14 18:30:11
# 124         124  2019-10-14 20:06:22
# 125         125  2019-10-14 22:26:44
# 126         126  2019-10-14 23:47:19
#
#                                                   body    neg    neu    pos  \
# 0    ['I have a Samsung CF391, and I want to use it...  0.088  0.755  0.157
# 1    ['I can hear my phone calls and the beeps and ...  0.000  0.910  0.090
# 2    ['Hi! So I recently got a new phone, I took th...  0.065  0.816  0.118
# 3    ['Rumours have it Apple will launch the new iP...  0.087  0.913  0.000
# 4    ["I just got a new S9+, after using an older S...  0.057  0.862  0.081
# ..                                                 ...    ...    ...    ...
# 122  ['I’m trying to set a rotation for different p...  0.090  0.910  0.000
# 123  ['Hello guys, I\'ve recently bought Samsung Ga...  0.032  0.906  0.062
# 124  ["Ive seen it on pixel phones but can't find i...  0.000  1.000  0.000
# 125  ['When I get in it wont load the community sec...  0.000  1.000  0.000
# 126  ['I previously was using brave browser and tho...  0.000  0.767  0.233
#
#      compound
# 0      0.2960
# 1      0.4497
# 2      0.7993
# 3     -0.2960
# 4      0.4574
# ..        ...
# 122   -0.5499
# 123    0.2716
# 124    0.0000
# 125    0.0000
# 126    0.9468
#
# [2215 rows x 7 columns]

# %%
#export to csv

df.to_csv(r"C:\Users\User\Desktop\FYP\FYP\Social Media\reddit\MLReady\SelfText\Concat\All_concat_selftext.csv", index=False, encoding='utf-8-sig')
